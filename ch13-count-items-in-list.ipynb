# %% [markdown]
# ### create a dictionary through a for loop

# %%
list = [102, 232, 424]
count = 0
d = {} #Empty dictionary to add values into

for i in list:
    d[count] = i
    count+=1
d
# Out:
# {0: 102, 1: 232, 2: 424}

# %%
list = [102, 232, 424]
d = {}

for a, b in enumerate(list):
    d[a] = b

d
# Out:
# {0: 102, 1: 232, 2: 424}

# %%
d = {a:b for a, b in enumerate(list)}
d
# Out:
# {0: 102, 1: 232, 2: 424}

# %%
dict(zip(range(0, len(list)), list))
# Out:
# {0: 102, 1: 232, 2: 424}

# %% [markdown]
# ### LIST ITEMS TO A DICTIONARY

# %%
items = "Whats the simpliest way to add the list items to a dictionary "

stats = {}
for i in items:
    if i in stats:
        stats[i] += 1
        print(stats)
    else:
        stats[i] = 1
        print("\t",stats)

# bonus
# for i in sorted(stats, key=stats.get):
#    print("%d×'%s'" % (stats[i], i))
# Out:
# 	 {'W': 1}
# 	 {'W': 1, 'h': 1}
# 	 {'W': 1, 'h': 1, 'a': 1}
# 	 {'W': 1, 'h': 1, 'a': 1, 't': 1}
# 	 {'W': 1, 'h': 1, 'a': 1, 't': 1, 's': 1}
# 	 {'W': 1, 'h': 1, 'a': 1, 't': 1, 's': 1, ' ': 1}
# {'W': 1, 'h': 1, 'a': 1, 't': 2, 's': 1, ' ': 1}
# {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 1, ' ': 1}
# 	 {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 1, ' ': 1, 'e': 1}
# {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 1, ' ': 2, 'e': 1}
# {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1}
# 	 {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1, 'i': 1}
# 	 {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1, 'i': 1, 'm': 1}
# 	 {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1, 'i': 1, 'm': 1, 'p': 1}
# 	 {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1, 'i': 1, 'm': 1, 'p': 1, 'l': 1}
# {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 1, 'i': 2, 'm': 1, 'p': 1, 'l': 1}
# {'W': 1, 'h': 2, 'a': 1, 't': 2, 's': 2, ' ': 2, 'e': 2, 'i': 2, 'm': 1, 'p': 1, 'l': 1}
# ...

# %%
for i in items:
    print(i)

# %%
i = ['apple','red','apple','red','red','pear']
d = {x:i.count(x) for x in i}
print(d)
# Out:
# {'apple': 2, 'red': 3, 'pear': 1}
