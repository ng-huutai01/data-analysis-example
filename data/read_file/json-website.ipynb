# %% [markdown]
# ModuleNotFoundError: No module named 'requests'
#
# pip install requests.

# %% [markdown]
# To find the last 30 GitHub issues for pandas on GitHub, we can make a GET HTTP request using the add-on requests library:

# %%
import requests
import pandas as pd
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
# The Response object’s json method will return a dictionary containing JSON parsed into native Python objects:
data = resp.json()
data[0]['title']
# Out:
# 'BUG: Expression xxxx has forbidden control characters - caused by new release of numexpr'

# %%
# Each element in data is a dictionary containing all of the data found on a GitHub issue page (except for the comments). We can pass data directly to DataFrame and extract fields of interest:
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    54542  BUG: Expression xxxx has forbidden control cha...
# 1    54541       Bump pypa/cibuildwheel from 2.14.1 to 2.15.0
# 2    54540  BUG: 54445 interferes with EAs that support co...
# 3    54537  REF: Refactor using_pyarrow check for string t...
# 4    54535  REF: Replace "pyarrow" string storage checks w...
# 5    54533  Implement Arrow String Array that is compatibl...
# 6    54532   Fixed DatetimeIndex.tz_convert() .freq attribute
# 7    54531                                 ENH: merge inplace
# 8    54527  wip special-case setting nan into integer seri...
# 9    54526        DOC: Series.count remove mention of "level"
# 10   54525                            BLD: Fix version script
# 11   54523  ENH: initialising `MultiIndex` with a `dtypes`...
# 12   54521  BUG: `assert_frame_equals` fails when `MultiIn...
# 13   54519  BUG: Changing dtype from pandas==2.0.1 to 2.0....
# 14   54518                        BUG: Incorrect rolling std
# 15   54516  ENH: Allow usage of custom library to serializ...
# 16   54511                   REF: implement Dtype.index_class
# 17   54510  Speed up StringDtype arrow implementation for ...
# 18   54508            PERF: DataFrame.iloc[int] for EA dtypes
# 19   54507  Enable assert_almost_equal to test numpy-like ...
# 20   54506                         Bitmask Backed MaskedArray
# 21   54503  Fix scatter_matrix lacking ability to use grid...
# 22   54500  #51826_Fixed bug when np.nan is used as index ...
# 23   54496  Fix inference for fixed with numpy strings wit...
# 24   54495  BUG: Bitwise operators for AND ( & ) and OR( |...
# 25   54494  BUG: TypeError when try to type hint generic t...
# 26   54493            DOC: updated required dependencies list
# 27   54492  DOC: tzdata should be listed as a required dep...
# 28   54491  DEPR: Positional arguments in to_hdf except pa...
# 29   54490                     DOC: Simplify missing_data.rst
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 2                                                  []  open
# 3   [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 4   [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 5                                                  []  open
# 6                                                  []  open
# 7   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 8                                                  []  open
# 9   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 10  [{'id': 129350, 'node_id': 'MDU6TGFiZWwxMjkzNT...  open
# 11  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 12  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 15                                                 []  open
# 16                                                 []  open
# 17  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 18  [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 19                                                 []  open
# 20                                                 []  open
# 21  [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzM...  open
# 22  [{'id': 2822342, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 23  [{'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUy...  open
# 24  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 25  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 26  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 27  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 28  [{'id': 47229190, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 29  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
