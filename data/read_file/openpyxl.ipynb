# %% [markdown]
# https://realpython.com/openpyxl-excel-spreadsheets-python/

# %% [markdown]
# pip install openpyxl

# %% [markdown]
# ### create a super simple spreadsheet

# %%
from openpyxl import Workbook

workbook = Workbook() # create a new empty workbook.
sheet = workbook.active

sheet["A1"] = "hello" # add data to specific cells.
sheet["B1"] = "world!" # add data to specific cells.

workbook.save(filename="openpyxl.xlsx") # save the spreadsheet when you’re done

# %% [markdown]
# ### Reading an Excel Spreadsheet

# %%
from openpyxl import load_workbook
workbook = load_workbook(filename="openpyxl2.xlsx")
workbook.sheetnames # use workbook.sheetnames to see all the sheets you have available to work with
# Out:
# ['Review Details_2019-05-27', 'Sheet3', 'Sheet1', 'Sheet2']

# %%
# workbook.active selects the first available sheet
sheet = workbook.active 
sheet
# Out:
# <Worksheet "Review Details_2019-05-27">

# %%
sheet.title
# Out:
# 'Review Details_2019-05-27'

# %%
sheet["A1"]
# Out:
# <Cell 'Review Details_2019-05-27'.A1>

# %%
sheet["A1"].value
# Out:
# 'report_date'

# %%
sheet["F10"].value
# Out:
# 'Personal Care'

# %% [markdown]
# __You can use the method .cell() to retrieve a cell using index notation. Remember to add .value to get the actual value and not a Cell object:__

# %%
sheet.cell(row=10, column=6)
# Out:
# <Cell 'Review Details_2019-05-27'.F10>

# %%
sheet.cell(row=10, column=6).value
# Out:
# 'Personal Care'

# %% [markdown]
# ### Additional Reading Options

# %% [markdown]
# There are a few arguments you can pass to load_workbook() that change the way a spreadsheet is loaded. The most important ones are the following two Booleans:
#
# __read_only__ loads a spreadsheet in read-only mode allowing you to open very large Excel files.
#
# __data_only__ ignores loading formulas and instead loads only the resulting values.

# %% [markdown]
# ### Importing Data From a Spreadsheet

# %% [markdown]
# #### Iterating Through the Data

# %%
# You can slice the data with a combination of columns and rows:
sheet["A1:C2"]
# Out:
# ((<Cell 'Review Details_2019-05-27'.A1>,
#   <Cell 'Review Details_2019-05-27'.B1>,
#   <Cell 'Review Details_2019-05-27'.C1>),
#  (<Cell 'Review Details_2019-05-27'.A2>,
#   <Cell 'Review Details_2019-05-27'.B2>,
#   <Cell 'Review Details_2019-05-27'.C2>))

# %%
# Get all cells from column A
sheet["A"]
# Out:
# (<Cell 'Review Details_2019-05-27'.A1>,
#  <Cell 'Review Details_2019-05-27'.A2>,
#  <Cell 'Review Details_2019-05-27'.A3>,
#  <Cell 'Review Details_2019-05-27'.A4>,
#  <Cell 'Review Details_2019-05-27'.A5>,
#  <Cell 'Review Details_2019-05-27'.A6>,
#  <Cell 'Review Details_2019-05-27'.A7>,
#  <Cell 'Review Details_2019-05-27'.A8>,
#  <Cell 'Review Details_2019-05-27'.A9>,
#  <Cell 'Review Details_2019-05-27'.A10>,
#  <Cell 'Review Details_2019-05-27'.A11>,
#  <Cell 'Review Details_2019-05-27'.A12>,
#  <Cell 'Review Details_2019-05-27'.A13>,
#  <Cell 'Review Details_2019-05-27'.A14>,
#  <Cell 'Review Details_2019-05-27'.A15>,
#  <Cell 'Review Details_2019-05-27'.A16>,
#  <Cell 'Review Details_2019-05-27'.A17>,
#  <Cell 'Review Details_2019-05-27'.A18>,
#  <Cell 'Review Details_2019-05-27'.A19>,
#  <Cell 'Review Details_2019-05-27'.A20>,
#  <Cell 'Review Details_2019-05-27'.A21>,
#  <Cell 'Review Details_2019-05-27'.A22>,
#  <Cell 'Review Details_2019-05-27'.A23>,
#  <Cell 'Review Details_2019-05-27'.A24>,
#  <Cell 'Review Details_2019-05-27'.A25>,
#  <Cell 'Review Details_2019-05-27'.A26>,
#  <Cell 'Review Details_2019-05-27'.A27>,
#  <Cell 'Review Details_2019-05-27'.A28>,
#  <Cell 'Review Details_2019-05-27'.A29>,
#  <Cell 'Review Details_2019-05-27'.A30>,
#  <Cell 'Review Details_2019-05-27'.A31>,
#  <Cell 'Review Details_2019-05-27'.A32>,
#  <Cell 'Review Details_2019-05-27'.A33>,
#  <Cell 'Review Details_2019-05-27'.A34>,
#  <Cell 'Review Details_2019-05-27'.A35>,
#  <Cell 'Review Details_2019-05-27'.A36>,
#  <Cell 'Review Details_2019-05-27'.A37>,
#  <Cell 'Review Details_2019-05-27'.A38>,
#  <Cell 'Review Details_2019-05-27'.A39>,
#  <Cell 'Review Details_2019-05-27'.A40>,
#  <Cell 'Review Details_2019-05-27'.A41>,
#  <Cell 'Review Details_2019-05-27'.A42>,
#  <Cell 'Review Details_2019-05-27'.A43>,
#  <Cell 'Review Details_2019-05-27'.A44>,
#  <Cell 'Review Details_2019-05-27'.A45>,
#  <Cell 'Review Details_2019-05-27'.A46>,
#  <Cell 'Review Details_2019-05-27'.A47>,
#  <Cell 'Review Details_2019-05-27'.A48>,
#  <Cell 'Review Details_2019-05-27'.A49>,
#  <Cell 'Review Details_2019-05-27'.A50>,
#  <Cell 'Review Details_2019-05-27'.A51>,
#  <Cell 'Review Details_2019-05-27'.A52>,
#  <Cell 'Review Details_2019-05-27'.A53>,
#  <Cell 'Review Details_2019-05-27'.A54>,
#  <Cell 'Review Details_2019-05-27'.A55>,
#  <Cell 'Review Details_2019-05-27'.A56>,
#  <Cell 'Review Details_2019-05-27'.A57>,
#  <Cell 'Review Details_2019-05-27'.A58>,
#  <Cell 'Review Details_2019-05-27'.A59>,
#  <Cell 'Review Details_2019-05-27'.A60>,
#  <Cell 'Review Details_2019-05-27'.A61>,
#  <Cell 'Review Details_2019-05-27'.A62>,
#  <Cell 'Review Details_2019-05-27'.A63>,
#  <Cell 'Review Details_2019-05-27'.A64>,
#  <Cell 'Review Details_2019-05-27'.A65>,
#  <Cell 'Review Details_2019-05-27'.A66>,
#  <Cell 'Review Details_2019-05-27'.A67>,
#  <Cell 'Review Details_2019-05-27'.A68>,
#  <Cell 'Review Details_2019-05-27'.A69>,
#  <Cell 'Review Details_2019-05-27'.A70>,
#  <Cell 'Review Details_2019-05-27'.A71>,
#  <Cell 'Review Details_2019-05-27'.A72>,
#  <Cell 'Review Details_2019-05-27'.A73>,
#  <Cell 'Review Details_2019-05-27'.A74>,
#  <Cell 'Review Details_2019-05-27'.A75>,
#  <Cell 'Review Details_2019-05-27'.A76>,
#  <Cell 'Review Details_2019-05-27'.A77>,
#  <Cell 'Review Details_2019-05-27'.A78>,
#  <Cell 'Review Details_2019-05-27'.A79>,
#  <Cell 'Review Details_2019-05-27'.A80>,
#  <Cell 'Review Details_2019-05-27'.A81>,
#  <Cell 'Review Details_2019-05-27'.A82>,
#  <Cell 'Review Details_2019-05-27'.A83>,
#  <Cell 'Review Details_2019-05-27'.A84>,
#  <Cell 'Review Details_2019-05-27'.A85>,
#  <Cell 'Review Details_2019-05-27'.A86>,
#  <Cell 'Review Details_2019-05-27'.A87>,
#  <Cell 'Review Details_2019-05-27'.A88>,
#  <Cell 'Review Details_2019-05-27'.A89>,
#  <Cell 'Review Details_2019-05-27'.A90>,
#  <Cell 'Review Details_2019-05-27'.A91>,
#  <Cell 'Review Details_2019-05-27'.A92>,
#  <Cell 'Review Details_2019-05-27'.A93>,
#  <Cell 'Review Details_2019-05-27'.A94>,
#  <Cell 'Review Details_2019-05-27'.A95>,
#  <Cell 'Review Details_2019-05-27'.A96>,
#  <Cell 'Review Details_2019-05-27'.A97>,
#  <Cell 'Review Details_2019-05-27'.A98>,
#  <Cell 'Review Details_2019-05-27'.A99>,
#  <Cell 'Review Details_2019-05-27'.A100>,
#  <Cell 'Review Details_2019-05-27'.A101>,
#  <Cell 'Review Details_2019-05-27'.A102>,
#  <Cell 'Review Details_2019-05-27'.A103>,
#  <Cell 'Review Details_2019-05-27'.A104>,
#  <Cell 'Review Details_2019-05-27'.A105>,
#  <Cell 'Review Details_2019-05-27'.A106>,
#  <Cell 'Review Details_2019-05-27'.A107>,
#  <Cell 'Review Details_2019-05-27'.A108>,
#  <Cell 'Review Details_2019-05-27'.A109>,
#  <Cell 'Review Details_2019-05-27'.A110>,
#  <Cell 'Review Details_2019-05-27'.A111>,
#  <Cell 'Review Details_2019-05-27'.A112>,
#  <Cell 'Review Details_2019-05-27'.A113>,
#  <Cell 'Review Details_2019-05-27'.A114>,
#  <Cell 'Review Details_2019-05-27'.A115>,
#  <Cell 'Review Details_2019-05-27'.A116>,
#  <Cell 'Review Details_2019-05-27'.A117>,
#  <Cell 'Review Details_2019-05-27'.A118>,
#  <Cell 'Review Details_2019-05-27'.A119>,
#  <Cell 'Review Details_2019-05-27'.A120>,
#  <Cell 'Review Details_2019-05-27'.A121>,
#  <Cell 'Review Details_2019-05-27'.A122>,
#  <Cell 'Review Details_2019-05-27'.A123>,
#  <Cell 'Review Details_2019-05-27'.A124>,
#  <Cell 'Review Details_2019-05-27'.A125>,
#  <Cell 'Review Details_2019-05-27'.A126>,
#  <Cell 'Review Details_2019-05-27'.A127>,
#  <Cell 'Review Details_2019-05-27'.A128>,
#  <Cell 'Review Details_2019-05-27'.A129>,
#  <Cell 'Review Details_2019-05-27'.A130>,
#  <Cell 'Review Details_2019-05-27'.A131>,
#  <Cell 'Review Details_2019-05-27'.A132>,
#  <Cell 'Review Details_2019-05-27'.A133>,
#  <Cell 'Review Details_2019-05-27'.A134>,
#  <Cell 'Review Details_2019-05-27'.A135>,
#  <Cell 'Review Details_2019-05-27'.A136>,
#  <Cell 'Review Details_2019-05-27'.A137>,
#  <Cell 'Review Details_2019-05-27'.A138>,
#  <Cell 'Review Details_2019-05-27'.A139>,
#  <Cell 'Review Details_2019-05-27'.A140>,
#  <Cell 'Review Details_2019-05-27'.A141>,
#  <Cell 'Review Details_2019-05-27'.A142>,
#  <Cell 'Review Details_2019-05-27'.A143>,
#  <Cell 'Review Details_2019-05-27'.A144>,
#  <Cell 'Review Details_2019-05-27'.A145>,
#  <Cell 'Review Details_2019-05-27'.A146>,
#  <Cell 'Review Details_2019-05-27'.A147>,
#  <Cell 'Review Details_2019-05-27'.A148>,
#  <Cell 'Review Details_2019-05-27'.A149>,
#  <Cell 'Review Details_2019-05-27'.A150>,
#  <Cell 'Review Details_2019-05-27'.A151>,
#  <Cell 'Review Details_2019-05-27'.A152>,
#  <Cell 'Review Details_2019-05-27'.A153>,
#  <Cell 'Review Details_2019-05-27'.A154>,
#  <Cell 'Review Details_2019-05-27'.A155>,
#  <Cell 'Review Details_2019-05-27'.A156>,
#  <Cell 'Review Details_2019-05-27'.A157>,
#  <Cell 'Review Details_2019-05-27'.A158>,
#  <Cell 'Review Details_2019-05-27'.A159>,
#  <Cell 'Review Details_2019-05-27'.A160>,
#  <Cell 'Review Details_2019-05-27'.A161>,
#  <Cell 'Review Details_2019-05-27'.A162>,
#  <Cell 'Review Details_2019-05-27'.A163>,
#  <Cell 'Review Details_2019-05-27'.A164>,
#  <Cell 'Review Details_2019-05-27'.A165>,
#  <Cell 'Review Details_2019-05-27'.A166>,
#  <Cell 'Review Details_2019-05-27'.A167>,
#  <Cell 'Review Details_2019-05-27'.A168>,
#  <Cell 'Review Details_2019-05-27'.A169>,
#  <Cell 'Review Details_2019-05-27'.A170>,
#  <Cell 'Review Details_2019-05-27'.A171>,
#  <Cell 'Review Details_2019-05-27'.A172>,
#  <Cell 'Review Details_2019-05-27'.A173>,
#  <Cell 'Review Details_2019-05-27'.A174>,
#  <Cell 'Review Details_2019-05-27'.A175>,
#  <Cell 'Review Details_2019-05-27'.A176>,
#  <Cell 'Review Details_2019-05-27'.A177>,
#  <Cell 'Review Details_2019-05-27'.A178>,
#  <Cell 'Review Details_2019-05-27'.A179>,
#  <Cell 'Review Details_2019-05-27'.A180>,
#  <Cell 'Review Details_2019-05-27'.A181>,
#  <Cell 'Review Details_2019-05-27'.A182>,
#  <Cell 'Review Details_2019-05-27'.A183>,
#  <Cell 'Review Details_2019-05-27'.A184>,
#  <Cell 'Review Details_2019-05-27'.A185>,
#  <Cell 'Review Details_2019-05-27'.A186>,
#  <Cell 'Review Details_2019-05-27'.A187>,
#  <Cell 'Review Details_2019-05-27'.A188>,
#  <Cell 'Review Details_2019-05-27'.A189>,
#  <Cell 'Review Details_2019-05-27'.A190>,
#  <Cell 'Review Details_2019-05-27'.A191>,
#  <Cell 'Review Details_2019-05-27'.A192>,
#  <Cell 'Review Details_2019-05-27'.A193>,
#  <Cell 'Review Details_2019-05-27'.A194>,
#  <Cell 'Review Details_2019-05-27'.A195>,
#  <Cell 'Review Details_2019-05-27'.A196>,
#  <Cell 'Review Details_2019-05-27'.A197>,
#  <Cell 'Review Details_2019-05-27'.A198>,
#  <Cell 'Review Details_2019-05-27'.A199>,
#  <Cell 'Review Details_2019-05-27'.A200>,
#  <Cell 'Review Details_2019-05-27'.A201>,
#  <Cell 'Review Details_2019-05-27'.A202>,
#  <Cell 'Review Details_2019-05-27'.A203>,
#  <Cell 'Review Details_2019-05-27'.A204>,
#  <Cell 'Review Details_2019-05-27'.A205>,
#  <Cell 'Review Details_2019-05-27'.A206>,
#  <Cell 'Review Details_2019-05-27'.A207>,
#  <Cell 'Review Details_2019-05-27'.A208>,
#  <Cell 'Review Details_2019-05-27'.A209>,
#  <Cell 'Review Details_2019-05-27'.A210>,
#  <Cell 'Review Details_2019-05-27'.A211>,
#  <Cell 'Review Details_2019-05-27'.A212>,
#  <Cell 'Review Details_2019-05-27'.A213>,
#  <Cell 'Review Details_2019-05-27'.A214>,
#  <Cell 'Review Details_2019-05-27'.A215>,
#  <Cell 'Review Details_2019-05-27'.A216>,
#  <Cell 'Review Details_2019-05-27'.A217>,
#  <Cell 'Review Details_2019-05-27'.A218>,
#  <Cell 'Review Details_2019-05-27'.A219>,
#  <Cell 'Review Details_2019-05-27'.A220>,
#  <Cell 'Review Details_2019-05-27'.A221>,
#  <Cell 'Review Details_2019-05-27'.A222>,
#  <Cell 'Review Details_2019-05-27'.A223>,
#  <Cell 'Review Details_2019-05-27'.A224>,
#  <Cell 'Review Details_2019-05-27'.A225>,
#  <Cell 'Review Details_2019-05-27'.A226>,
#  <Cell 'Review Details_2019-05-27'.A227>,
#  <Cell 'Review Details_2019-05-27'.A228>,
#  <Cell 'Review Details_2019-05-27'.A229>,
#  <Cell 'Review Details_2019-05-27'.A230>,
#  <Cell 'Review Details_2019-05-27'.A231>,
#  <Cell 'Review Details_2019-05-27'.A232>,
#  <Cell 'Review Details_2019-05-27'.A233>,
#  <Cell 'Review Details_2019-05-27'.A234>,
#  <Cell 'Review Details_2019-05-27'.A235>,
#  <Cell 'Review Details_2019-05-27'.A236>,
#  <Cell 'Review Details_2019-05-27'.A237>,
#  <Cell 'Review Details_2019-05-27'.A238>,
#  <Cell 'Review Details_2019-05-27'.A239>,
#  <Cell 'Review Details_2019-05-27'.A240>,
#  <Cell 'Review Details_2019-05-27'.A241>,
#  <Cell 'Review Details_2019-05-27'.A242>,
#  <Cell 'Review Details_2019-05-27'.A243>,
#  <Cell 'Review Details_2019-05-27'.A244>,
#  <Cell 'Review Details_2019-05-27'.A245>,
#  <Cell 'Review Details_2019-05-27'.A246>,
#  <Cell 'Review Details_2019-05-27'.A247>,
#  <Cell 'Review Details_2019-05-27'.A248>,
#  <Cell 'Review Details_2019-05-27'.A249>,
#  <Cell 'Review Details_2019-05-27'.A250>,
#  <Cell 'Review Details_2019-05-27'.A251>,
#  <Cell 'Review Details_2019-05-27'.A252>,
#  <Cell 'Review Details_2019-05-27'.A253>,
#  <Cell 'Review Details_2019-05-27'.A254>,
#  <Cell 'Review Details_2019-05-27'.A255>,
#  <Cell 'Review Details_2019-05-27'.A256>,
#  <Cell 'Review Details_2019-05-27'.A257>,
#  <Cell 'Review Details_2019-05-27'.A258>,
#  <Cell 'Review Details_2019-05-27'.A259>,
#  <Cell 'Review Details_2019-05-27'.A260>,
#  <Cell 'Review Details_2019-05-27'.A261>,
#  <Cell 'Review Details_2019-05-27'.A262>,
#  <Cell 'Review Details_2019-05-27'.A263>,
#  <Cell 'Review Details_2019-05-27'.A264>,
#  <Cell 'Review Details_2019-05-27'.A265>,
#  <Cell 'Review Details_2019-05-27'.A266>,
#  <Cell 'Review Details_2019-05-27'.A267>,
#  <Cell 'Review Details_2019-05-27'.A268>,
#  <Cell 'Review Details_2019-05-27'.A269>,
#  <Cell 'Review Details_2019-05-27'.A270>,
#  <Cell 'Review Details_2019-05-27'.A271>,
#  <Cell 'Review Details_2019-05-27'.A272>,
#  <Cell 'Review Details_2019-05-27'.A273>,
#  <Cell 'Review Details_2019-05-27'.A274>,
#  <Cell 'Review Details_2019-05-27'.A275>,
#  <Cell 'Review Details_2019-05-27'.A276>,
#  <Cell 'Review Details_2019-05-27'.A277>,
#  <Cell 'Review Details_2019-05-27'.A278>,
#  <Cell 'Review Details_2019-05-27'.A279>,
#  <Cell 'Review Details_2019-05-27'.A280>,
#  <Cell 'Review Details_2019-05-27'.A281>,
#  <Cell 'Review Details_2019-05-27'.A282>,
#  <Cell 'Review Details_2019-05-27'.A283>,
#  <Cell 'Review Details_2019-05-27'.A284>,
#  <Cell 'Review Details_2019-05-27'.A285>,
#  <Cell 'Review Details_2019-05-27'.A286>,
#  <Cell 'Review Details_2019-05-27'.A287>,
#  <Cell 'Review Details_2019-05-27'.A288>,
#  <Cell 'Review Details_2019-05-27'.A289>,
#  <Cell 'Review Details_2019-05-27'.A290>,
#  <Cell 'Review Details_2019-05-27'.A291>,
#  <Cell 'Review Details_2019-05-27'.A292>,
#  <Cell 'Review Details_2019-05-27'.A293>,
#  <Cell 'Review Details_2019-05-27'.A294>,
#  <Cell 'Review Details_2019-05-27'.A295>,
#  <Cell 'Review Details_2019-05-27'.A296>,
#  <Cell 'Review Details_2019-05-27'.A297>,
#  <Cell 'Review Details_2019-05-27'.A298>,
#  <Cell 'Review Details_2019-05-27'.A299>,
#  <Cell 'Review Details_2019-05-27'.A300>,
#  <Cell 'Review Details_2019-05-27'.A301>,
#  <Cell 'Review Details_2019-05-27'.A302>,
#  <Cell 'Review Details_2019-05-27'.A303>,
#  <Cell 'Review Details_2019-05-27'.A304>,
#  <Cell 'Review Details_2019-05-27'.A305>,
#  <Cell 'Review Details_2019-05-27'.A306>,
#  <Cell 'Review Details_2019-05-27'.A307>,
#  <Cell 'Review Details_2019-05-27'.A308>,
#  <Cell 'Review Details_2019-05-27'.A309>,
#  <Cell 'Review Details_2019-05-27'.A310>,
#  <Cell 'Review Details_2019-05-27'.A311>,
#  <Cell 'Review Details_2019-05-27'.A312>,
#  <Cell 'Review Details_2019-05-27'.A313>,
#  <Cell 'Review Details_2019-05-27'.A314>,
#  <Cell 'Review Details_2019-05-27'.A315>,
#  <Cell 'Review Details_2019-05-27'.A316>,
#  <Cell 'Review Details_2019-05-27'.A317>,
#  <Cell 'Review Details_2019-05-27'.A318>,
#  <Cell 'Review Details_2019-05-27'.A319>,
#  <Cell 'Review Details_2019-05-27'.A320>,
#  <Cell 'Review Details_2019-05-27'.A321>,
#  <Cell 'Review Details_2019-05-27'.A322>,
#  <Cell 'Review Details_2019-05-27'.A323>,
#  <Cell 'Review Details_2019-05-27'.A324>,
#  <Cell 'Review Details_2019-05-27'.A325>,
#  <Cell 'Review Details_2019-05-27'.A326>,
#  <Cell 'Review Details_2019-05-27'.A327>,
#  <Cell 'Review Details_2019-05-27'.A328>,
#  <Cell 'Review Details_2019-05-27'.A329>,
#  <Cell 'Review Details_2019-05-27'.A330>,
#  <Cell 'Review Details_2019-05-27'.A331>,
#  <Cell 'Review Details_2019-05-27'.A332>,
#  <Cell 'Review Details_2019-05-27'.A333>,
#  <Cell 'Review Details_2019-05-27'.A334>,
#  <Cell 'Review Details_2019-05-27'.A335>,
#  <Cell 'Review Details_2019-05-27'.A336>,
#  <Cell 'Review Details_2019-05-27'.A337>,
#  <Cell 'Review Details_2019-05-27'.A338>,
#  <Cell 'Review Details_2019-05-27'.A339>,
#  <Cell 'Review Details_2019-05-27'.A340>,
#  <Cell 'Review Details_2019-05-27'.A341>,
#  <Cell 'Review Details_2019-05-27'.A342>,
#  <Cell 'Review Details_2019-05-27'.A343>,
#  <Cell 'Review Details_2019-05-27'.A344>,
#  <Cell 'Review Details_2019-05-27'.A345>,
#  <Cell 'Review Details_2019-05-27'.A346>,
#  <Cell 'Review Details_2019-05-27'.A347>,
#  <Cell 'Review Details_2019-05-27'.A348>,
#  <Cell 'Review Details_2019-05-27'.A349>,
#  <Cell 'Review Details_2019-05-27'.A350>,
#  <Cell 'Review Details_2019-05-27'.A351>,
#  <Cell 'Review Details_2019-05-27'.A352>,
#  <Cell 'Review Details_2019-05-27'.A353>,
#  <Cell 'Review Details_2019-05-27'.A354>,
#  <Cell 'Review Details_2019-05-27'.A355>,
#  <Cell 'Review Details_2019-05-27'.A356>,
#  <Cell 'Review Details_2019-05-27'.A357>,
#  <Cell 'Review Details_2019-05-27'.A358>,
#  <Cell 'Review Details_2019-05-27'.A359>,
#  <Cell 'Review Details_2019-05-27'.A360>,
#  <Cell 'Review Details_2019-05-27'.A361>,
#  <Cell 'Review Details_2019-05-27'.A362>,
#  <Cell 'Review Details_2019-05-27'.A363>,
#  <Cell 'Review Details_2019-05-27'.A364>,
#  <Cell 'Review Details_2019-05-27'.A365>,
#  <Cell 'Review Details_2019-05-27'.A366>,
#  <Cell 'Review Details_2019-05-27'.A367>,
#  <Cell 'Review Details_2019-05-27'.A368>,
#  <Cell 'Review Details_2019-05-27'.A369>,
#  <Cell 'Review Details_2019-05-27'.A370>,
#  <Cell 'Review Details_2019-05-27'.A371>,
#  <Cell 'Review Details_2019-05-27'.A372>,
#  <Cell 'Review Details_2019-05-27'.A373>,
#  <Cell 'Review Details_2019-05-27'.A374>,
#  <Cell 'Review Details_2019-05-27'.A375>,
#  <Cell 'Review Details_2019-05-27'.A376>,
#  <Cell 'Review Details_2019-05-27'.A377>,
#  <Cell 'Review Details_2019-05-27'.A378>,
#  <Cell 'Review Details_2019-05-27'.A379>,
#  <Cell 'Review Details_2019-05-27'.A380>,
#  <Cell 'Review Details_2019-05-27'.A381>,
#  <Cell 'Review Details_2019-05-27'.A382>,
#  <Cell 'Review Details_2019-05-27'.A383>,
#  <Cell 'Review Details_2019-05-27'.A384>,
#  <Cell 'Review Details_2019-05-27'.A385>,
#  <Cell 'Review Details_2019-05-27'.A386>,
#  <Cell 'Review Details_2019-05-27'.A387>,
#  <Cell 'Review Details_2019-05-27'.A388>,
#  <Cell 'Review Details_2019-05-27'.A389>,
#  <Cell 'Review Details_2019-05-27'.A390>,
#  <Cell 'Review Details_2019-05-27'.A391>,
#  <Cell 'Review Details_2019-05-27'.A392>,
#  <Cell 'Review Details_2019-05-27'.A393>,
#  <Cell 'Review Details_2019-05-27'.A394>,
#  <Cell 'Review Details_2019-05-27'.A395>,
#  <Cell 'Review Details_2019-05-27'.A396>,
#  <Cell 'Review Details_2019-05-27'.A397>,
#  <Cell 'Review Details_2019-05-27'.A398>,
#  <Cell 'Review Details_2019-05-27'.A399>,
#  <Cell 'Review Details_2019-05-27'.A400>,
#  <Cell 'Review Details_2019-05-27'.A401>,
#  <Cell 'Review Details_2019-05-27'.A402>,
#  <Cell 'Review Details_2019-05-27'.A403>,
#  <Cell 'Review Details_2019-05-27'.A404>,
#  <Cell 'Review Details_2019-05-27'.A405>,
#  <Cell 'Review Details_2019-05-27'.A406>,
#  <Cell 'Review Details_2019-05-27'.A407>,
#  <Cell 'Review Details_2019-05-27'.A408>,
#  <Cell 'Review Details_2019-05-27'.A409>,
#  <Cell 'Review Details_2019-05-27'.A410>,
#  <Cell 'Review Details_2019-05-27'.A411>,
#  <Cell 'Review Details_2019-05-27'.A412>,
#  <Cell 'Review Details_2019-05-27'.A413>,
#  <Cell 'Review Details_2019-05-27'.A414>,
#  <Cell 'Review Details_2019-05-27'.A415>,
#  <Cell 'Review Details_2019-05-27'.A416>,
#  <Cell 'Review Details_2019-05-27'.A417>,
#  <Cell 'Review Details_2019-05-27'.A418>,
#  <Cell 'Review Details_2019-05-27'.A419>,
#  <Cell 'Review Details_2019-05-27'.A420>,
#  <Cell 'Review Details_2019-05-27'.A421>,
#  <Cell 'Review Details_2019-05-27'.A422>,
#  <Cell 'Review Details_2019-05-27'.A423>,
#  <Cell 'Review Details_2019-05-27'.A424>,
#  <Cell 'Review Details_2019-05-27'.A425>,
#  <Cell 'Review Details_2019-05-27'.A426>,
#  <Cell 'Review Details_2019-05-27'.A427>,
#  <Cell 'Review Details_2019-05-27'.A428>,
#  <Cell 'Review Details_2019-05-27'.A429>,
#  <Cell 'Review Details_2019-05-27'.A430>,
#  <Cell 'Review Details_2019-05-27'.A431>,
#  <Cell 'Review Details_2019-05-27'.A432>,
#  <Cell 'Review Details_2019-05-27'.A433>,
#  <Cell 'Review Details_2019-05-27'.A434>,
#  <Cell 'Review Details_2019-05-27'.A435>,
#  <Cell 'Review Details_2019-05-27'.A436>,
#  <Cell 'Review Details_2019-05-27'.A437>,
#  <Cell 'Review Details_2019-05-27'.A438>,
#  <Cell 'Review Details_2019-05-27'.A439>,
#  <Cell 'Review Details_2019-05-27'.A440>,
#  <Cell 'Review Details_2019-05-27'.A441>,
#  <Cell 'Review Details_2019-05-27'.A442>,
#  <Cell 'Review Details_2019-05-27'.A443>,
#  <Cell 'Review Details_2019-05-27'.A444>,
#  <Cell 'Review Details_2019-05-27'.A445>,
#  <Cell 'Review Details_2019-05-27'.A446>,
#  <Cell 'Review Details_2019-05-27'.A447>,
#  <Cell 'Review Details_2019-05-27'.A448>,
#  <Cell 'Review Details_2019-05-27'.A449>,
#  <Cell 'Review Details_2019-05-27'.A450>,
#  <Cell 'Review Details_2019-05-27'.A451>,
#  <Cell 'Review Details_2019-05-27'.A452>,
#  <Cell 'Review Details_2019-05-27'.A453>,
#  <Cell 'Review Details_2019-05-27'.A454>,
#  <Cell 'Review Details_2019-05-27'.A455>,
#  <Cell 'Review Details_2019-05-27'.A456>,
#  <Cell 'Review Details_2019-05-27'.A457>,
#  <Cell 'Review Details_2019-05-27'.A458>,
#  <Cell 'Review Details_2019-05-27'.A459>,
#  <Cell 'Review Details_2019-05-27'.A460>,
#  <Cell 'Review Details_2019-05-27'.A461>,
#  <Cell 'Review Details_2019-05-27'.A462>,
#  <Cell 'Review Details_2019-05-27'.A463>,
#  <Cell 'Review Details_2019-05-27'.A464>,
#  <Cell 'Review Details_2019-05-27'.A465>,
#  <Cell 'Review Details_2019-05-27'.A466>,
#  <Cell 'Review Details_2019-05-27'.A467>,
#  <Cell 'Review Details_2019-05-27'.A468>,
#  <Cell 'Review Details_2019-05-27'.A469>,
#  <Cell 'Review Details_2019-05-27'.A470>,
#  <Cell 'Review Details_2019-05-27'.A471>,
#  <Cell 'Review Details_2019-05-27'.A472>,
#  <Cell 'Review Details_2019-05-27'.A473>,
#  <Cell 'Review Details_2019-05-27'.A474>,
#  <Cell 'Review Details_2019-05-27'.A475>,
#  <Cell 'Review Details_2019-05-27'.A476>,
#  <Cell 'Review Details_2019-05-27'.A477>,
#  <Cell 'Review Details_2019-05-27'.A478>,
#  <Cell 'Review Details_2019-05-27'.A479>,
#  <Cell 'Review Details_2019-05-27'.A480>,
#  <Cell 'Review Details_2019-05-27'.A481>,
#  <Cell 'Review Details_2019-05-27'.A482>,
#  <Cell 'Review Details_2019-05-27'.A483>,
#  <Cell 'Review Details_2019-05-27'.A484>,
#  <Cell 'Review Details_2019-05-27'.A485>,
#  <Cell 'Review Details_2019-05-27'.A486>,
#  <Cell 'Review Details_2019-05-27'.A487>,
#  <Cell 'Review Details_2019-05-27'.A488>,
#  <Cell 'Review Details_2019-05-27'.A489>,
#  <Cell 'Review Details_2019-05-27'.A490>,
#  <Cell 'Review Details_2019-05-27'.A491>,
#  <Cell 'Review Details_2019-05-27'.A492>,
#  <Cell 'Review Details_2019-05-27'.A493>,
#  <Cell 'Review Details_2019-05-27'.A494>,
#  <Cell 'Review Details_2019-05-27'.A495>,
#  <Cell 'Review Details_2019-05-27'.A496>,
#  <Cell 'Review Details_2019-05-27'.A497>,
#  <Cell 'Review Details_2019-05-27'.A498>,
#  <Cell 'Review Details_2019-05-27'.A499>,
#  <Cell 'Review Details_2019-05-27'.A500>,
#  <Cell 'Review Details_2019-05-27'.A501>,
#  <Cell 'Review Details_2019-05-27'.A502>,
#  <Cell 'Review Details_2019-05-27'.A503>,
#  <Cell 'Review Details_2019-05-27'.A504>,
#  <Cell 'Review Details_2019-05-27'.A505>,
#  <Cell 'Review Details_2019-05-27'.A506>,
#  <Cell 'Review Details_2019-05-27'.A507>,
#  <Cell 'Review Details_2019-05-27'.A508>,
#  <Cell 'Review Details_2019-05-27'.A509>,
#  <Cell 'Review Details_2019-05-27'.A510>,
#  <Cell 'Review Details_2019-05-27'.A511>,
#  <Cell 'Review Details_2019-05-27'.A512>,
#  <Cell 'Review Details_2019-05-27'.A513>,
#  <Cell 'Review Details_2019-05-27'.A514>,
#  <Cell 'Review Details_2019-05-27'.A515>,
#  <Cell 'Review Details_2019-05-27'.A516>,
#  <Cell 'Review Details_2019-05-27'.A517>,
#  <Cell 'Review Details_2019-05-27'.A518>,
#  <Cell 'Review Details_2019-05-27'.A519>,
#  <Cell 'Review Details_2019-05-27'.A520>,
#  <Cell 'Review Details_2019-05-27'.A521>,
#  <Cell 'Review Details_2019-05-27'.A522>,
#  <Cell 'Review Details_2019-05-27'.A523>,
#  <Cell 'Review Details_2019-05-27'.A524>,
#  <Cell 'Review Details_2019-05-27'.A525>,
#  <Cell 'Review Details_2019-05-27'.A526>,
#  <Cell 'Review Details_2019-05-27'.A527>,
#  <Cell 'Review Details_2019-05-27'.A528>,
#  <Cell 'Review Details_2019-05-27'.A529>,
#  <Cell 'Review Details_2019-05-27'.A530>,
#  <Cell 'Review Details_2019-05-27'.A531>,
#  <Cell 'Review Details_2019-05-27'.A532>,
#  <Cell 'Review Details_2019-05-27'.A533>,
#  <Cell 'Review Details_2019-05-27'.A534>,
#  <Cell 'Review Details_2019-05-27'.A535>,
#  <Cell 'Review Details_2019-05-27'.A536>,
#  <Cell 'Review Details_2019-05-27'.A537>,
#  <Cell 'Review Details_2019-05-27'.A538>,
#  <Cell 'Review Details_2019-05-27'.A539>,
#  <Cell 'Review Details_2019-05-27'.A540>,
#  <Cell 'Review Details_2019-05-27'.A541>,
#  <Cell 'Review Details_2019-05-27'.A542>,
#  <Cell 'Review Details_2019-05-27'.A543>,
#  <Cell 'Review Details_2019-05-27'.A544>,
#  <Cell 'Review Details_2019-05-27'.A545>,
#  <Cell 'Review Details_2019-05-27'.A546>,
#  <Cell 'Review Details_2019-05-27'.A547>,
#  <Cell 'Review Details_2019-05-27'.A548>,
#  <Cell 'Review Details_2019-05-27'.A549>,
#  <Cell 'Review Details_2019-05-27'.A550>,
#  <Cell 'Review Details_2019-05-27'.A551>,
#  <Cell 'Review Details_2019-05-27'.A552>,
#  <Cell 'Review Details_2019-05-27'.A553>,
#  <Cell 'Review Details_2019-05-27'.A554>,
#  <Cell 'Review Details_2019-05-27'.A555>,
#  <Cell 'Review Details_2019-05-27'.A556>,
#  <Cell 'Review Details_2019-05-27'.A557>,
#  <Cell 'Review Details_2019-05-27'.A558>,
#  <Cell 'Review Details_2019-05-27'.A559>,
#  <Cell 'Review Details_2019-05-27'.A560>,
#  <Cell 'Review Details_2019-05-27'.A561>,
#  <Cell 'Review Details_2019-05-27'.A562>,
#  <Cell 'Review Details_2019-05-27'.A563>,
#  <Cell 'Review Details_2019-05-27'.A564>,
#  <Cell 'Review Details_2019-05-27'.A565>,
#  <Cell 'Review Details_2019-05-27'.A566>,
#  <Cell 'Review Details_2019-05-27'.A567>,
#  <Cell 'Review Details_2019-05-27'.A568>,
#  <Cell 'Review Details_2019-05-27'.A569>,
#  <Cell 'Review Details_2019-05-27'.A570>,
#  <Cell 'Review Details_2019-05-27'.A571>,
#  <Cell 'Review Details_2019-05-27'.A572>,
#  <Cell 'Review Details_2019-05-27'.A573>,
#  <Cell 'Review Details_2019-05-27'.A574>,
#  <Cell 'Review Details_2019-05-27'.A575>,
#  <Cell 'Review Details_2019-05-27'.A576>,
#  <Cell 'Review Details_2019-05-27'.A577>,
#  <Cell 'Review Details_2019-05-27'.A578>,
#  <Cell 'Review Details_2019-05-27'.A579>,
#  <Cell 'Review Details_2019-05-27'.A580>,
#  <Cell 'Review Details_2019-05-27'.A581>,
#  <Cell 'Review Details_2019-05-27'.A582>,
#  <Cell 'Review Details_2019-05-27'.A583>,
#  <Cell 'Review Details_2019-05-27'.A584>,
#  <Cell 'Review Details_2019-05-27'.A585>,
#  <Cell 'Review Details_2019-05-27'.A586>,
#  <Cell 'Review Details_2019-05-27'.A587>,
#  <Cell 'Review Details_2019-05-27'.A588>,
#  <Cell 'Review Details_2019-05-27'.A589>,
#  <Cell 'Review Details_2019-05-27'.A590>,
#  <Cell 'Review Details_2019-05-27'.A591>,
#  <Cell 'Review Details_2019-05-27'.A592>,
#  <Cell 'Review Details_2019-05-27'.A593>,
#  <Cell 'Review Details_2019-05-27'.A594>,
#  <Cell 'Review Details_2019-05-27'.A595>,
#  <Cell 'Review Details_2019-05-27'.A596>,
#  <Cell 'Review Details_2019-05-27'.A597>,
#  <Cell 'Review Details_2019-05-27'.A598>,
#  <Cell 'Review Details_2019-05-27'.A599>,
#  <Cell 'Review Details_2019-05-27'.A600>,
#  <Cell 'Review Details_2019-05-27'.A601>,
#  <Cell 'Review Details_2019-05-27'.A602>,
#  <Cell 'Review Details_2019-05-27'.A603>,
#  <Cell 'Review Details_2019-05-27'.A604>,
#  <Cell 'Review Details_2019-05-27'.A605>,
#  <Cell 'Review Details_2019-05-27'.A606>,
#  <Cell 'Review Details_2019-05-27'.A607>,
#  <Cell 'Review Details_2019-05-27'.A608>,
#  <Cell 'Review Details_2019-05-27'.A609>,
#  <Cell 'Review Details_2019-05-27'.A610>,
#  <Cell 'Review Details_2019-05-27'.A611>,
#  <Cell 'Review Details_2019-05-27'.A612>,
#  <Cell 'Review Details_2019-05-27'.A613>,
#  <Cell 'Review Details_2019-05-27'.A614>,
#  <Cell 'Review Details_2019-05-27'.A615>,
#  <Cell 'Review Details_2019-05-27'.A616>,
#  <Cell 'Review Details_2019-05-27'.A617>,
#  <Cell 'Review Details_2019-05-27'.A618>,
#  <Cell 'Review Details_2019-05-27'.A619>,
#  <Cell 'Review Details_2019-05-27'.A620>,
#  <Cell 'Review Details_2019-05-27'.A621>,
#  <Cell 'Review Details_2019-05-27'.A622>,
#  <Cell 'Review Details_2019-05-27'.A623>,
#  <Cell 'Review Details_2019-05-27'.A624>,
#  <Cell 'Review Details_2019-05-27'.A625>,
#  <Cell 'Review Details_2019-05-27'.A626>,
#  <Cell 'Review Details_2019-05-27'.A627>,
#  <Cell 'Review Details_2019-05-27'.A628>,
#  <Cell 'Review Details_2019-05-27'.A629>,
#  <Cell 'Review Details_2019-05-27'.A630>,
#  <Cell 'Review Details_2019-05-27'.A631>,
#  <Cell 'Review Details_2019-05-27'.A632>,
#  <Cell 'Review Details_2019-05-27'.A633>,
#  <Cell 'Review Details_2019-05-27'.A634>,
#  <Cell 'Review Details_2019-05-27'.A635>,
#  <Cell 'Review Details_2019-05-27'.A636>,
#  <Cell 'Review Details_2019-05-27'.A637>,
#  <Cell 'Review Details_2019-05-27'.A638>,
#  <Cell 'Review Details_2019-05-27'.A639>,
#  <Cell 'Review Details_2019-05-27'.A640>,
#  <Cell 'Review Details_2019-05-27'.A641>,
#  <Cell 'Review Details_2019-05-27'.A642>,
#  <Cell 'Review Details_2019-05-27'.A643>,
#  <Cell 'Review Details_2019-05-27'.A644>,
#  <Cell 'Review Details_2019-05-27'.A645>,
#  <Cell 'Review Details_2019-05-27'.A646>,
#  <Cell 'Review Details_2019-05-27'.A647>,
#  <Cell 'Review Details_2019-05-27'.A648>,
#  <Cell 'Review Details_2019-05-27'.A649>,
#  <Cell 'Review Details_2019-05-27'.A650>,
#  <Cell 'Review Details_2019-05-27'.A651>,
#  <Cell 'Review Details_2019-05-27'.A652>,
#  <Cell 'Review Details_2019-05-27'.A653>,
#  <Cell 'Review Details_2019-05-27'.A654>,
#  <Cell 'Review Details_2019-05-27'.A655>,
#  <Cell 'Review Details_2019-05-27'.A656>,
#  <Cell 'Review Details_2019-05-27'.A657>,
#  <Cell 'Review Details_2019-05-27'.A658>,
#  <Cell 'Review Details_2019-05-27'.A659>,
#  <Cell 'Review Details_2019-05-27'.A660>,
#  <Cell 'Review Details_2019-05-27'.A661>,
#  <Cell 'Review Details_2019-05-27'.A662>,
#  <Cell 'Review Details_2019-05-27'.A663>,
#  <Cell 'Review Details_2019-05-27'.A664>,
#  <Cell 'Review Details_2019-05-27'.A665>,
#  <Cell 'Review Details_2019-05-27'.A666>,
#  <Cell 'Review Details_2019-05-27'.A667>,
#  <Cell 'Review Details_2019-05-27'.A668>,
#  <Cell 'Review Details_2019-05-27'.A669>,
#  <Cell 'Review Details_2019-05-27'.A670>,
#  <Cell 'Review Details_2019-05-27'.A671>,
#  <Cell 'Review Details_2019-05-27'.A672>,
#  <Cell 'Review Details_2019-05-27'.A673>,
#  <Cell 'Review Details_2019-05-27'.A674>,
#  <Cell 'Review Details_2019-05-27'.A675>,
#  <Cell 'Review Details_2019-05-27'.A676>,
#  <Cell 'Review Details_2019-05-27'.A677>,
#  <Cell 'Review Details_2019-05-27'.A678>,
#  <Cell 'Review Details_2019-05-27'.A679>,
#  <Cell 'Review Details_2019-05-27'.A680>,
#  <Cell 'Review Details_2019-05-27'.A681>,
#  <Cell 'Review Details_2019-05-27'.A682>,
#  <Cell 'Review Details_2019-05-27'.A683>,
#  <Cell 'Review Details_2019-05-27'.A684>,
#  <Cell 'Review Details_2019-05-27'.A685>,
#  <Cell 'Review Details_2019-05-27'.A686>,
#  <Cell 'Review Details_2019-05-27'.A687>,
#  <Cell 'Review Details_2019-05-27'.A688>,
#  <Cell 'Review Details_2019-05-27'.A689>,
#  <Cell 'Review Details_2019-05-27'.A690>,
#  <Cell 'Review Details_2019-05-27'.A691>,
#  <Cell 'Review Details_2019-05-27'.A692>,
#  <Cell 'Review Details_2019-05-27'.A693>,
#  <Cell 'Review Details_2019-05-27'.A694>,
#  <Cell 'Review Details_2019-05-27'.A695>,
#  <Cell 'Review Details_2019-05-27'.A696>,
#  <Cell 'Review Details_2019-05-27'.A697>,
#  <Cell 'Review Details_2019-05-27'.A698>,
#  <Cell 'Review Details_2019-05-27'.A699>,
#  <Cell 'Review Details_2019-05-27'.A700>,
#  <Cell 'Review Details_2019-05-27'.A701>,
#  <Cell 'Review Details_2019-05-27'.A702>,
#  <Cell 'Review Details_2019-05-27'.A703>,
#  <Cell 'Review Details_2019-05-27'.A704>,
#  <Cell 'Review Details_2019-05-27'.A705>,
#  <Cell 'Review Details_2019-05-27'.A706>,
#  <Cell 'Review Details_2019-05-27'.A707>,
#  <Cell 'Review Details_2019-05-27'.A708>,
#  <Cell 'Review Details_2019-05-27'.A709>,
#  <Cell 'Review Details_2019-05-27'.A710>,
#  <Cell 'Review Details_2019-05-27'.A711>,
#  <Cell 'Review Details_2019-05-27'.A712>,
#  <Cell 'Review Details_2019-05-27'.A713>,
#  <Cell 'Review Details_2019-05-27'.A714>,
#  <Cell 'Review Details_2019-05-27'.A715>,
#  <Cell 'Review Details_2019-05-27'.A716>,
#  <Cell 'Review Details_2019-05-27'.A717>,
#  <Cell 'Review Details_2019-05-27'.A718>,
#  <Cell 'Review Details_2019-05-27'.A719>,
#  <Cell 'Review Details_2019-05-27'.A720>,
#  <Cell 'Review Details_2019-05-27'.A721>,
#  <Cell 'Review Details_2019-05-27'.A722>,
#  <Cell 'Review Details_2019-05-27'.A723>,
#  <Cell 'Review Details_2019-05-27'.A724>,
#  <Cell 'Review Details_2019-05-27'.A725>,
#  <Cell 'Review Details_2019-05-27'.A726>,
#  <Cell 'Review Details_2019-05-27'.A727>,
#  <Cell 'Review Details_2019-05-27'.A728>,
#  <Cell 'Review Details_2019-05-27'.A729>,
#  <Cell 'Review Details_2019-05-27'.A730>,
#  <Cell 'Review Details_2019-05-27'.A731>,
#  <Cell 'Review Details_2019-05-27'.A732>,
#  <Cell 'Review Details_2019-05-27'.A733>,
#  <Cell 'Review Details_2019-05-27'.A734>,
#  <Cell 'Review Details_2019-05-27'.A735>,
#  <Cell 'Review Details_2019-05-27'.A736>,
#  <Cell 'Review Details_2019-05-27'.A737>,
#  <Cell 'Review Details_2019-05-27'.A738>,
#  <Cell 'Review Details_2019-05-27'.A739>,
#  <Cell 'Review Details_2019-05-27'.A740>,
#  <Cell 'Review Details_2019-05-27'.A741>,
#  <Cell 'Review Details_2019-05-27'.A742>,
#  <Cell 'Review Details_2019-05-27'.A743>,
#  <Cell 'Review Details_2019-05-27'.A744>,
#  <Cell 'Review Details_2019-05-27'.A745>,
#  <Cell 'Review Details_2019-05-27'.A746>,
#  <Cell 'Review Details_2019-05-27'.A747>,
#  <Cell 'Review Details_2019-05-27'.A748>,
#  <Cell 'Review Details_2019-05-27'.A749>,
#  <Cell 'Review Details_2019-05-27'.A750>,
#  <Cell 'Review Details_2019-05-27'.A751>,
#  <Cell 'Review Details_2019-05-27'.A752>,
#  <Cell 'Review Details_2019-05-27'.A753>,
#  <Cell 'Review Details_2019-05-27'.A754>,
#  <Cell 'Review Details_2019-05-27'.A755>,
#  <Cell 'Review Details_2019-05-27'.A756>,
#  <Cell 'Review Details_2019-05-27'.A757>,
#  <Cell 'Review Details_2019-05-27'.A758>,
#  <Cell 'Review Details_2019-05-27'.A759>,
#  <Cell 'Review Details_2019-05-27'.A760>,
#  <Cell 'Review Details_2019-05-27'.A761>,
#  <Cell 'Review Details_2019-05-27'.A762>,
#  <Cell 'Review Details_2019-05-27'.A763>,
#  <Cell 'Review Details_2019-05-27'.A764>,
#  <Cell 'Review Details_2019-05-27'.A765>,
#  <Cell 'Review Details_2019-05-27'.A766>,
#  <Cell 'Review Details_2019-05-27'.A767>,
#  <Cell 'Review Details_2019-05-27'.A768>,
#  <Cell 'Review Details_2019-05-27'.A769>,
#  <Cell 'Review Details_2019-05-27'.A770>,
#  <Cell 'Review Details_2019-05-27'.A771>,
#  <Cell 'Review Details_2019-05-27'.A772>,
#  <Cell 'Review Details_2019-05-27'.A773>,
#  <Cell 'Review Details_2019-05-27'.A774>,
#  <Cell 'Review Details_2019-05-27'.A775>,
#  <Cell 'Review Details_2019-05-27'.A776>,
#  <Cell 'Review Details_2019-05-27'.A777>,
#  <Cell 'Review Details_2019-05-27'.A778>,
#  <Cell 'Review Details_2019-05-27'.A779>,
#  <Cell 'Review Details_2019-05-27'.A780>,
#  <Cell 'Review Details_2019-05-27'.A781>,
#  <Cell 'Review Details_2019-05-27'.A782>,
#  <Cell 'Review Details_2019-05-27'.A783>,
#  <Cell 'Review Details_2019-05-27'.A784>,
#  <Cell 'Review Details_2019-05-27'.A785>,
#  <Cell 'Review Details_2019-05-27'.A786>,
#  <Cell 'Review Details_2019-05-27'.A787>,
#  <Cell 'Review Details_2019-05-27'.A788>,
#  <Cell 'Review Details_2019-05-27'.A789>,
#  <Cell 'Review Details_2019-05-27'.A790>,
#  <Cell 'Review Details_2019-05-27'.A791>,
#  <Cell 'Review Details_2019-05-27'.A792>,
#  <Cell 'Review Details_2019-05-27'.A793>,
#  <Cell 'Review Details_2019-05-27'.A794>,
#  <Cell 'Review Details_2019-05-27'.A795>,
#  <Cell 'Review Details_2019-05-27'.A796>,
#  <Cell 'Review Details_2019-05-27'.A797>,
#  <Cell 'Review Details_2019-05-27'.A798>,
#  <Cell 'Review Details_2019-05-27'.A799>,
#  <Cell 'Review Details_2019-05-27'.A800>,
#  <Cell 'Review Details_2019-05-27'.A801>,
#  <Cell 'Review Details_2019-05-27'.A802>,
#  <Cell 'Review Details_2019-05-27'.A803>,
#  <Cell 'Review Details_2019-05-27'.A804>,
#  <Cell 'Review Details_2019-05-27'.A805>,
#  <Cell 'Review Details_2019-05-27'.A806>,
#  <Cell 'Review Details_2019-05-27'.A807>,
#  <Cell 'Review Details_2019-05-27'.A808>,
#  <Cell 'Review Details_2019-05-27'.A809>,
#  <Cell 'Review Details_2019-05-27'.A810>,
#  <Cell 'Review Details_2019-05-27'.A811>,
#  <Cell 'Review Details_2019-05-27'.A812>,
#  <Cell 'Review Details_2019-05-27'.A813>,
#  <Cell 'Review Details_2019-05-27'.A814>,
#  <Cell 'Review Details_2019-05-27'.A815>,
#  <Cell 'Review Details_2019-05-27'.A816>,
#  <Cell 'Review Details_2019-05-27'.A817>,
#  <Cell 'Review Details_2019-05-27'.A818>,
#  <Cell 'Review Details_2019-05-27'.A819>,
#  <Cell 'Review Details_2019-05-27'.A820>,
#  <Cell 'Review Details_2019-05-27'.A821>,
#  <Cell 'Review Details_2019-05-27'.A822>,
#  <Cell 'Review Details_2019-05-27'.A823>,
#  <Cell 'Review Details_2019-05-27'.A824>,
#  <Cell 'Review Details_2019-05-27'.A825>,
#  <Cell 'Review Details_2019-05-27'.A826>,
#  <Cell 'Review Details_2019-05-27'.A827>,
#  <Cell 'Review Details_2019-05-27'.A828>,
#  <Cell 'Review Details_2019-05-27'.A829>,
#  <Cell 'Review Details_2019-05-27'.A830>,
#  <Cell 'Review Details_2019-05-27'.A831>,
#  <Cell 'Review Details_2019-05-27'.A832>,
#  <Cell 'Review Details_2019-05-27'.A833>,
#  <Cell 'Review Details_2019-05-27'.A834>,
#  <Cell 'Review Details_2019-05-27'.A835>,
#  <Cell 'Review Details_2019-05-27'.A836>,
#  <Cell 'Review Details_2019-05-27'.A837>,
#  <Cell 'Review Details_2019-05-27'.A838>,
#  <Cell 'Review Details_2019-05-27'.A839>,
#  <Cell 'Review Details_2019-05-27'.A840>,
#  <Cell 'Review Details_2019-05-27'.A841>,
#  <Cell 'Review Details_2019-05-27'.A842>,
#  <Cell 'Review Details_2019-05-27'.A843>,
#  <Cell 'Review Details_2019-05-27'.A844>,
#  <Cell 'Review Details_2019-05-27'.A845>,
#  <Cell 'Review Details_2019-05-27'.A846>,
#  <Cell 'Review Details_2019-05-27'.A847>,
#  <Cell 'Review Details_2019-05-27'.A848>,
#  <Cell 'Review Details_2019-05-27'.A849>,
#  <Cell 'Review Details_2019-05-27'.A850>,
#  <Cell 'Review Details_2019-05-27'.A851>,
#  <Cell 'Review Details_2019-05-27'.A852>,
#  <Cell 'Review Details_2019-05-27'.A853>,
#  <Cell 'Review Details_2019-05-27'.A854>,
#  <Cell 'Review Details_2019-05-27'.A855>,
#  <Cell 'Review Details_2019-05-27'.A856>,
#  <Cell 'Review Details_2019-05-27'.A857>,
#  <Cell 'Review Details_2019-05-27'.A858>,
#  <Cell 'Review Details_2019-05-27'.A859>,
#  <Cell 'Review Details_2019-05-27'.A860>,
#  <Cell 'Review Details_2019-05-27'.A861>,
#  <Cell 'Review Details_2019-05-27'.A862>,
#  <Cell 'Review Details_2019-05-27'.A863>,
#  <Cell 'Review Details_2019-05-27'.A864>,
#  <Cell 'Review Details_2019-05-27'.A865>,
#  <Cell 'Review Details_2019-05-27'.A866>,
#  <Cell 'Review Details_2019-05-27'.A867>,
#  <Cell 'Review Details_2019-05-27'.A868>,
#  <Cell 'Review Details_2019-05-27'.A869>,
#  <Cell 'Review Details_2019-05-27'.A870>,
#  <Cell 'Review Details_2019-05-27'.A871>,
#  <Cell 'Review Details_2019-05-27'.A872>,
#  <Cell 'Review Details_2019-05-27'.A873>,
#  <Cell 'Review Details_2019-05-27'.A874>,
#  <Cell 'Review Details_2019-05-27'.A875>,
#  <Cell 'Review Details_2019-05-27'.A876>,
#  <Cell 'Review Details_2019-05-27'.A877>,
#  <Cell 'Review Details_2019-05-27'.A878>,
#  <Cell 'Review Details_2019-05-27'.A879>,
#  <Cell 'Review Details_2019-05-27'.A880>,
#  <Cell 'Review Details_2019-05-27'.A881>,
#  <Cell 'Review Details_2019-05-27'.A882>,
#  <Cell 'Review Details_2019-05-27'.A883>,
#  <Cell 'Review Details_2019-05-27'.A884>,
#  <Cell 'Review Details_2019-05-27'.A885>,
#  <Cell 'Review Details_2019-05-27'.A886>,
#  <Cell 'Review Details_2019-05-27'.A887>,
#  <Cell 'Review Details_2019-05-27'.A888>,
#  <Cell 'Review Details_2019-05-27'.A889>,
#  <Cell 'Review Details_2019-05-27'.A890>,
#  <Cell 'Review Details_2019-05-27'.A891>,
#  <Cell 'Review Details_2019-05-27'.A892>,
#  <Cell 'Review Details_2019-05-27'.A893>,
#  <Cell 'Review Details_2019-05-27'.A894>,
#  <Cell 'Review Details_2019-05-27'.A895>,
#  <Cell 'Review Details_2019-05-27'.A896>,
#  <Cell 'Review Details_2019-05-27'.A897>,
#  <Cell 'Review Details_2019-05-27'.A898>,
#  <Cell 'Review Details_2019-05-27'.A899>,
#  <Cell 'Review Details_2019-05-27'.A900>,
#  <Cell 'Review Details_2019-05-27'.A901>,
#  <Cell 'Review Details_2019-05-27'.A902>,
#  <Cell 'Review Details_2019-05-27'.A903>,
#  <Cell 'Review Details_2019-05-27'.A904>,
#  <Cell 'Review Details_2019-05-27'.A905>,
#  <Cell 'Review Details_2019-05-27'.A906>,
#  <Cell 'Review Details_2019-05-27'.A907>,
#  <Cell 'Review Details_2019-05-27'.A908>,
#  <Cell 'Review Details_2019-05-27'.A909>,
#  <Cell 'Review Details_2019-05-27'.A910>,
#  <Cell 'Review Details_2019-05-27'.A911>,
#  <Cell 'Review Details_2019-05-27'.A912>,
#  <Cell 'Review Details_2019-05-27'.A913>,
#  <Cell 'Review Details_2019-05-27'.A914>,
#  <Cell 'Review Details_2019-05-27'.A915>,
#  <Cell 'Review Details_2019-05-27'.A916>,
#  <Cell 'Review Details_2019-05-27'.A917>,
#  <Cell 'Review Details_2019-05-27'.A918>,
#  <Cell 'Review Details_2019-05-27'.A919>,
#  <Cell 'Review Details_2019-05-27'.A920>,
#  <Cell 'Review Details_2019-05-27'.A921>,
#  <Cell 'Review Details_2019-05-27'.A922>,
#  <Cell 'Review Details_2019-05-27'.A923>,
#  <Cell 'Review Details_2019-05-27'.A924>,
#  <Cell 'Review Details_2019-05-27'.A925>,
#  <Cell 'Review Details_2019-05-27'.A926>,
#  <Cell 'Review Details_2019-05-27'.A927>,
#  <Cell 'Review Details_2019-05-27'.A928>,
#  <Cell 'Review Details_2019-05-27'.A929>,
#  <Cell 'Review Details_2019-05-27'.A930>,
#  <Cell 'Review Details_2019-05-27'.A931>,
#  <Cell 'Review Details_2019-05-27'.A932>,
#  <Cell 'Review Details_2019-05-27'.A933>,
#  <Cell 'Review Details_2019-05-27'.A934>,
#  <Cell 'Review Details_2019-05-27'.A935>,
#  <Cell 'Review Details_2019-05-27'.A936>,
#  <Cell 'Review Details_2019-05-27'.A937>,
#  <Cell 'Review Details_2019-05-27'.A938>,
#  <Cell 'Review Details_2019-05-27'.A939>,
#  <Cell 'Review Details_2019-05-27'.A940>,
#  <Cell 'Review Details_2019-05-27'.A941>,
#  <Cell 'Review Details_2019-05-27'.A942>,
#  <Cell 'Review Details_2019-05-27'.A943>,
#  <Cell 'Review Details_2019-05-27'.A944>,
#  <Cell 'Review Details_2019-05-27'.A945>,
#  <Cell 'Review Details_2019-05-27'.A946>,
#  <Cell 'Review Details_2019-05-27'.A947>,
#  <Cell 'Review Details_2019-05-27'.A948>,
#  <Cell 'Review Details_2019-05-27'.A949>,
#  <Cell 'Review Details_2019-05-27'.A950>,
#  <Cell 'Review Details_2019-05-27'.A951>,
#  <Cell 'Review Details_2019-05-27'.A952>,
#  <Cell 'Review Details_2019-05-27'.A953>,
#  <Cell 'Review Details_2019-05-27'.A954>,
#  <Cell 'Review Details_2019-05-27'.A955>,
#  <Cell 'Review Details_2019-05-27'.A956>,
#  <Cell 'Review Details_2019-05-27'.A957>,
#  <Cell 'Review Details_2019-05-27'.A958>,
#  <Cell 'Review Details_2019-05-27'.A959>,
#  <Cell 'Review Details_2019-05-27'.A960>,
#  <Cell 'Review Details_2019-05-27'.A961>,
#  <Cell 'Review Details_2019-05-27'.A962>,
#  <Cell 'Review Details_2019-05-27'.A963>,
#  <Cell 'Review Details_2019-05-27'.A964>,
#  <Cell 'Review Details_2019-05-27'.A965>,
#  <Cell 'Review Details_2019-05-27'.A966>,
#  <Cell 'Review Details_2019-05-27'.A967>,
#  <Cell 'Review Details_2019-05-27'.A968>,
#  <Cell 'Review Details_2019-05-27'.A969>,
#  <Cell 'Review Details_2019-05-27'.A970>,
#  <Cell 'Review Details_2019-05-27'.A971>,
#  <Cell 'Review Details_2019-05-27'.A972>,
#  <Cell 'Review Details_2019-05-27'.A973>,
#  <Cell 'Review Details_2019-05-27'.A974>,
#  <Cell 'Review Details_2019-05-27'.A975>,
#  <Cell 'Review Details_2019-05-27'.A976>,
#  <Cell 'Review Details_2019-05-27'.A977>,
#  <Cell 'Review Details_2019-05-27'.A978>,
#  <Cell 'Review Details_2019-05-27'.A979>,
#  <Cell 'Review Details_2019-05-27'.A980>,
#  <Cell 'Review Details_2019-05-27'.A981>,
#  <Cell 'Review Details_2019-05-27'.A982>,
#  <Cell 'Review Details_2019-05-27'.A983>,
#  <Cell 'Review Details_2019-05-27'.A984>,
#  <Cell 'Review Details_2019-05-27'.A985>,
#  <Cell 'Review Details_2019-05-27'.A986>,
#  <Cell 'Review Details_2019-05-27'.A987>,
#  <Cell 'Review Details_2019-05-27'.A988>,
#  <Cell 'Review Details_2019-05-27'.A989>,
#  <Cell 'Review Details_2019-05-27'.A990>,
#  <Cell 'Review Details_2019-05-27'.A991>,
#  <Cell 'Review Details_2019-05-27'.A992>,
#  <Cell 'Review Details_2019-05-27'.A993>,
#  <Cell 'Review Details_2019-05-27'.A994>,
#  <Cell 'Review Details_2019-05-27'.A995>,
#  <Cell 'Review Details_2019-05-27'.A996>,
#  <Cell 'Review Details_2019-05-27'.A997>,
#  <Cell 'Review Details_2019-05-27'.A998>,
#  <Cell 'Review Details_2019-05-27'.A999>,
#  <Cell 'Review Details_2019-05-27'.A1000>,
#  ...)

# %%
# Get all cells for a range of columns
sheet["A:B"]
# Out:
# ((<Cell 'Review Details_2019-05-27'.A1>,
#   <Cell 'Review Details_2019-05-27'.A2>,
#   <Cell 'Review Details_2019-05-27'.A3>,
#   <Cell 'Review Details_2019-05-27'.A4>,
#   <Cell 'Review Details_2019-05-27'.A5>,
#   <Cell 'Review Details_2019-05-27'.A6>,
#   <Cell 'Review Details_2019-05-27'.A7>,
#   <Cell 'Review Details_2019-05-27'.A8>,
#   <Cell 'Review Details_2019-05-27'.A9>,
#   <Cell 'Review Details_2019-05-27'.A10>,
#   <Cell 'Review Details_2019-05-27'.A11>,
#   <Cell 'Review Details_2019-05-27'.A12>,
#   <Cell 'Review Details_2019-05-27'.A13>,
#   <Cell 'Review Details_2019-05-27'.A14>,
#   <Cell 'Review Details_2019-05-27'.A15>,
#   <Cell 'Review Details_2019-05-27'.A16>,
#   <Cell 'Review Details_2019-05-27'.A17>,
#   <Cell 'Review Details_2019-05-27'.A18>,
#   <Cell 'Review Details_2019-05-27'.A19>,
#   <Cell 'Review Details_2019-05-27'.A20>,
#   <Cell 'Review Details_2019-05-27'.A21>,
#   <Cell 'Review Details_2019-05-27'.A22>,
#   <Cell 'Review Details_2019-05-27'.A23>,
#   <Cell 'Review Details_2019-05-27'.A24>,
#   <Cell 'Review Details_2019-05-27'.A25>,
#   <Cell 'Review Details_2019-05-27'.A26>,
#   <Cell 'Review Details_2019-05-27'.A27>,
#   <Cell 'Review Details_2019-05-27'.A28>,
#   <Cell 'Review Details_2019-05-27'.A29>,
#   <Cell 'Review Details_2019-05-27'.A30>,
#   <Cell 'Review Details_2019-05-27'.A31>,
#   <Cell 'Review Details_2019-05-27'.A32>,
#   <Cell 'Review Details_2019-05-27'.A33>,
#   <Cell 'Review Details_2019-05-27'.A34>,
#   <Cell 'Review Details_2019-05-27'.A35>,
#   <Cell 'Review Details_2019-05-27'.A36>,
#   <Cell 'Review Details_2019-05-27'.A37>,
#   <Cell 'Review Details_2019-05-27'.A38>,
#   <Cell 'Review Details_2019-05-27'.A39>,
#   <Cell 'Review Details_2019-05-27'.A40>,
#   <Cell 'Review Details_2019-05-27'.A41>,
#   <Cell 'Review Details_2019-05-27'.A42>,
#   <Cell 'Review Details_2019-05-27'.A43>,
#   <Cell 'Review Details_2019-05-27'.A44>,
#   <Cell 'Review Details_2019-05-27'.A45>,
#   <Cell 'Review Details_2019-05-27'.A46>,
#   <Cell 'Review Details_2019-05-27'.A47>,
#   <Cell 'Review Details_2019-05-27'.A48>,
#   <Cell 'Review Details_2019-05-27'.A49>,
#   <Cell 'Review Details_2019-05-27'.A50>,
#   <Cell 'Review Details_2019-05-27'.A51>,
#   <Cell 'Review Details_2019-05-27'.A52>,
#   <Cell 'Review Details_2019-05-27'.A53>,
#   <Cell 'Review Details_2019-05-27'.A54>,
#   <Cell 'Review Details_2019-05-27'.A55>,
#   <Cell 'Review Details_2019-05-27'.A56>,
#   <Cell 'Review Details_2019-05-27'.A57>,
#   <Cell 'Review Details_2019-05-27'.A58>,
#   <Cell 'Review Details_2019-05-27'.A59>,
#   <Cell 'Review Details_2019-05-27'.A60>,
#   <Cell 'Review Details_2019-05-27'.A61>,
#   <Cell 'Review Details_2019-05-27'.A62>,
#   <Cell 'Review Details_2019-05-27'.A63>,
#   <Cell 'Review Details_2019-05-27'.A64>,
#   <Cell 'Review Details_2019-05-27'.A65>,
#   <Cell 'Review Details_2019-05-27'.A66>,
#   <Cell 'Review Details_2019-05-27'.A67>,
#   <Cell 'Review Details_2019-05-27'.A68>,
#   <Cell 'Review Details_2019-05-27'.A69>,
#   <Cell 'Review Details_2019-05-27'.A70>,
#   <Cell 'Review Details_2019-05-27'.A71>,
#   <Cell 'Review Details_2019-05-27'.A72>,
#   <Cell 'Review Details_2019-05-27'.A73>,
#   <Cell 'Review Details_2019-05-27'.A74>,
#   <Cell 'Review Details_2019-05-27'.A75>,
#   <Cell 'Review Details_2019-05-27'.A76>,
#   <Cell 'Review Details_2019-05-27'.A77>,
#   <Cell 'Review Details_2019-05-27'.A78>,
#   <Cell 'Review Details_2019-05-27'.A79>,
#   <Cell 'Review Details_2019-05-27'.A80>,
#   <Cell 'Review Details_2019-05-27'.A81>,
#   <Cell 'Review Details_2019-05-27'.A82>,
#   <Cell 'Review Details_2019-05-27'.A83>,
#   <Cell 'Review Details_2019-05-27'.A84>,
#   <Cell 'Review Details_2019-05-27'.A85>,
#   <Cell 'Review Details_2019-05-27'.A86>,
#   <Cell 'Review Details_2019-05-27'.A87>,
#   <Cell 'Review Details_2019-05-27'.A88>,
#   <Cell 'Review Details_2019-05-27'.A89>,
#   <Cell 'Review Details_2019-05-27'.A90>,
#   <Cell 'Review Details_2019-05-27'.A91>,
#   <Cell 'Review Details_2019-05-27'.A92>,
#   <Cell 'Review Details_2019-05-27'.A93>,
#   <Cell 'Review Details_2019-05-27'.A94>,
#   <Cell 'Review Details_2019-05-27'.A95>,
#   <Cell 'Review Details_2019-05-27'.A96>,
#   <Cell 'Review Details_2019-05-27'.A97>,
#   <Cell 'Review Details_2019-05-27'.A98>,
#   <Cell 'Review Details_2019-05-27'.A99>,
#   <Cell 'Review Details_2019-05-27'.A100>,
#   <Cell 'Review Details_2019-05-27'.A101>,
#   <Cell 'Review Details_2019-05-27'.A102>,
#   <Cell 'Review Details_2019-05-27'.A103>,
#   <Cell 'Review Details_2019-05-27'.A104>,
#   <Cell 'Review Details_2019-05-27'.A105>,
#   <Cell 'Review Details_2019-05-27'.A106>,
#   <Cell 'Review Details_2019-05-27'.A107>,
#   <Cell 'Review Details_2019-05-27'.A108>,
#   <Cell 'Review Details_2019-05-27'.A109>,
#   <Cell 'Review Details_2019-05-27'.A110>,
#   <Cell 'Review Details_2019-05-27'.A111>,
#   <Cell 'Review Details_2019-05-27'.A112>,
#   <Cell 'Review Details_2019-05-27'.A113>,
#   <Cell 'Review Details_2019-05-27'.A114>,
#   <Cell 'Review Details_2019-05-27'.A115>,
#   <Cell 'Review Details_2019-05-27'.A116>,
#   <Cell 'Review Details_2019-05-27'.A117>,
#   <Cell 'Review Details_2019-05-27'.A118>,
#   <Cell 'Review Details_2019-05-27'.A119>,
#   <Cell 'Review Details_2019-05-27'.A120>,
#   <Cell 'Review Details_2019-05-27'.A121>,
#   <Cell 'Review Details_2019-05-27'.A122>,
#   <Cell 'Review Details_2019-05-27'.A123>,
#   <Cell 'Review Details_2019-05-27'.A124>,
#   <Cell 'Review Details_2019-05-27'.A125>,
#   <Cell 'Review Details_2019-05-27'.A126>,
#   <Cell 'Review Details_2019-05-27'.A127>,
#   <Cell 'Review Details_2019-05-27'.A128>,
#   <Cell 'Review Details_2019-05-27'.A129>,
#   <Cell 'Review Details_2019-05-27'.A130>,
#   <Cell 'Review Details_2019-05-27'.A131>,
#   <Cell 'Review Details_2019-05-27'.A132>,
#   <Cell 'Review Details_2019-05-27'.A133>,
#   <Cell 'Review Details_2019-05-27'.A134>,
#   <Cell 'Review Details_2019-05-27'.A135>,
#   <Cell 'Review Details_2019-05-27'.A136>,
#   <Cell 'Review Details_2019-05-27'.A137>,
#   <Cell 'Review Details_2019-05-27'.A138>,
#   <Cell 'Review Details_2019-05-27'.A139>,
#   <Cell 'Review Details_2019-05-27'.A140>,
#   <Cell 'Review Details_2019-05-27'.A141>,
#   <Cell 'Review Details_2019-05-27'.A142>,
#   <Cell 'Review Details_2019-05-27'.A143>,
#   <Cell 'Review Details_2019-05-27'.A144>,
#   <Cell 'Review Details_2019-05-27'.A145>,
#   <Cell 'Review Details_2019-05-27'.A146>,
#   <Cell 'Review Details_2019-05-27'.A147>,
#   <Cell 'Review Details_2019-05-27'.A148>,
#   <Cell 'Review Details_2019-05-27'.A149>,
#   <Cell 'Review Details_2019-05-27'.A150>,
#   <Cell 'Review Details_2019-05-27'.A151>,
#   <Cell 'Review Details_2019-05-27'.A152>,
#   <Cell 'Review Details_2019-05-27'.A153>,
#   <Cell 'Review Details_2019-05-27'.A154>,
#   <Cell 'Review Details_2019-05-27'.A155>,
#   <Cell 'Review Details_2019-05-27'.A156>,
#   <Cell 'Review Details_2019-05-27'.A157>,
#   <Cell 'Review Details_2019-05-27'.A158>,
#   <Cell 'Review Details_2019-05-27'.A159>,
#   <Cell 'Review Details_2019-05-27'.A160>,
#   <Cell 'Review Details_2019-05-27'.A161>,
#   <Cell 'Review Details_2019-05-27'.A162>,
#   <Cell 'Review Details_2019-05-27'.A163>,
#   <Cell 'Review Details_2019-05-27'.A164>,
#   <Cell 'Review Details_2019-05-27'.A165>,
#   <Cell 'Review Details_2019-05-27'.A166>,
#   <Cell 'Review Details_2019-05-27'.A167>,
#   <Cell 'Review Details_2019-05-27'.A168>,
#   <Cell 'Review Details_2019-05-27'.A169>,
#   <Cell 'Review Details_2019-05-27'.A170>,
#   <Cell 'Review Details_2019-05-27'.A171>,
#   <Cell 'Review Details_2019-05-27'.A172>,
#   <Cell 'Review Details_2019-05-27'.A173>,
#   <Cell 'Review Details_2019-05-27'.A174>,
#   <Cell 'Review Details_2019-05-27'.A175>,
#   <Cell 'Review Details_2019-05-27'.A176>,
#   <Cell 'Review Details_2019-05-27'.A177>,
#   <Cell 'Review Details_2019-05-27'.A178>,
#   <Cell 'Review Details_2019-05-27'.A179>,
#   <Cell 'Review Details_2019-05-27'.A180>,
#   <Cell 'Review Details_2019-05-27'.A181>,
#   <Cell 'Review Details_2019-05-27'.A182>,
#   <Cell 'Review Details_2019-05-27'.A183>,
#   <Cell 'Review Details_2019-05-27'.A184>,
#   <Cell 'Review Details_2019-05-27'.A185>,
#   <Cell 'Review Details_2019-05-27'.A186>,
#   <Cell 'Review Details_2019-05-27'.A187>,
#   <Cell 'Review Details_2019-05-27'.A188>,
#   <Cell 'Review Details_2019-05-27'.A189>,
#   <Cell 'Review Details_2019-05-27'.A190>,
#   <Cell 'Review Details_2019-05-27'.A191>,
#   <Cell 'Review Details_2019-05-27'.A192>,
#   <Cell 'Review Details_2019-05-27'.A193>,
#   <Cell 'Review Details_2019-05-27'.A194>,
#   <Cell 'Review Details_2019-05-27'.A195>,
#   <Cell 'Review Details_2019-05-27'.A196>,
#   <Cell 'Review Details_2019-05-27'.A197>,
#   <Cell 'Review Details_2019-05-27'.A198>,
#   <Cell 'Review Details_2019-05-27'.A199>,
#   <Cell 'Review Details_2019-05-27'.A200>,
#   <Cell 'Review Details_2019-05-27'.A201>,
#   <Cell 'Review Details_2019-05-27'.A202>,
#   <Cell 'Review Details_2019-05-27'.A203>,
#   <Cell 'Review Details_2019-05-27'.A204>,
#   <Cell 'Review Details_2019-05-27'.A205>,
#   <Cell 'Review Details_2019-05-27'.A206>,
#   <Cell 'Review Details_2019-05-27'.A207>,
#   <Cell 'Review Details_2019-05-27'.A208>,
#   <Cell 'Review Details_2019-05-27'.A209>,
#   <Cell 'Review Details_2019-05-27'.A210>,
#   <Cell 'Review Details_2019-05-27'.A211>,
#   <Cell 'Review Details_2019-05-27'.A212>,
#   <Cell 'Review Details_2019-05-27'.A213>,
#   <Cell 'Review Details_2019-05-27'.A214>,
#   <Cell 'Review Details_2019-05-27'.A215>,
#   <Cell 'Review Details_2019-05-27'.A216>,
#   <Cell 'Review Details_2019-05-27'.A217>,
#   <Cell 'Review Details_2019-05-27'.A218>,
#   <Cell 'Review Details_2019-05-27'.A219>,
#   <Cell 'Review Details_2019-05-27'.A220>,
#   <Cell 'Review Details_2019-05-27'.A221>,
#   <Cell 'Review Details_2019-05-27'.A222>,
#   <Cell 'Review Details_2019-05-27'.A223>,
#   <Cell 'Review Details_2019-05-27'.A224>,
#   <Cell 'Review Details_2019-05-27'.A225>,
#   <Cell 'Review Details_2019-05-27'.A226>,
#   <Cell 'Review Details_2019-05-27'.A227>,
#   <Cell 'Review Details_2019-05-27'.A228>,
#   <Cell 'Review Details_2019-05-27'.A229>,
#   <Cell 'Review Details_2019-05-27'.A230>,
#   <Cell 'Review Details_2019-05-27'.A231>,
#   <Cell 'Review Details_2019-05-27'.A232>,
#   <Cell 'Review Details_2019-05-27'.A233>,
#   <Cell 'Review Details_2019-05-27'.A234>,
#   <Cell 'Review Details_2019-05-27'.A235>,
#   <Cell 'Review Details_2019-05-27'.A236>,
#   <Cell 'Review Details_2019-05-27'.A237>,
#   <Cell 'Review Details_2019-05-27'.A238>,
#   <Cell 'Review Details_2019-05-27'.A239>,
#   <Cell 'Review Details_2019-05-27'.A240>,
#   <Cell 'Review Details_2019-05-27'.A241>,
#   <Cell 'Review Details_2019-05-27'.A242>,
#   <Cell 'Review Details_2019-05-27'.A243>,
#   <Cell 'Review Details_2019-05-27'.A244>,
#   <Cell 'Review Details_2019-05-27'.A245>,
#   <Cell 'Review Details_2019-05-27'.A246>,
#   <Cell 'Review Details_2019-05-27'.A247>,
#   <Cell 'Review Details_2019-05-27'.A248>,
#   <Cell 'Review Details_2019-05-27'.A249>,
#   <Cell 'Review Details_2019-05-27'.A250>,
#   <Cell 'Review Details_2019-05-27'.A251>,
#   <Cell 'Review Details_2019-05-27'.A252>,
#   <Cell 'Review Details_2019-05-27'.A253>,
#   <Cell 'Review Details_2019-05-27'.A254>,
#   <Cell 'Review Details_2019-05-27'.A255>,
#   <Cell 'Review Details_2019-05-27'.A256>,
#   <Cell 'Review Details_2019-05-27'.A257>,
#   <Cell 'Review Details_2019-05-27'.A258>,
#   <Cell 'Review Details_2019-05-27'.A259>,
#   <Cell 'Review Details_2019-05-27'.A260>,
#   <Cell 'Review Details_2019-05-27'.A261>,
#   <Cell 'Review Details_2019-05-27'.A262>,
#   <Cell 'Review Details_2019-05-27'.A263>,
#   <Cell 'Review Details_2019-05-27'.A264>,
#   <Cell 'Review Details_2019-05-27'.A265>,
#   <Cell 'Review Details_2019-05-27'.A266>,
#   <Cell 'Review Details_2019-05-27'.A267>,
#   <Cell 'Review Details_2019-05-27'.A268>,
#   <Cell 'Review Details_2019-05-27'.A269>,
#   <Cell 'Review Details_2019-05-27'.A270>,
#   <Cell 'Review Details_2019-05-27'.A271>,
#   <Cell 'Review Details_2019-05-27'.A272>,
#   <Cell 'Review Details_2019-05-27'.A273>,
#   <Cell 'Review Details_2019-05-27'.A274>,
#   <Cell 'Review Details_2019-05-27'.A275>,
#   <Cell 'Review Details_2019-05-27'.A276>,
#   <Cell 'Review Details_2019-05-27'.A277>,
#   <Cell 'Review Details_2019-05-27'.A278>,
#   <Cell 'Review Details_2019-05-27'.A279>,
#   <Cell 'Review Details_2019-05-27'.A280>,
#   <Cell 'Review Details_2019-05-27'.A281>,
#   <Cell 'Review Details_2019-05-27'.A282>,
#   <Cell 'Review Details_2019-05-27'.A283>,
#   <Cell 'Review Details_2019-05-27'.A284>,
#   <Cell 'Review Details_2019-05-27'.A285>,
#   <Cell 'Review Details_2019-05-27'.A286>,
#   <Cell 'Review Details_2019-05-27'.A287>,
#   <Cell 'Review Details_2019-05-27'.A288>,
#   <Cell 'Review Details_2019-05-27'.A289>,
#   <Cell 'Review Details_2019-05-27'.A290>,
#   <Cell 'Review Details_2019-05-27'.A291>,
#   <Cell 'Review Details_2019-05-27'.A292>,
#   <Cell 'Review Details_2019-05-27'.A293>,
#   <Cell 'Review Details_2019-05-27'.A294>,
#   <Cell 'Review Details_2019-05-27'.A295>,
#   <Cell 'Review Details_2019-05-27'.A296>,
#   <Cell 'Review Details_2019-05-27'.A297>,
#   <Cell 'Review Details_2019-05-27'.A298>,
#   <Cell 'Review Details_2019-05-27'.A299>,
#   <Cell 'Review Details_2019-05-27'.A300>,
#   <Cell 'Review Details_2019-05-27'.A301>,
#   <Cell 'Review Details_2019-05-27'.A302>,
#   <Cell 'Review Details_2019-05-27'.A303>,
#   <Cell 'Review Details_2019-05-27'.A304>,
#   <Cell 'Review Details_2019-05-27'.A305>,
#   <Cell 'Review Details_2019-05-27'.A306>,
#   <Cell 'Review Details_2019-05-27'.A307>,
#   <Cell 'Review Details_2019-05-27'.A308>,
#   <Cell 'Review Details_2019-05-27'.A309>,
#   <Cell 'Review Details_2019-05-27'.A310>,
#   <Cell 'Review Details_2019-05-27'.A311>,
#   <Cell 'Review Details_2019-05-27'.A312>,
#   <Cell 'Review Details_2019-05-27'.A313>,
#   <Cell 'Review Details_2019-05-27'.A314>,
#   <Cell 'Review Details_2019-05-27'.A315>,
#   <Cell 'Review Details_2019-05-27'.A316>,
#   <Cell 'Review Details_2019-05-27'.A317>,
#   <Cell 'Review Details_2019-05-27'.A318>,
#   <Cell 'Review Details_2019-05-27'.A319>,
#   <Cell 'Review Details_2019-05-27'.A320>,
#   <Cell 'Review Details_2019-05-27'.A321>,
#   <Cell 'Review Details_2019-05-27'.A322>,
#   <Cell 'Review Details_2019-05-27'.A323>,
#   <Cell 'Review Details_2019-05-27'.A324>,
#   <Cell 'Review Details_2019-05-27'.A325>,
#   <Cell 'Review Details_2019-05-27'.A326>,
#   <Cell 'Review Details_2019-05-27'.A327>,
#   <Cell 'Review Details_2019-05-27'.A328>,
#   <Cell 'Review Details_2019-05-27'.A329>,
#   <Cell 'Review Details_2019-05-27'.A330>,
#   <Cell 'Review Details_2019-05-27'.A331>,
#   <Cell 'Review Details_2019-05-27'.A332>,
#   <Cell 'Review Details_2019-05-27'.A333>,
#   <Cell 'Review Details_2019-05-27'.A334>,
#   <Cell 'Review Details_2019-05-27'.A335>,
#   <Cell 'Review Details_2019-05-27'.A336>,
#   <Cell 'Review Details_2019-05-27'.A337>,
#   <Cell 'Review Details_2019-05-27'.A338>,
#   <Cell 'Review Details_2019-05-27'.A339>,
#   <Cell 'Review Details_2019-05-27'.A340>,
#   <Cell 'Review Details_2019-05-27'.A341>,
#   <Cell 'Review Details_2019-05-27'.A342>,
#   <Cell 'Review Details_2019-05-27'.A343>,
#   <Cell 'Review Details_2019-05-27'.A344>,
#   <Cell 'Review Details_2019-05-27'.A345>,
#   <Cell 'Review Details_2019-05-27'.A346>,
#   <Cell 'Review Details_2019-05-27'.A347>,
#   <Cell 'Review Details_2019-05-27'.A348>,
#   <Cell 'Review Details_2019-05-27'.A349>,
#   <Cell 'Review Details_2019-05-27'.A350>,
#   <Cell 'Review Details_2019-05-27'.A351>,
#   <Cell 'Review Details_2019-05-27'.A352>,
#   <Cell 'Review Details_2019-05-27'.A353>,
#   <Cell 'Review Details_2019-05-27'.A354>,
#   <Cell 'Review Details_2019-05-27'.A355>,
#   <Cell 'Review Details_2019-05-27'.A356>,
#   <Cell 'Review Details_2019-05-27'.A357>,
#   <Cell 'Review Details_2019-05-27'.A358>,
#   <Cell 'Review Details_2019-05-27'.A359>,
#   <Cell 'Review Details_2019-05-27'.A360>,
#   <Cell 'Review Details_2019-05-27'.A361>,
#   <Cell 'Review Details_2019-05-27'.A362>,
#   <Cell 'Review Details_2019-05-27'.A363>,
#   <Cell 'Review Details_2019-05-27'.A364>,
#   <Cell 'Review Details_2019-05-27'.A365>,
#   <Cell 'Review Details_2019-05-27'.A366>,
#   <Cell 'Review Details_2019-05-27'.A367>,
#   <Cell 'Review Details_2019-05-27'.A368>,
#   <Cell 'Review Details_2019-05-27'.A369>,
#   <Cell 'Review Details_2019-05-27'.A370>,
#   <Cell 'Review Details_2019-05-27'.A371>,
#   <Cell 'Review Details_2019-05-27'.A372>,
#   <Cell 'Review Details_2019-05-27'.A373>,
#   <Cell 'Review Details_2019-05-27'.A374>,
#   <Cell 'Review Details_2019-05-27'.A375>,
#   <Cell 'Review Details_2019-05-27'.A376>,
#   <Cell 'Review Details_2019-05-27'.A377>,
#   <Cell 'Review Details_2019-05-27'.A378>,
#   <Cell 'Review Details_2019-05-27'.A379>,
#   <Cell 'Review Details_2019-05-27'.A380>,
#   <Cell 'Review Details_2019-05-27'.A381>,
#   <Cell 'Review Details_2019-05-27'.A382>,
#   <Cell 'Review Details_2019-05-27'.A383>,
#   <Cell 'Review Details_2019-05-27'.A384>,
#   <Cell 'Review Details_2019-05-27'.A385>,
#   <Cell 'Review Details_2019-05-27'.A386>,
#   <Cell 'Review Details_2019-05-27'.A387>,
#   <Cell 'Review Details_2019-05-27'.A388>,
#   <Cell 'Review Details_2019-05-27'.A389>,
#   <Cell 'Review Details_2019-05-27'.A390>,
#   <Cell 'Review Details_2019-05-27'.A391>,
#   <Cell 'Review Details_2019-05-27'.A392>,
#   <Cell 'Review Details_2019-05-27'.A393>,
#   <Cell 'Review Details_2019-05-27'.A394>,
#   <Cell 'Review Details_2019-05-27'.A395>,
#   <Cell 'Review Details_2019-05-27'.A396>,
#   <Cell 'Review Details_2019-05-27'.A397>,
#   <Cell 'Review Details_2019-05-27'.A398>,
#   <Cell 'Review Details_2019-05-27'.A399>,
#   <Cell 'Review Details_2019-05-27'.A400>,
#   <Cell 'Review Details_2019-05-27'.A401>,
#   <Cell 'Review Details_2019-05-27'.A402>,
#   <Cell 'Review Details_2019-05-27'.A403>,
#   <Cell 'Review Details_2019-05-27'.A404>,
#   <Cell 'Review Details_2019-05-27'.A405>,
#   <Cell 'Review Details_2019-05-27'.A406>,
#   <Cell 'Review Details_2019-05-27'.A407>,
#   <Cell 'Review Details_2019-05-27'.A408>,
#   <Cell 'Review Details_2019-05-27'.A409>,
#   <Cell 'Review Details_2019-05-27'.A410>,
#   <Cell 'Review Details_2019-05-27'.A411>,
#   <Cell 'Review Details_2019-05-27'.A412>,
#   <Cell 'Review Details_2019-05-27'.A413>,
#   <Cell 'Review Details_2019-05-27'.A414>,
#   <Cell 'Review Details_2019-05-27'.A415>,
#   <Cell 'Review Details_2019-05-27'.A416>,
#   <Cell 'Review Details_2019-05-27'.A417>,
#   <Cell 'Review Details_2019-05-27'.A418>,
#   <Cell 'Review Details_2019-05-27'.A419>,
#   <Cell 'Review Details_2019-05-27'.A420>,
#   <Cell 'Review Details_2019-05-27'.A421>,
#   <Cell 'Review Details_2019-05-27'.A422>,
#   <Cell 'Review Details_2019-05-27'.A423>,
#   <Cell 'Review Details_2019-05-27'.A424>,
#   <Cell 'Review Details_2019-05-27'.A425>,
#   <Cell 'Review Details_2019-05-27'.A426>,
#   <Cell 'Review Details_2019-05-27'.A427>,
#   <Cell 'Review Details_2019-05-27'.A428>,
#   <Cell 'Review Details_2019-05-27'.A429>,
#   <Cell 'Review Details_2019-05-27'.A430>,
#   <Cell 'Review Details_2019-05-27'.A431>,
#   <Cell 'Review Details_2019-05-27'.A432>,
#   <Cell 'Review Details_2019-05-27'.A433>,
#   <Cell 'Review Details_2019-05-27'.A434>,
#   <Cell 'Review Details_2019-05-27'.A435>,
#   <Cell 'Review Details_2019-05-27'.A436>,
#   <Cell 'Review Details_2019-05-27'.A437>,
#   <Cell 'Review Details_2019-05-27'.A438>,
#   <Cell 'Review Details_2019-05-27'.A439>,
#   <Cell 'Review Details_2019-05-27'.A440>,
#   <Cell 'Review Details_2019-05-27'.A441>,
#   <Cell 'Review Details_2019-05-27'.A442>,
#   <Cell 'Review Details_2019-05-27'.A443>,
#   <Cell 'Review Details_2019-05-27'.A444>,
#   <Cell 'Review Details_2019-05-27'.A445>,
#   <Cell 'Review Details_2019-05-27'.A446>,
#   <Cell 'Review Details_2019-05-27'.A447>,
#   <Cell 'Review Details_2019-05-27'.A448>,
#   <Cell 'Review Details_2019-05-27'.A449>,
#   <Cell 'Review Details_2019-05-27'.A450>,
#   <Cell 'Review Details_2019-05-27'.A451>,
#   <Cell 'Review Details_2019-05-27'.A452>,
#   <Cell 'Review Details_2019-05-27'.A453>,
#   <Cell 'Review Details_2019-05-27'.A454>,
#   <Cell 'Review Details_2019-05-27'.A455>,
#   <Cell 'Review Details_2019-05-27'.A456>,
#   <Cell 'Review Details_2019-05-27'.A457>,
#   <Cell 'Review Details_2019-05-27'.A458>,
#   <Cell 'Review Details_2019-05-27'.A459>,
#   <Cell 'Review Details_2019-05-27'.A460>,
#   <Cell 'Review Details_2019-05-27'.A461>,
#   <Cell 'Review Details_2019-05-27'.A462>,
#   <Cell 'Review Details_2019-05-27'.A463>,
#   <Cell 'Review Details_2019-05-27'.A464>,
#   <Cell 'Review Details_2019-05-27'.A465>,
#   <Cell 'Review Details_2019-05-27'.A466>,
#   <Cell 'Review Details_2019-05-27'.A467>,
#   <Cell 'Review Details_2019-05-27'.A468>,
#   <Cell 'Review Details_2019-05-27'.A469>,
#   <Cell 'Review Details_2019-05-27'.A470>,
#   <Cell 'Review Details_2019-05-27'.A471>,
#   <Cell 'Review Details_2019-05-27'.A472>,
#   <Cell 'Review Details_2019-05-27'.A473>,
#   <Cell 'Review Details_2019-05-27'.A474>,
#   <Cell 'Review Details_2019-05-27'.A475>,
#   <Cell 'Review Details_2019-05-27'.A476>,
#   <Cell 'Review Details_2019-05-27'.A477>,
#   <Cell 'Review Details_2019-05-27'.A478>,
#   <Cell 'Review Details_2019-05-27'.A479>,
#   <Cell 'Review Details_2019-05-27'.A480>,
#   <Cell 'Review Details_2019-05-27'.A481>,
#   <Cell 'Review Details_2019-05-27'.A482>,
#   <Cell 'Review Details_2019-05-27'.A483>,
#   <Cell 'Review Details_2019-05-27'.A484>,
#   <Cell 'Review Details_2019-05-27'.A485>,
#   <Cell 'Review Details_2019-05-27'.A486>,
#   <Cell 'Review Details_2019-05-27'.A487>,
#   <Cell 'Review Details_2019-05-27'.A488>,
#   <Cell 'Review Details_2019-05-27'.A489>,
#   <Cell 'Review Details_2019-05-27'.A490>,
#   <Cell 'Review Details_2019-05-27'.A491>,
#   <Cell 'Review Details_2019-05-27'.A492>,
#   <Cell 'Review Details_2019-05-27'.A493>,
#   <Cell 'Review Details_2019-05-27'.A494>,
#   <Cell 'Review Details_2019-05-27'.A495>,
#   <Cell 'Review Details_2019-05-27'.A496>,
#   <Cell 'Review Details_2019-05-27'.A497>,
#   <Cell 'Review Details_2019-05-27'.A498>,
#   <Cell 'Review Details_2019-05-27'.A499>,
#   <Cell 'Review Details_2019-05-27'.A500>,
#   <Cell 'Review Details_2019-05-27'.A501>,
#   <Cell 'Review Details_2019-05-27'.A502>,
#   <Cell 'Review Details_2019-05-27'.A503>,
#   <Cell 'Review Details_2019-05-27'.A504>,
#   <Cell 'Review Details_2019-05-27'.A505>,
#   <Cell 'Review Details_2019-05-27'.A506>,
#   <Cell 'Review Details_2019-05-27'.A507>,
#   <Cell 'Review Details_2019-05-27'.A508>,
#   <Cell 'Review Details_2019-05-27'.A509>,
#   <Cell 'Review Details_2019-05-27'.A510>,
#   <Cell 'Review Details_2019-05-27'.A511>,
#   <Cell 'Review Details_2019-05-27'.A512>,
#   <Cell 'Review Details_2019-05-27'.A513>,
#   <Cell 'Review Details_2019-05-27'.A514>,
#   <Cell 'Review Details_2019-05-27'.A515>,
#   <Cell 'Review Details_2019-05-27'.A516>,
#   <Cell 'Review Details_2019-05-27'.A517>,
#   <Cell 'Review Details_2019-05-27'.A518>,
#   <Cell 'Review Details_2019-05-27'.A519>,
#   <Cell 'Review Details_2019-05-27'.A520>,
#   <Cell 'Review Details_2019-05-27'.A521>,
#   <Cell 'Review Details_2019-05-27'.A522>,
#   <Cell 'Review Details_2019-05-27'.A523>,
#   <Cell 'Review Details_2019-05-27'.A524>,
#   <Cell 'Review Details_2019-05-27'.A525>,
#   <Cell 'Review Details_2019-05-27'.A526>,
#   <Cell 'Review Details_2019-05-27'.A527>,
#   <Cell 'Review Details_2019-05-27'.A528>,
#   <Cell 'Review Details_2019-05-27'.A529>,
#   <Cell 'Review Details_2019-05-27'.A530>,
#   <Cell 'Review Details_2019-05-27'.A531>,
#   <Cell 'Review Details_2019-05-27'.A532>,
#   <Cell 'Review Details_2019-05-27'.A533>,
#   <Cell 'Review Details_2019-05-27'.A534>,
#   <Cell 'Review Details_2019-05-27'.A535>,
#   <Cell 'Review Details_2019-05-27'.A536>,
#   <Cell 'Review Details_2019-05-27'.A537>,
#   <Cell 'Review Details_2019-05-27'.A538>,
#   <Cell 'Review Details_2019-05-27'.A539>,
#   <Cell 'Review Details_2019-05-27'.A540>,
#   <Cell 'Review Details_2019-05-27'.A541>,
#   <Cell 'Review Details_2019-05-27'.A542>,
#   <Cell 'Review Details_2019-05-27'.A543>,
#   <Cell 'Review Details_2019-05-27'.A544>,
#   <Cell 'Review Details_2019-05-27'.A545>,
#   <Cell 'Review Details_2019-05-27'.A546>,
#   <Cell 'Review Details_2019-05-27'.A547>,
#   <Cell 'Review Details_2019-05-27'.A548>,
#   <Cell 'Review Details_2019-05-27'.A549>,
#   <Cell 'Review Details_2019-05-27'.A550>,
#   <Cell 'Review Details_2019-05-27'.A551>,
#   <Cell 'Review Details_2019-05-27'.A552>,
#   <Cell 'Review Details_2019-05-27'.A553>,
#   <Cell 'Review Details_2019-05-27'.A554>,
#   <Cell 'Review Details_2019-05-27'.A555>,
#   <Cell 'Review Details_2019-05-27'.A556>,
#   <Cell 'Review Details_2019-05-27'.A557>,
#   <Cell 'Review Details_2019-05-27'.A558>,
#   <Cell 'Review Details_2019-05-27'.A559>,
#   <Cell 'Review Details_2019-05-27'.A560>,
#   <Cell 'Review Details_2019-05-27'.A561>,
#   <Cell 'Review Details_2019-05-27'.A562>,
#   <Cell 'Review Details_2019-05-27'.A563>,
#   <Cell 'Review Details_2019-05-27'.A564>,
#   <Cell 'Review Details_2019-05-27'.A565>,
#   <Cell 'Review Details_2019-05-27'.A566>,
#   <Cell 'Review Details_2019-05-27'.A567>,
#   <Cell 'Review Details_2019-05-27'.A568>,
#   <Cell 'Review Details_2019-05-27'.A569>,
#   <Cell 'Review Details_2019-05-27'.A570>,
#   <Cell 'Review Details_2019-05-27'.A571>,
#   <Cell 'Review Details_2019-05-27'.A572>,
#   <Cell 'Review Details_2019-05-27'.A573>,
#   <Cell 'Review Details_2019-05-27'.A574>,
#   <Cell 'Review Details_2019-05-27'.A575>,
#   <Cell 'Review Details_2019-05-27'.A576>,
#   <Cell 'Review Details_2019-05-27'.A577>,
#   <Cell 'Review Details_2019-05-27'.A578>,
#   <Cell 'Review Details_2019-05-27'.A579>,
#   <Cell 'Review Details_2019-05-27'.A580>,
#   <Cell 'Review Details_2019-05-27'.A581>,
#   <Cell 'Review Details_2019-05-27'.A582>,
#   <Cell 'Review Details_2019-05-27'.A583>,
#   <Cell 'Review Details_2019-05-27'.A584>,
#   <Cell 'Review Details_2019-05-27'.A585>,
#   <Cell 'Review Details_2019-05-27'.A586>,
#   <Cell 'Review Details_2019-05-27'.A587>,
#   <Cell 'Review Details_2019-05-27'.A588>,
#   <Cell 'Review Details_2019-05-27'.A589>,
#   <Cell 'Review Details_2019-05-27'.A590>,
#   <Cell 'Review Details_2019-05-27'.A591>,
#   <Cell 'Review Details_2019-05-27'.A592>,
#   <Cell 'Review Details_2019-05-27'.A593>,
#   <Cell 'Review Details_2019-05-27'.A594>,
#   <Cell 'Review Details_2019-05-27'.A595>,
#   <Cell 'Review Details_2019-05-27'.A596>,
#   <Cell 'Review Details_2019-05-27'.A597>,
#   <Cell 'Review Details_2019-05-27'.A598>,
#   <Cell 'Review Details_2019-05-27'.A599>,
#   <Cell 'Review Details_2019-05-27'.A600>,
#   <Cell 'Review Details_2019-05-27'.A601>,
#   <Cell 'Review Details_2019-05-27'.A602>,
#   <Cell 'Review Details_2019-05-27'.A603>,
#   <Cell 'Review Details_2019-05-27'.A604>,
#   <Cell 'Review Details_2019-05-27'.A605>,
#   <Cell 'Review Details_2019-05-27'.A606>,
#   <Cell 'Review Details_2019-05-27'.A607>,
#   <Cell 'Review Details_2019-05-27'.A608>,
#   <Cell 'Review Details_2019-05-27'.A609>,
#   <Cell 'Review Details_2019-05-27'.A610>,
#   <Cell 'Review Details_2019-05-27'.A611>,
#   <Cell 'Review Details_2019-05-27'.A612>,
#   <Cell 'Review Details_2019-05-27'.A613>,
#   <Cell 'Review Details_2019-05-27'.A614>,
#   <Cell 'Review Details_2019-05-27'.A615>,
#   <Cell 'Review Details_2019-05-27'.A616>,
#   <Cell 'Review Details_2019-05-27'.A617>,
#   <Cell 'Review Details_2019-05-27'.A618>,
#   <Cell 'Review Details_2019-05-27'.A619>,
#   <Cell 'Review Details_2019-05-27'.A620>,
#   <Cell 'Review Details_2019-05-27'.A621>,
#   <Cell 'Review Details_2019-05-27'.A622>,
#   <Cell 'Review Details_2019-05-27'.A623>,
#   <Cell 'Review Details_2019-05-27'.A624>,
#   <Cell 'Review Details_2019-05-27'.A625>,
#   <Cell 'Review Details_2019-05-27'.A626>,
#   <Cell 'Review Details_2019-05-27'.A627>,
#   <Cell 'Review Details_2019-05-27'.A628>,
#   <Cell 'Review Details_2019-05-27'.A629>,
#   <Cell 'Review Details_2019-05-27'.A630>,
#   <Cell 'Review Details_2019-05-27'.A631>,
#   <Cell 'Review Details_2019-05-27'.A632>,
#   <Cell 'Review Details_2019-05-27'.A633>,
#   <Cell 'Review Details_2019-05-27'.A634>,
#   <Cell 'Review Details_2019-05-27'.A635>,
#   <Cell 'Review Details_2019-05-27'.A636>,
#   <Cell 'Review Details_2019-05-27'.A637>,
#   <Cell 'Review Details_2019-05-27'.A638>,
#   <Cell 'Review Details_2019-05-27'.A639>,
#   <Cell 'Review Details_2019-05-27'.A640>,
#   <Cell 'Review Details_2019-05-27'.A641>,
#   <Cell 'Review Details_2019-05-27'.A642>,
#   <Cell 'Review Details_2019-05-27'.A643>,
#   <Cell 'Review Details_2019-05-27'.A644>,
#   <Cell 'Review Details_2019-05-27'.A645>,
#   <Cell 'Review Details_2019-05-27'.A646>,
#   <Cell 'Review Details_2019-05-27'.A647>,
#   <Cell 'Review Details_2019-05-27'.A648>,
#   <Cell 'Review Details_2019-05-27'.A649>,
#   <Cell 'Review Details_2019-05-27'.A650>,
#   <Cell 'Review Details_2019-05-27'.A651>,
#   <Cell 'Review Details_2019-05-27'.A652>,
#   <Cell 'Review Details_2019-05-27'.A653>,
#   <Cell 'Review Details_2019-05-27'.A654>,
#   <Cell 'Review Details_2019-05-27'.A655>,
#   <Cell 'Review Details_2019-05-27'.A656>,
#   <Cell 'Review Details_2019-05-27'.A657>,
#   <Cell 'Review Details_2019-05-27'.A658>,
#   <Cell 'Review Details_2019-05-27'.A659>,
#   <Cell 'Review Details_2019-05-27'.A660>,
#   <Cell 'Review Details_2019-05-27'.A661>,
#   <Cell 'Review Details_2019-05-27'.A662>,
#   <Cell 'Review Details_2019-05-27'.A663>,
#   <Cell 'Review Details_2019-05-27'.A664>,
#   <Cell 'Review Details_2019-05-27'.A665>,
#   <Cell 'Review Details_2019-05-27'.A666>,
#   <Cell 'Review Details_2019-05-27'.A667>,
#   <Cell 'Review Details_2019-05-27'.A668>,
#   <Cell 'Review Details_2019-05-27'.A669>,
#   <Cell 'Review Details_2019-05-27'.A670>,
#   <Cell 'Review Details_2019-05-27'.A671>,
#   <Cell 'Review Details_2019-05-27'.A672>,
#   <Cell 'Review Details_2019-05-27'.A673>,
#   <Cell 'Review Details_2019-05-27'.A674>,
#   <Cell 'Review Details_2019-05-27'.A675>,
#   <Cell 'Review Details_2019-05-27'.A676>,
#   <Cell 'Review Details_2019-05-27'.A677>,
#   <Cell 'Review Details_2019-05-27'.A678>,
#   <Cell 'Review Details_2019-05-27'.A679>,
#   <Cell 'Review Details_2019-05-27'.A680>,
#   <Cell 'Review Details_2019-05-27'.A681>,
#   <Cell 'Review Details_2019-05-27'.A682>,
#   <Cell 'Review Details_2019-05-27'.A683>,
#   <Cell 'Review Details_2019-05-27'.A684>,
#   <Cell 'Review Details_2019-05-27'.A685>,
#   <Cell 'Review Details_2019-05-27'.A686>,
#   <Cell 'Review Details_2019-05-27'.A687>,
#   <Cell 'Review Details_2019-05-27'.A688>,
#   <Cell 'Review Details_2019-05-27'.A689>,
#   <Cell 'Review Details_2019-05-27'.A690>,
#   <Cell 'Review Details_2019-05-27'.A691>,
#   <Cell 'Review Details_2019-05-27'.A692>,
#   <Cell 'Review Details_2019-05-27'.A693>,
#   <Cell 'Review Details_2019-05-27'.A694>,
#   <Cell 'Review Details_2019-05-27'.A695>,
#   <Cell 'Review Details_2019-05-27'.A696>,
#   <Cell 'Review Details_2019-05-27'.A697>,
#   <Cell 'Review Details_2019-05-27'.A698>,
#   <Cell 'Review Details_2019-05-27'.A699>,
#   <Cell 'Review Details_2019-05-27'.A700>,
#   <Cell 'Review Details_2019-05-27'.A701>,
#   <Cell 'Review Details_2019-05-27'.A702>,
#   <Cell 'Review Details_2019-05-27'.A703>,
#   <Cell 'Review Details_2019-05-27'.A704>,
#   <Cell 'Review Details_2019-05-27'.A705>,
#   <Cell 'Review Details_2019-05-27'.A706>,
#   <Cell 'Review Details_2019-05-27'.A707>,
#   <Cell 'Review Details_2019-05-27'.A708>,
#   <Cell 'Review Details_2019-05-27'.A709>,
#   <Cell 'Review Details_2019-05-27'.A710>,
#   <Cell 'Review Details_2019-05-27'.A711>,
#   <Cell 'Review Details_2019-05-27'.A712>,
#   <Cell 'Review Details_2019-05-27'.A713>,
#   <Cell 'Review Details_2019-05-27'.A714>,
#   <Cell 'Review Details_2019-05-27'.A715>,
#   <Cell 'Review Details_2019-05-27'.A716>,
#   <Cell 'Review Details_2019-05-27'.A717>,
#   <Cell 'Review Details_2019-05-27'.A718>,
#   <Cell 'Review Details_2019-05-27'.A719>,
#   <Cell 'Review Details_2019-05-27'.A720>,
#   <Cell 'Review Details_2019-05-27'.A721>,
#   <Cell 'Review Details_2019-05-27'.A722>,
#   <Cell 'Review Details_2019-05-27'.A723>,
#   <Cell 'Review Details_2019-05-27'.A724>,
#   <Cell 'Review Details_2019-05-27'.A725>,
#   <Cell 'Review Details_2019-05-27'.A726>,
#   <Cell 'Review Details_2019-05-27'.A727>,
#   <Cell 'Review Details_2019-05-27'.A728>,
#   <Cell 'Review Details_2019-05-27'.A729>,
#   <Cell 'Review Details_2019-05-27'.A730>,
#   <Cell 'Review Details_2019-05-27'.A731>,
#   <Cell 'Review Details_2019-05-27'.A732>,
#   <Cell 'Review Details_2019-05-27'.A733>,
#   <Cell 'Review Details_2019-05-27'.A734>,
#   <Cell 'Review Details_2019-05-27'.A735>,
#   <Cell 'Review Details_2019-05-27'.A736>,
#   <Cell 'Review Details_2019-05-27'.A737>,
#   <Cell 'Review Details_2019-05-27'.A738>,
#   <Cell 'Review Details_2019-05-27'.A739>,
#   <Cell 'Review Details_2019-05-27'.A740>,
#   <Cell 'Review Details_2019-05-27'.A741>,
#   <Cell 'Review Details_2019-05-27'.A742>,
#   <Cell 'Review Details_2019-05-27'.A743>,
#   <Cell 'Review Details_2019-05-27'.A744>,
#   <Cell 'Review Details_2019-05-27'.A745>,
#   <Cell 'Review Details_2019-05-27'.A746>,
#   <Cell 'Review Details_2019-05-27'.A747>,
#   <Cell 'Review Details_2019-05-27'.A748>,
#   <Cell 'Review Details_2019-05-27'.A749>,
#   <Cell 'Review Details_2019-05-27'.A750>,
#   <Cell 'Review Details_2019-05-27'.A751>,
#   <Cell 'Review Details_2019-05-27'.A752>,
#   <Cell 'Review Details_2019-05-27'.A753>,
#   <Cell 'Review Details_2019-05-27'.A754>,
#   <Cell 'Review Details_2019-05-27'.A755>,
#   <Cell 'Review Details_2019-05-27'.A756>,
#   <Cell 'Review Details_2019-05-27'.A757>,
#   <Cell 'Review Details_2019-05-27'.A758>,
#   <Cell 'Review Details_2019-05-27'.A759>,
#   <Cell 'Review Details_2019-05-27'.A760>,
#   <Cell 'Review Details_2019-05-27'.A761>,
#   <Cell 'Review Details_2019-05-27'.A762>,
#   <Cell 'Review Details_2019-05-27'.A763>,
#   <Cell 'Review Details_2019-05-27'.A764>,
#   <Cell 'Review Details_2019-05-27'.A765>,
#   <Cell 'Review Details_2019-05-27'.A766>,
#   <Cell 'Review Details_2019-05-27'.A767>,
#   <Cell 'Review Details_2019-05-27'.A768>,
#   <Cell 'Review Details_2019-05-27'.A769>,
#   <Cell 'Review Details_2019-05-27'.A770>,
#   <Cell 'Review Details_2019-05-27'.A771>,
#   <Cell 'Review Details_2019-05-27'.A772>,
#   <Cell 'Review Details_2019-05-27'.A773>,
#   <Cell 'Review Details_2019-05-27'.A774>,
#   <Cell 'Review Details_2019-05-27'.A775>,
#   <Cell 'Review Details_2019-05-27'.A776>,
#   <Cell 'Review Details_2019-05-27'.A777>,
#   <Cell 'Review Details_2019-05-27'.A778>,
#   <Cell 'Review Details_2019-05-27'.A779>,
#   <Cell 'Review Details_2019-05-27'.A780>,
#   <Cell 'Review Details_2019-05-27'.A781>,
#   <Cell 'Review Details_2019-05-27'.A782>,
#   <Cell 'Review Details_2019-05-27'.A783>,
#   <Cell 'Review Details_2019-05-27'.A784>,
#   <Cell 'Review Details_2019-05-27'.A785>,
#   <Cell 'Review Details_2019-05-27'.A786>,
#   <Cell 'Review Details_2019-05-27'.A787>,
#   <Cell 'Review Details_2019-05-27'.A788>,
#   <Cell 'Review Details_2019-05-27'.A789>,
#   <Cell 'Review Details_2019-05-27'.A790>,
#   <Cell 'Review Details_2019-05-27'.A791>,
#   <Cell 'Review Details_2019-05-27'.A792>,
#   <Cell 'Review Details_2019-05-27'.A793>,
#   <Cell 'Review Details_2019-05-27'.A794>,
#   <Cell 'Review Details_2019-05-27'.A795>,
#   <Cell 'Review Details_2019-05-27'.A796>,
#   <Cell 'Review Details_2019-05-27'.A797>,
#   <Cell 'Review Details_2019-05-27'.A798>,
#   <Cell 'Review Details_2019-05-27'.A799>,
#   <Cell 'Review Details_2019-05-27'.A800>,
#   <Cell 'Review Details_2019-05-27'.A801>,
#   <Cell 'Review Details_2019-05-27'.A802>,
#   <Cell 'Review Details_2019-05-27'.A803>,
#   <Cell 'Review Details_2019-05-27'.A804>,
#   <Cell 'Review Details_2019-05-27'.A805>,
#   <Cell 'Review Details_2019-05-27'.A806>,
#   <Cell 'Review Details_2019-05-27'.A807>,
#   <Cell 'Review Details_2019-05-27'.A808>,
#   <Cell 'Review Details_2019-05-27'.A809>,
#   <Cell 'Review Details_2019-05-27'.A810>,
#   <Cell 'Review Details_2019-05-27'.A811>,
#   <Cell 'Review Details_2019-05-27'.A812>,
#   <Cell 'Review Details_2019-05-27'.A813>,
#   <Cell 'Review Details_2019-05-27'.A814>,
#   <Cell 'Review Details_2019-05-27'.A815>,
#   <Cell 'Review Details_2019-05-27'.A816>,
#   <Cell 'Review Details_2019-05-27'.A817>,
#   <Cell 'Review Details_2019-05-27'.A818>,
#   <Cell 'Review Details_2019-05-27'.A819>,
#   <Cell 'Review Details_2019-05-27'.A820>,
#   <Cell 'Review Details_2019-05-27'.A821>,
#   <Cell 'Review Details_2019-05-27'.A822>,
#   <Cell 'Review Details_2019-05-27'.A823>,
#   <Cell 'Review Details_2019-05-27'.A824>,
#   <Cell 'Review Details_2019-05-27'.A825>,
#   <Cell 'Review Details_2019-05-27'.A826>,
#   <Cell 'Review Details_2019-05-27'.A827>,
#   <Cell 'Review Details_2019-05-27'.A828>,
#   <Cell 'Review Details_2019-05-27'.A829>,
#   <Cell 'Review Details_2019-05-27'.A830>,
#   <Cell 'Review Details_2019-05-27'.A831>,
#   <Cell 'Review Details_2019-05-27'.A832>,
#   <Cell 'Review Details_2019-05-27'.A833>,
#   <Cell 'Review Details_2019-05-27'.A834>,
#   <Cell 'Review Details_2019-05-27'.A835>,
#   <Cell 'Review Details_2019-05-27'.A836>,
#   <Cell 'Review Details_2019-05-27'.A837>,
#   <Cell 'Review Details_2019-05-27'.A838>,
#   <Cell 'Review Details_2019-05-27'.A839>,
#   <Cell 'Review Details_2019-05-27'.A840>,
#   <Cell 'Review Details_2019-05-27'.A841>,
#   <Cell 'Review Details_2019-05-27'.A842>,
#   <Cell 'Review Details_2019-05-27'.A843>,
#   <Cell 'Review Details_2019-05-27'.A844>,
#   <Cell 'Review Details_2019-05-27'.A845>,
#   <Cell 'Review Details_2019-05-27'.A846>,
#   <Cell 'Review Details_2019-05-27'.A847>,
#   <Cell 'Review Details_2019-05-27'.A848>,
#   <Cell 'Review Details_2019-05-27'.A849>,
#   <Cell 'Review Details_2019-05-27'.A850>,
#   <Cell 'Review Details_2019-05-27'.A851>,
#   <Cell 'Review Details_2019-05-27'.A852>,
#   <Cell 'Review Details_2019-05-27'.A853>,
#   <Cell 'Review Details_2019-05-27'.A854>,
#   <Cell 'Review Details_2019-05-27'.A855>,
#   <Cell 'Review Details_2019-05-27'.A856>,
#   <Cell 'Review Details_2019-05-27'.A857>,
#   <Cell 'Review Details_2019-05-27'.A858>,
#   <Cell 'Review Details_2019-05-27'.A859>,
#   <Cell 'Review Details_2019-05-27'.A860>,
#   <Cell 'Review Details_2019-05-27'.A861>,
#   <Cell 'Review Details_2019-05-27'.A862>,
#   <Cell 'Review Details_2019-05-27'.A863>,
#   <Cell 'Review Details_2019-05-27'.A864>,
#   <Cell 'Review Details_2019-05-27'.A865>,
#   <Cell 'Review Details_2019-05-27'.A866>,
#   <Cell 'Review Details_2019-05-27'.A867>,
#   <Cell 'Review Details_2019-05-27'.A868>,
#   <Cell 'Review Details_2019-05-27'.A869>,
#   <Cell 'Review Details_2019-05-27'.A870>,
#   <Cell 'Review Details_2019-05-27'.A871>,
#   <Cell 'Review Details_2019-05-27'.A872>,
#   <Cell 'Review Details_2019-05-27'.A873>,
#   <Cell 'Review Details_2019-05-27'.A874>,
#   <Cell 'Review Details_2019-05-27'.A875>,
#   <Cell 'Review Details_2019-05-27'.A876>,
#   <Cell 'Review Details_2019-05-27'.A877>,
#   <Cell 'Review Details_2019-05-27'.A878>,
#   <Cell 'Review Details_2019-05-27'.A879>,
#   <Cell 'Review Details_2019-05-27'.A880>,
#   <Cell 'Review Details_2019-05-27'.A881>,
#   <Cell 'Review Details_2019-05-27'.A882>,
#   <Cell 'Review Details_2019-05-27'.A883>,
#   <Cell 'Review Details_2019-05-27'.A884>,
#   <Cell 'Review Details_2019-05-27'.A885>,
#   <Cell 'Review Details_2019-05-27'.A886>,
#   <Cell 'Review Details_2019-05-27'.A887>,
#   <Cell 'Review Details_2019-05-27'.A888>,
#   <Cell 'Review Details_2019-05-27'.A889>,
#   <Cell 'Review Details_2019-05-27'.A890>,
#   <Cell 'Review Details_2019-05-27'.A891>,
#   <Cell 'Review Details_2019-05-27'.A892>,
#   <Cell 'Review Details_2019-05-27'.A893>,
#   <Cell 'Review Details_2019-05-27'.A894>,
#   <Cell 'Review Details_2019-05-27'.A895>,
#   <Cell 'Review Details_2019-05-27'.A896>,
#   <Cell 'Review Details_2019-05-27'.A897>,
#   <Cell 'Review Details_2019-05-27'.A898>,
#   <Cell 'Review Details_2019-05-27'.A899>,
#   <Cell 'Review Details_2019-05-27'.A900>,
#   <Cell 'Review Details_2019-05-27'.A901>,
#   <Cell 'Review Details_2019-05-27'.A902>,
#   <Cell 'Review Details_2019-05-27'.A903>,
#   <Cell 'Review Details_2019-05-27'.A904>,
#   <Cell 'Review Details_2019-05-27'.A905>,
#   <Cell 'Review Details_2019-05-27'.A906>,
#   <Cell 'Review Details_2019-05-27'.A907>,
#   <Cell 'Review Details_2019-05-27'.A908>,
#   <Cell 'Review Details_2019-05-27'.A909>,
#   <Cell 'Review Details_2019-05-27'.A910>,
#   <Cell 'Review Details_2019-05-27'.A911>,
#   <Cell 'Review Details_2019-05-27'.A912>,
#   <Cell 'Review Details_2019-05-27'.A913>,
#   <Cell 'Review Details_2019-05-27'.A914>,
#   <Cell 'Review Details_2019-05-27'.A915>,
#   <Cell 'Review Details_2019-05-27'.A916>,
#   <Cell 'Review Details_2019-05-27'.A917>,
#   <Cell 'Review Details_2019-05-27'.A918>,
#   <Cell 'Review Details_2019-05-27'.A919>,
#   <Cell 'Review Details_2019-05-27'.A920>,
#   <Cell 'Review Details_2019-05-27'.A921>,
#   <Cell 'Review Details_2019-05-27'.A922>,
#   <Cell 'Review Details_2019-05-27'.A923>,
#   <Cell 'Review Details_2019-05-27'.A924>,
#   <Cell 'Review Details_2019-05-27'.A925>,
#   <Cell 'Review Details_2019-05-27'.A926>,
#   <Cell 'Review Details_2019-05-27'.A927>,
#   <Cell 'Review Details_2019-05-27'.A928>,
#   <Cell 'Review Details_2019-05-27'.A929>,
#   <Cell 'Review Details_2019-05-27'.A930>,
#   <Cell 'Review Details_2019-05-27'.A931>,
#   <Cell 'Review Details_2019-05-27'.A932>,
#   <Cell 'Review Details_2019-05-27'.A933>,
#   <Cell 'Review Details_2019-05-27'.A934>,
#   <Cell 'Review Details_2019-05-27'.A935>,
#   <Cell 'Review Details_2019-05-27'.A936>,
#   <Cell 'Review Details_2019-05-27'.A937>,
#   <Cell 'Review Details_2019-05-27'.A938>,
#   <Cell 'Review Details_2019-05-27'.A939>,
#   <Cell 'Review Details_2019-05-27'.A940>,
#   <Cell 'Review Details_2019-05-27'.A941>,
#   <Cell 'Review Details_2019-05-27'.A942>,
#   <Cell 'Review Details_2019-05-27'.A943>,
#   <Cell 'Review Details_2019-05-27'.A944>,
#   <Cell 'Review Details_2019-05-27'.A945>,
#   <Cell 'Review Details_2019-05-27'.A946>,
#   <Cell 'Review Details_2019-05-27'.A947>,
#   <Cell 'Review Details_2019-05-27'.A948>,
#   <Cell 'Review Details_2019-05-27'.A949>,
#   <Cell 'Review Details_2019-05-27'.A950>,
#   <Cell 'Review Details_2019-05-27'.A951>,
#   <Cell 'Review Details_2019-05-27'.A952>,
#   <Cell 'Review Details_2019-05-27'.A953>,
#   <Cell 'Review Details_2019-05-27'.A954>,
#   <Cell 'Review Details_2019-05-27'.A955>,
#   <Cell 'Review Details_2019-05-27'.A956>,
#   <Cell 'Review Details_2019-05-27'.A957>,
#   <Cell 'Review Details_2019-05-27'.A958>,
#   <Cell 'Review Details_2019-05-27'.A959>,
#   <Cell 'Review Details_2019-05-27'.A960>,
#   <Cell 'Review Details_2019-05-27'.A961>,
#   <Cell 'Review Details_2019-05-27'.A962>,
#   <Cell 'Review Details_2019-05-27'.A963>,
#   <Cell 'Review Details_2019-05-27'.A964>,
#   <Cell 'Review Details_2019-05-27'.A965>,
#   <Cell 'Review Details_2019-05-27'.A966>,
#   <Cell 'Review Details_2019-05-27'.A967>,
#   <Cell 'Review Details_2019-05-27'.A968>,
#   <Cell 'Review Details_2019-05-27'.A969>,
#   <Cell 'Review Details_2019-05-27'.A970>,
#   <Cell 'Review Details_2019-05-27'.A971>,
#   <Cell 'Review Details_2019-05-27'.A972>,
#   <Cell 'Review Details_2019-05-27'.A973>,
#   <Cell 'Review Details_2019-05-27'.A974>,
#   <Cell 'Review Details_2019-05-27'.A975>,
#   <Cell 'Review Details_2019-05-27'.A976>,
#   <Cell 'Review Details_2019-05-27'.A977>,
#   <Cell 'Review Details_2019-05-27'.A978>,
#   <Cell 'Review Details_2019-05-27'.A979>,
#   <Cell 'Review Details_2019-05-27'.A980>,
#   <Cell 'Review Details_2019-05-27'.A981>,
#   <Cell 'Review Details_2019-05-27'.A982>,
#   <Cell 'Review Details_2019-05-27'.A983>,
#   <Cell 'Review Details_2019-05-27'.A984>,
#   <Cell 'Review Details_2019-05-27'.A985>,
#   <Cell 'Review Details_2019-05-27'.A986>,
#   <Cell 'Review Details_2019-05-27'.A987>,
#   <Cell 'Review Details_2019-05-27'.A988>,
#   <Cell 'Review Details_2019-05-27'.A989>,
#   <Cell 'Review Details_2019-05-27'.A990>,
#   <Cell 'Review Details_2019-05-27'.A991>,
#   <Cell 'Review Details_2019-05-27'.A992>,
#   <Cell 'Review Details_2019-05-27'.A993>,
#   <Cell 'Review Details_2019-05-27'.A994>,
#   <Cell 'Review Details_2019-05-27'.A995>,
#   <Cell 'Review Details_2019-05-27'.A996>,
#   <Cell 'Review Details_2019-05-27'.A997>,
#   <Cell 'Review Details_2019-05-27'.A998>,
#   <Cell 'Review Details_2019-05-27'.A999>,
#   <Cell 'Review Details_2019-05-27'.A1000>,
#   ...),
#  (<Cell 'Review Details_2019-05-27'.B1>,
#   <Cell 'Review Details_2019-05-27'.B2>,
#   <Cell 'Review Details_2019-05-27'.B3>,
#   <Cell 'Review Details_2019-05-27'.B4>,
#   <Cell 'Review Details_2019-05-27'.B5>,
#   <Cell 'Review Details_2019-05-27'.B6>,
#   <Cell 'Review Details_2019-05-27'.B7>,
#   <Cell 'Review Details_2019-05-27'.B8>,
#   <Cell 'Review Details_2019-05-27'.B9>,
#   <Cell 'Review Details_2019-05-27'.B10>,
#   <Cell 'Review Details_2019-05-27'.B11>,
#   <Cell 'Review Details_2019-05-27'.B12>,
#   <Cell 'Review Details_2019-05-27'.B13>,
#   <Cell 'Review Details_2019-05-27'.B14>,
#   <Cell 'Review Details_2019-05-27'.B15>,
#   <Cell 'Review Details_2019-05-27'.B16>,
#   <Cell 'Review Details_2019-05-27'.B17>,
#   <Cell 'Review Details_2019-05-27'.B18>,
#   <Cell 'Review Details_2019-05-27'.B19>,
#   <Cell 'Review Details_2019-05-27'.B20>,
#   <Cell 'Review Details_2019-05-27'.B21>,
#   <Cell 'Review Details_2019-05-27'.B22>,
#   <Cell 'Review Details_2019-05-27'.B23>,
#   <Cell 'Review Details_2019-05-27'.B24>,
#   <Cell 'Review Details_2019-05-27'.B25>,
#   <Cell 'Review Details_2019-05-27'.B26>,
#   <Cell 'Review Details_2019-05-27'.B27>,
#   <Cell 'Review Details_2019-05-27'.B28>,
#   <Cell 'Review Details_2019-05-27'.B29>,
#   <Cell 'Review Details_2019-05-27'.B30>,
#   <Cell 'Review Details_2019-05-27'.B31>,
#   <Cell 'Review Details_2019-05-27'.B32>,
#   <Cell 'Review Details_2019-05-27'.B33>,
#   <Cell 'Review Details_2019-05-27'.B34>,
#   <Cell 'Review Details_2019-05-27'.B35>,
#   <Cell 'Review Details_2019-05-27'.B36>,
#   <Cell 'Review Details_2019-05-27'.B37>,
#   <Cell 'Review Details_2019-05-27'.B38>,
#   <Cell 'Review Details_2019-05-27'.B39>,
#   <Cell 'Review Details_2019-05-27'.B40>,
#   <Cell 'Review Details_2019-05-27'.B41>,
#   <Cell 'Review Details_2019-05-27'.B42>,
#   <Cell 'Review Details_2019-05-27'.B43>,
#   <Cell 'Review Details_2019-05-27'.B44>,
#   <Cell 'Review Details_2019-05-27'.B45>,
#   <Cell 'Review Details_2019-05-27'.B46>,
#   <Cell 'Review Details_2019-05-27'.B47>,
#   <Cell 'Review Details_2019-05-27'.B48>,
#   <Cell 'Review Details_2019-05-27'.B49>,
#   <Cell 'Review Details_2019-05-27'.B50>,
#   <Cell 'Review Details_2019-05-27'.B51>,
#   <Cell 'Review Details_2019-05-27'.B52>,
#   <Cell 'Review Details_2019-05-27'.B53>,
#   <Cell 'Review Details_2019-05-27'.B54>,
#   <Cell 'Review Details_2019-05-27'.B55>,
#   <Cell 'Review Details_2019-05-27'.B56>,
#   <Cell 'Review Details_2019-05-27'.B57>,
#   <Cell 'Review Details_2019-05-27'.B58>,
#   <Cell 'Review Details_2019-05-27'.B59>,
#   <Cell 'Review Details_2019-05-27'.B60>,
#   <Cell 'Review Details_2019-05-27'.B61>,
#   <Cell 'Review Details_2019-05-27'.B62>,
#   <Cell 'Review Details_2019-05-27'.B63>,
#   <Cell 'Review Details_2019-05-27'.B64>,
#   <Cell 'Review Details_2019-05-27'.B65>,
#   <Cell 'Review Details_2019-05-27'.B66>,
#   <Cell 'Review Details_2019-05-27'.B67>,
#   <Cell 'Review Details_2019-05-27'.B68>,
#   <Cell 'Review Details_2019-05-27'.B69>,
#   <Cell 'Review Details_2019-05-27'.B70>,
#   <Cell 'Review Details_2019-05-27'.B71>,
#   <Cell 'Review Details_2019-05-27'.B72>,
#   <Cell 'Review Details_2019-05-27'.B73>,
#   <Cell 'Review Details_2019-05-27'.B74>,
#   <Cell 'Review Details_2019-05-27'.B75>,
#   <Cell 'Review Details_2019-05-27'.B76>,
#   <Cell 'Review Details_2019-05-27'.B77>,
#   <Cell 'Review Details_2019-05-27'.B78>,
#   <Cell 'Review Details_2019-05-27'.B79>,
#   <Cell 'Review Details_2019-05-27'.B80>,
#   <Cell 'Review Details_2019-05-27'.B81>,
#   <Cell 'Review Details_2019-05-27'.B82>,
#   <Cell 'Review Details_2019-05-27'.B83>,
#   <Cell 'Review Details_2019-05-27'.B84>,
#   <Cell 'Review Details_2019-05-27'.B85>,
#   <Cell 'Review Details_2019-05-27'.B86>,
#   <Cell 'Review Details_2019-05-27'.B87>,
#   <Cell 'Review Details_2019-05-27'.B88>,
#   <Cell 'Review Details_2019-05-27'.B89>,
#   <Cell 'Review Details_2019-05-27'.B90>,
#   <Cell 'Review Details_2019-05-27'.B91>,
#   <Cell 'Review Details_2019-05-27'.B92>,
#   <Cell 'Review Details_2019-05-27'.B93>,
#   <Cell 'Review Details_2019-05-27'.B94>,
#   <Cell 'Review Details_2019-05-27'.B95>,
#   <Cell 'Review Details_2019-05-27'.B96>,
#   <Cell 'Review Details_2019-05-27'.B97>,
#   <Cell 'Review Details_2019-05-27'.B98>,
#   <Cell 'Review Details_2019-05-27'.B99>,
#   <Cell 'Review Details_2019-05-27'.B100>,
#   <Cell 'Review Details_2019-05-27'.B101>,
#   <Cell 'Review Details_2019-05-27'.B102>,
#   <Cell 'Review Details_2019-05-27'.B103>,
#   <Cell 'Review Details_2019-05-27'.B104>,
#   <Cell 'Review Details_2019-05-27'.B105>,
#   <Cell 'Review Details_2019-05-27'.B106>,
#   <Cell 'Review Details_2019-05-27'.B107>,
#   <Cell 'Review Details_2019-05-27'.B108>,
#   <Cell 'Review Details_2019-05-27'.B109>,
#   <Cell 'Review Details_2019-05-27'.B110>,
#   <Cell 'Review Details_2019-05-27'.B111>,
#   <Cell 'Review Details_2019-05-27'.B112>,
#   <Cell 'Review Details_2019-05-27'.B113>,
#   <Cell 'Review Details_2019-05-27'.B114>,
#   <Cell 'Review Details_2019-05-27'.B115>,
#   <Cell 'Review Details_2019-05-27'.B116>,
#   <Cell 'Review Details_2019-05-27'.B117>,
#   <Cell 'Review Details_2019-05-27'.B118>,
#   <Cell 'Review Details_2019-05-27'.B119>,
#   <Cell 'Review Details_2019-05-27'.B120>,
#   <Cell 'Review Details_2019-05-27'.B121>,
# ...
#   <Cell 'Review Details_2019-05-27'.B630>,
#   <Cell 'Review Details_2019-05-27'.B631>,
#   <Cell 'Review Details_2019-05-27'.B632>,
#   <Cell 'Review Details_2019-05-27'.B633>,
#   <Cell 'Review Details_2019-05-27'.B634>,
#   <Cell 'Review Details_2019-05-27'.B635>,
#   <Cell 'Review Details_2019-05-27'.B636>,
#   <Cell 'Review Details_2019-05-27'.B637>,
#   <Cell 'Review Details_2019-05-27'.B638>,
#   <Cell 'Review Details_2019-05-27'.B639>,
#   <Cell 'Review Details_2019-05-27'.B640>,
#   <Cell 'Review Details_2019-05-27'.B641>,
#   <Cell 'Review Details_2019-05-27'.B642>,
#   <Cell 'Review Details_2019-05-27'.B643>,
#   <Cell 'Review Details_2019-05-27'.B644>,
#   <Cell 'Review Details_2019-05-27'.B645>,
#   <Cell 'Review Details_2019-05-27'.B646>,
#   <Cell 'Review Details_2019-05-27'.B647>,
#   <Cell 'Review Details_2019-05-27'.B648>,
#   <Cell 'Review Details_2019-05-27'.B649>,
#   <Cell 'Review Details_2019-05-27'.B650>,
#   <Cell 'Review Details_2019-05-27'.B651>,
#   <Cell 'Review Details_2019-05-27'.B652>,
#   <Cell 'Review Details_2019-05-27'.B653>,
#   <Cell 'Review Details_2019-05-27'.B654>,
#   <Cell 'Review Details_2019-05-27'.B655>,
#   <Cell 'Review Details_2019-05-27'.B656>,
#   <Cell 'Review Details_2019-05-27'.B657>,
#   <Cell 'Review Details_2019-05-27'.B658>,
#   <Cell 'Review Details_2019-05-27'.B659>,
#   <Cell 'Review Details_2019-05-27'.B660>,
#   <Cell 'Review Details_2019-05-27'.B661>,
#   <Cell 'Review Details_2019-05-27'.B662>,
#   <Cell 'Review Details_2019-05-27'.B663>,
#   <Cell 'Review Details_2019-05-27'.B664>,
#   <Cell 'Review Details_2019-05-27'.B665>,
#   <Cell 'Review Details_2019-05-27'.B666>,
#   <Cell 'Review Details_2019-05-27'.B667>,
#   <Cell 'Review Details_2019-05-27'.B668>,
#   <Cell 'Review Details_2019-05-27'.B669>,
#   <Cell 'Review Details_2019-05-27'.B670>,
#   <Cell 'Review Details_2019-05-27'.B671>,
#   <Cell 'Review Details_2019-05-27'.B672>,
#   <Cell 'Review Details_2019-05-27'.B673>,
#   <Cell 'Review Details_2019-05-27'.B674>,
#   <Cell 'Review Details_2019-05-27'.B675>,
#   <Cell 'Review Details_2019-05-27'.B676>,
#   <Cell 'Review Details_2019-05-27'.B677>,
#   <Cell 'Review Details_2019-05-27'.B678>,
#   <Cell 'Review Details_2019-05-27'.B679>,
#   <Cell 'Review Details_2019-05-27'.B680>,
#   <Cell 'Review Details_2019-05-27'.B681>,
#   <Cell 'Review Details_2019-05-27'.B682>,
#   <Cell 'Review Details_2019-05-27'.B683>,
#   <Cell 'Review Details_2019-05-27'.B684>,
#   <Cell 'Review Details_2019-05-27'.B685>,
#   <Cell 'Review Details_2019-05-27'.B686>,
#   <Cell 'Review Details_2019-05-27'.B687>,
#   <Cell 'Review Details_2019-05-27'.B688>,
#   <Cell 'Review Details_2019-05-27'.B689>,
#   <Cell 'Review Details_2019-05-27'.B690>,
#   <Cell 'Review Details_2019-05-27'.B691>,
#   <Cell 'Review Details_2019-05-27'.B692>,
#   <Cell 'Review Details_2019-05-27'.B693>,
#   <Cell 'Review Details_2019-05-27'.B694>,
#   <Cell 'Review Details_2019-05-27'.B695>,
#   <Cell 'Review Details_2019-05-27'.B696>,
#   <Cell 'Review Details_2019-05-27'.B697>,
#   <Cell 'Review Details_2019-05-27'.B698>,
#   <Cell 'Review Details_2019-05-27'.B699>,
#   <Cell 'Review Details_2019-05-27'.B700>,
#   <Cell 'Review Details_2019-05-27'.B701>,
#   <Cell 'Review Details_2019-05-27'.B702>,
#   <Cell 'Review Details_2019-05-27'.B703>,
#   <Cell 'Review Details_2019-05-27'.B704>,
#   <Cell 'Review Details_2019-05-27'.B705>,
#   <Cell 'Review Details_2019-05-27'.B706>,
#   <Cell 'Review Details_2019-05-27'.B707>,
#   <Cell 'Review Details_2019-05-27'.B708>,
#   <Cell 'Review Details_2019-05-27'.B709>,
#   <Cell 'Review Details_2019-05-27'.B710>,
#   <Cell 'Review Details_2019-05-27'.B711>,
#   <Cell 'Review Details_2019-05-27'.B712>,
#   <Cell 'Review Details_2019-05-27'.B713>,
#   <Cell 'Review Details_2019-05-27'.B714>,
#   <Cell 'Review Details_2019-05-27'.B715>,
#   <Cell 'Review Details_2019-05-27'.B716>,
#   <Cell 'Review Details_2019-05-27'.B717>,
#   <Cell 'Review Details_2019-05-27'.B718>,
#   <Cell 'Review Details_2019-05-27'.B719>,
#   <Cell 'Review Details_2019-05-27'.B720>,
#   <Cell 'Review Details_2019-05-27'.B721>,
#   <Cell 'Review Details_2019-05-27'.B722>,
#   <Cell 'Review Details_2019-05-27'.B723>,
#   <Cell 'Review Details_2019-05-27'.B724>,
#   <Cell 'Review Details_2019-05-27'.B725>,
#   <Cell 'Review Details_2019-05-27'.B726>,
#   <Cell 'Review Details_2019-05-27'.B727>,
#   <Cell 'Review Details_2019-05-27'.B728>,
#   <Cell 'Review Details_2019-05-27'.B729>,
#   <Cell 'Review Details_2019-05-27'.B730>,
#   <Cell 'Review Details_2019-05-27'.B731>,
#   <Cell 'Review Details_2019-05-27'.B732>,
#   <Cell 'Review Details_2019-05-27'.B733>,
#   <Cell 'Review Details_2019-05-27'.B734>,
#   <Cell 'Review Details_2019-05-27'.B735>,
#   <Cell 'Review Details_2019-05-27'.B736>,
#   <Cell 'Review Details_2019-05-27'.B737>,
#   <Cell 'Review Details_2019-05-27'.B738>,
#   <Cell 'Review Details_2019-05-27'.B739>,
#   <Cell 'Review Details_2019-05-27'.B740>,
#   <Cell 'Review Details_2019-05-27'.B741>,
#   <Cell 'Review Details_2019-05-27'.B742>,
#   <Cell 'Review Details_2019-05-27'.B743>,
#   <Cell 'Review Details_2019-05-27'.B744>,
#   <Cell 'Review Details_2019-05-27'.B745>,
#   <Cell 'Review Details_2019-05-27'.B746>,
#   <Cell 'Review Details_2019-05-27'.B747>,
#   <Cell 'Review Details_2019-05-27'.B748>,
#   <Cell 'Review Details_2019-05-27'.B749>,
#   <Cell 'Review Details_2019-05-27'.B750>,
#   <Cell 'Review Details_2019-05-27'.B751>,
#   <Cell 'Review Details_2019-05-27'.B752>,
#   <Cell 'Review Details_2019-05-27'.B753>,
#   <Cell 'Review Details_2019-05-27'.B754>,
#   <Cell 'Review Details_2019-05-27'.B755>,
#   <Cell 'Review Details_2019-05-27'.B756>,
#   <Cell 'Review Details_2019-05-27'.B757>,
#   <Cell 'Review Details_2019-05-27'.B758>,
#   <Cell 'Review Details_2019-05-27'.B759>,
#   <Cell 'Review Details_2019-05-27'.B760>,
#   <Cell 'Review Details_2019-05-27'.B761>,
#   <Cell 'Review Details_2019-05-27'.B762>,
#   <Cell 'Review Details_2019-05-27'.B763>,
#   <Cell 'Review Details_2019-05-27'.B764>,
#   <Cell 'Review Details_2019-05-27'.B765>,
#   <Cell 'Review Details_2019-05-27'.B766>,
#   <Cell 'Review Details_2019-05-27'.B767>,
#   <Cell 'Review Details_2019-05-27'.B768>,
#   <Cell 'Review Details_2019-05-27'.B769>,
#   <Cell 'Review Details_2019-05-27'.B770>,
#   <Cell 'Review Details_2019-05-27'.B771>,
#   <Cell 'Review Details_2019-05-27'.B772>,
#   <Cell 'Review Details_2019-05-27'.B773>,
#   <Cell 'Review Details_2019-05-27'.B774>,
#   <Cell 'Review Details_2019-05-27'.B775>,
#   <Cell 'Review Details_2019-05-27'.B776>,
#   <Cell 'Review Details_2019-05-27'.B777>,
#   <Cell 'Review Details_2019-05-27'.B778>,
#   <Cell 'Review Details_2019-05-27'.B779>,
#   <Cell 'Review Details_2019-05-27'.B780>,
#   <Cell 'Review Details_2019-05-27'.B781>,
#   <Cell 'Review Details_2019-05-27'.B782>,
#   <Cell 'Review Details_2019-05-27'.B783>,
#   <Cell 'Review Details_2019-05-27'.B784>,
#   <Cell 'Review Details_2019-05-27'.B785>,
#   <Cell 'Review Details_2019-05-27'.B786>,
#   <Cell 'Review Details_2019-05-27'.B787>,
#   <Cell 'Review Details_2019-05-27'.B788>,
#   <Cell 'Review Details_2019-05-27'.B789>,
#   <Cell 'Review Details_2019-05-27'.B790>,
#   <Cell 'Review Details_2019-05-27'.B791>,
#   <Cell 'Review Details_2019-05-27'.B792>,
#   <Cell 'Review Details_2019-05-27'.B793>,
#   <Cell 'Review Details_2019-05-27'.B794>,
#   <Cell 'Review Details_2019-05-27'.B795>,
#   <Cell 'Review Details_2019-05-27'.B796>,
#   <Cell 'Review Details_2019-05-27'.B797>,
#   <Cell 'Review Details_2019-05-27'.B798>,
#   <Cell 'Review Details_2019-05-27'.B799>,
#   <Cell 'Review Details_2019-05-27'.B800>,
#   <Cell 'Review Details_2019-05-27'.B801>,
#   <Cell 'Review Details_2019-05-27'.B802>,
#   <Cell 'Review Details_2019-05-27'.B803>,
#   <Cell 'Review Details_2019-05-27'.B804>,
#   <Cell 'Review Details_2019-05-27'.B805>,
#   <Cell 'Review Details_2019-05-27'.B806>,
#   <Cell 'Review Details_2019-05-27'.B807>,
#   <Cell 'Review Details_2019-05-27'.B808>,
#   <Cell 'Review Details_2019-05-27'.B809>,
#   <Cell 'Review Details_2019-05-27'.B810>,
#   <Cell 'Review Details_2019-05-27'.B811>,
#   <Cell 'Review Details_2019-05-27'.B812>,
#   <Cell 'Review Details_2019-05-27'.B813>,
#   <Cell 'Review Details_2019-05-27'.B814>,
#   <Cell 'Review Details_2019-05-27'.B815>,
#   <Cell 'Review Details_2019-05-27'.B816>,
#   <Cell 'Review Details_2019-05-27'.B817>,
#   <Cell 'Review Details_2019-05-27'.B818>,
#   <Cell 'Review Details_2019-05-27'.B819>,
#   <Cell 'Review Details_2019-05-27'.B820>,
#   <Cell 'Review Details_2019-05-27'.B821>,
#   <Cell 'Review Details_2019-05-27'.B822>,
#   <Cell 'Review Details_2019-05-27'.B823>,
#   <Cell 'Review Details_2019-05-27'.B824>,
#   <Cell 'Review Details_2019-05-27'.B825>,
#   <Cell 'Review Details_2019-05-27'.B826>,
#   <Cell 'Review Details_2019-05-27'.B827>,
#   <Cell 'Review Details_2019-05-27'.B828>,
#   <Cell 'Review Details_2019-05-27'.B829>,
#   <Cell 'Review Details_2019-05-27'.B830>,
#   <Cell 'Review Details_2019-05-27'.B831>,
#   <Cell 'Review Details_2019-05-27'.B832>,
#   <Cell 'Review Details_2019-05-27'.B833>,
#   <Cell 'Review Details_2019-05-27'.B834>,
#   <Cell 'Review Details_2019-05-27'.B835>,
#   <Cell 'Review Details_2019-05-27'.B836>,
#   <Cell 'Review Details_2019-05-27'.B837>,
#   <Cell 'Review Details_2019-05-27'.B838>,
#   <Cell 'Review Details_2019-05-27'.B839>,
#   <Cell 'Review Details_2019-05-27'.B840>,
#   <Cell 'Review Details_2019-05-27'.B841>,
#   <Cell 'Review Details_2019-05-27'.B842>,
#   <Cell 'Review Details_2019-05-27'.B843>,
#   <Cell 'Review Details_2019-05-27'.B844>,
#   <Cell 'Review Details_2019-05-27'.B845>,
#   <Cell 'Review Details_2019-05-27'.B846>,
#   <Cell 'Review Details_2019-05-27'.B847>,
#   <Cell 'Review Details_2019-05-27'.B848>,
#   <Cell 'Review Details_2019-05-27'.B849>,
#   <Cell 'Review Details_2019-05-27'.B850>,
#   <Cell 'Review Details_2019-05-27'.B851>,
#   <Cell 'Review Details_2019-05-27'.B852>,
#   <Cell 'Review Details_2019-05-27'.B853>,
#   <Cell 'Review Details_2019-05-27'.B854>,
#   <Cell 'Review Details_2019-05-27'.B855>,
#   <Cell 'Review Details_2019-05-27'.B856>,
#   <Cell 'Review Details_2019-05-27'.B857>,
#   <Cell 'Review Details_2019-05-27'.B858>,
#   <Cell 'Review Details_2019-05-27'.B859>,
#   <Cell 'Review Details_2019-05-27'.B860>,
#   <Cell 'Review Details_2019-05-27'.B861>,
#   <Cell 'Review Details_2019-05-27'.B862>,
#   <Cell 'Review Details_2019-05-27'.B863>,
#   <Cell 'Review Details_2019-05-27'.B864>,
#   <Cell 'Review Details_2019-05-27'.B865>,
#   <Cell 'Review Details_2019-05-27'.B866>,
#   <Cell 'Review Details_2019-05-27'.B867>,
#   <Cell 'Review Details_2019-05-27'.B868>,
#   <Cell 'Review Details_2019-05-27'.B869>,
#   <Cell 'Review Details_2019-05-27'.B870>,
#   <Cell 'Review Details_2019-05-27'.B871>,
#   <Cell 'Review Details_2019-05-27'.B872>,
#   <Cell 'Review Details_2019-05-27'.B873>,
#   <Cell 'Review Details_2019-05-27'.B874>,
#   <Cell 'Review Details_2019-05-27'.B875>,
#   <Cell 'Review Details_2019-05-27'.B876>,
#   <Cell 'Review Details_2019-05-27'.B877>,
#   <Cell 'Review Details_2019-05-27'.B878>,
#   <Cell 'Review Details_2019-05-27'.B879>,
#   <Cell 'Review Details_2019-05-27'.B880>,
#   <Cell 'Review Details_2019-05-27'.B881>,
#   <Cell 'Review Details_2019-05-27'.B882>,
#   <Cell 'Review Details_2019-05-27'.B883>,
#   <Cell 'Review Details_2019-05-27'.B884>,
#   <Cell 'Review Details_2019-05-27'.B885>,
#   <Cell 'Review Details_2019-05-27'.B886>,
#   <Cell 'Review Details_2019-05-27'.B887>,
#   <Cell 'Review Details_2019-05-27'.B888>,
#   <Cell 'Review Details_2019-05-27'.B889>,
#   <Cell 'Review Details_2019-05-27'.B890>,
#   <Cell 'Review Details_2019-05-27'.B891>,
#   <Cell 'Review Details_2019-05-27'.B892>,
#   <Cell 'Review Details_2019-05-27'.B893>,
#   <Cell 'Review Details_2019-05-27'.B894>,
#   <Cell 'Review Details_2019-05-27'.B895>,
#   <Cell 'Review Details_2019-05-27'.B896>,
#   <Cell 'Review Details_2019-05-27'.B897>,
#   <Cell 'Review Details_2019-05-27'.B898>,
#   <Cell 'Review Details_2019-05-27'.B899>,
#   <Cell 'Review Details_2019-05-27'.B900>,
#   <Cell 'Review Details_2019-05-27'.B901>,
#   <Cell 'Review Details_2019-05-27'.B902>,
#   <Cell 'Review Details_2019-05-27'.B903>,
#   <Cell 'Review Details_2019-05-27'.B904>,
#   <Cell 'Review Details_2019-05-27'.B905>,
#   <Cell 'Review Details_2019-05-27'.B906>,
#   <Cell 'Review Details_2019-05-27'.B907>,
#   <Cell 'Review Details_2019-05-27'.B908>,
#   <Cell 'Review Details_2019-05-27'.B909>,
#   <Cell 'Review Details_2019-05-27'.B910>,
#   <Cell 'Review Details_2019-05-27'.B911>,
#   <Cell 'Review Details_2019-05-27'.B912>,
#   <Cell 'Review Details_2019-05-27'.B913>,
#   <Cell 'Review Details_2019-05-27'.B914>,
#   <Cell 'Review Details_2019-05-27'.B915>,
#   <Cell 'Review Details_2019-05-27'.B916>,
#   <Cell 'Review Details_2019-05-27'.B917>,
#   <Cell 'Review Details_2019-05-27'.B918>,
#   <Cell 'Review Details_2019-05-27'.B919>,
#   <Cell 'Review Details_2019-05-27'.B920>,
#   <Cell 'Review Details_2019-05-27'.B921>,
#   <Cell 'Review Details_2019-05-27'.B922>,
#   <Cell 'Review Details_2019-05-27'.B923>,
#   <Cell 'Review Details_2019-05-27'.B924>,
#   <Cell 'Review Details_2019-05-27'.B925>,
#   <Cell 'Review Details_2019-05-27'.B926>,
#   <Cell 'Review Details_2019-05-27'.B927>,
#   <Cell 'Review Details_2019-05-27'.B928>,
#   <Cell 'Review Details_2019-05-27'.B929>,
#   <Cell 'Review Details_2019-05-27'.B930>,
#   <Cell 'Review Details_2019-05-27'.B931>,
#   <Cell 'Review Details_2019-05-27'.B932>,
#   <Cell 'Review Details_2019-05-27'.B933>,
#   <Cell 'Review Details_2019-05-27'.B934>,
#   <Cell 'Review Details_2019-05-27'.B935>,
#   <Cell 'Review Details_2019-05-27'.B936>,
#   <Cell 'Review Details_2019-05-27'.B937>,
#   <Cell 'Review Details_2019-05-27'.B938>,
#   <Cell 'Review Details_2019-05-27'.B939>,
#   <Cell 'Review Details_2019-05-27'.B940>,
#   <Cell 'Review Details_2019-05-27'.B941>,
#   <Cell 'Review Details_2019-05-27'.B942>,
#   <Cell 'Review Details_2019-05-27'.B943>,
#   <Cell 'Review Details_2019-05-27'.B944>,
#   <Cell 'Review Details_2019-05-27'.B945>,
#   <Cell 'Review Details_2019-05-27'.B946>,
#   <Cell 'Review Details_2019-05-27'.B947>,
#   <Cell 'Review Details_2019-05-27'.B948>,
#   <Cell 'Review Details_2019-05-27'.B949>,
#   <Cell 'Review Details_2019-05-27'.B950>,
#   <Cell 'Review Details_2019-05-27'.B951>,
#   <Cell 'Review Details_2019-05-27'.B952>,
#   <Cell 'Review Details_2019-05-27'.B953>,
#   <Cell 'Review Details_2019-05-27'.B954>,
#   <Cell 'Review Details_2019-05-27'.B955>,
#   <Cell 'Review Details_2019-05-27'.B956>,
#   <Cell 'Review Details_2019-05-27'.B957>,
#   <Cell 'Review Details_2019-05-27'.B958>,
#   <Cell 'Review Details_2019-05-27'.B959>,
#   <Cell 'Review Details_2019-05-27'.B960>,
#   <Cell 'Review Details_2019-05-27'.B961>,
#   <Cell 'Review Details_2019-05-27'.B962>,
#   <Cell 'Review Details_2019-05-27'.B963>,
#   <Cell 'Review Details_2019-05-27'.B964>,
#   <Cell 'Review Details_2019-05-27'.B965>,
#   <Cell 'Review Details_2019-05-27'.B966>,
#   <Cell 'Review Details_2019-05-27'.B967>,
#   <Cell 'Review Details_2019-05-27'.B968>,
#   <Cell 'Review Details_2019-05-27'.B969>,
#   <Cell 'Review Details_2019-05-27'.B970>,
#   <Cell 'Review Details_2019-05-27'.B971>,
#   <Cell 'Review Details_2019-05-27'.B972>,
#   <Cell 'Review Details_2019-05-27'.B973>,
#   <Cell 'Review Details_2019-05-27'.B974>,
#   <Cell 'Review Details_2019-05-27'.B975>,
#   <Cell 'Review Details_2019-05-27'.B976>,
#   <Cell 'Review Details_2019-05-27'.B977>,
#   <Cell 'Review Details_2019-05-27'.B978>,
#   <Cell 'Review Details_2019-05-27'.B979>,
#   <Cell 'Review Details_2019-05-27'.B980>,
#   <Cell 'Review Details_2019-05-27'.B981>,
#   <Cell 'Review Details_2019-05-27'.B982>,
#   <Cell 'Review Details_2019-05-27'.B983>,
#   <Cell 'Review Details_2019-05-27'.B984>,
#   <Cell 'Review Details_2019-05-27'.B985>,
#   <Cell 'Review Details_2019-05-27'.B986>,
#   <Cell 'Review Details_2019-05-27'.B987>,
#   <Cell 'Review Details_2019-05-27'.B988>,
#   <Cell 'Review Details_2019-05-27'.B989>,
#   <Cell 'Review Details_2019-05-27'.B990>,
#   <Cell 'Review Details_2019-05-27'.B991>,
#   <Cell 'Review Details_2019-05-27'.B992>,
#   <Cell 'Review Details_2019-05-27'.B993>,
#   <Cell 'Review Details_2019-05-27'.B994>,
#   <Cell 'Review Details_2019-05-27'.B995>,
#   <Cell 'Review Details_2019-05-27'.B996>,
#   <Cell 'Review Details_2019-05-27'.B997>,
#   <Cell 'Review Details_2019-05-27'.B998>,
#   <Cell 'Review Details_2019-05-27'.B999>,
#   <Cell 'Review Details_2019-05-27'.B1000>,
#   ...))

# %%
# Get all cells from row 5
sheet[5]
# Out:
# (<Cell 'Review Details_2019-05-27'.A5>,
#  <Cell 'Review Details_2019-05-27'.B5>,
#  <Cell 'Review Details_2019-05-27'.C5>,
#  <Cell 'Review Details_2019-05-27'.D5>,
#  <Cell 'Review Details_2019-05-27'.E5>,
#  <Cell 'Review Details_2019-05-27'.F5>,
#  <Cell 'Review Details_2019-05-27'.G5>,
#  <Cell 'Review Details_2019-05-27'.H5>,
#  <Cell 'Review Details_2019-05-27'.I5>,
#  <Cell 'Review Details_2019-05-27'.J5>,
#  <Cell 'Review Details_2019-05-27'.K5>,
#  <Cell 'Review Details_2019-05-27'.L5>,
#  <Cell 'Review Details_2019-05-27'.M5>,
#  <Cell 'Review Details_2019-05-27'.N5>,
#  <Cell 'Review Details_2019-05-27'.O5>,
#  <Cell 'Review Details_2019-05-27'.P5>,
#  <Cell 'Review Details_2019-05-27'.Q5>,
#  <Cell 'Review Details_2019-05-27'.R5>,
#  <Cell 'Review Details_2019-05-27'.S5>,
#  <Cell 'Review Details_2019-05-27'.T5>,
#  <Cell 'Review Details_2019-05-27'.U5>,
#  <Cell 'Review Details_2019-05-27'.V5>,
#  <Cell 'Review Details_2019-05-27'.W5>,
#  <Cell 'Review Details_2019-05-27'.X5>,
#  <Cell 'Review Details_2019-05-27'.Y5>,
#  <Cell 'Review Details_2019-05-27'.Z5>,
#  <Cell 'Review Details_2019-05-27'.AA5>,
#  <Cell 'Review Details_2019-05-27'.AB5>,
#  <Cell 'Review Details_2019-05-27'.AC5>,
#  <Cell 'Review Details_2019-05-27'.AD5>,
#  <Cell 'Review Details_2019-05-27'.AE5>,
#  <Cell 'Review Details_2019-05-27'.AF5>)

# %%
# Get all cells for a range of rows
sheet[5:6]
# Out:
# ((<Cell 'Review Details_2019-05-27'.A5>,
#   <Cell 'Review Details_2019-05-27'.B5>,
#   <Cell 'Review Details_2019-05-27'.C5>,
#   <Cell 'Review Details_2019-05-27'.D5>,
#   <Cell 'Review Details_2019-05-27'.E5>,
#   <Cell 'Review Details_2019-05-27'.F5>,
#   <Cell 'Review Details_2019-05-27'.G5>,
#   <Cell 'Review Details_2019-05-27'.H5>,
#   <Cell 'Review Details_2019-05-27'.I5>,
#   <Cell 'Review Details_2019-05-27'.J5>,
#   <Cell 'Review Details_2019-05-27'.K5>,
#   <Cell 'Review Details_2019-05-27'.L5>,
#   <Cell 'Review Details_2019-05-27'.M5>,
#   <Cell 'Review Details_2019-05-27'.N5>,
#   <Cell 'Review Details_2019-05-27'.O5>,
#   <Cell 'Review Details_2019-05-27'.P5>,
#   <Cell 'Review Details_2019-05-27'.Q5>,
#   <Cell 'Review Details_2019-05-27'.R5>,
#   <Cell 'Review Details_2019-05-27'.S5>,
#   <Cell 'Review Details_2019-05-27'.T5>,
#   <Cell 'Review Details_2019-05-27'.U5>,
#   <Cell 'Review Details_2019-05-27'.V5>,
#   <Cell 'Review Details_2019-05-27'.W5>,
#   <Cell 'Review Details_2019-05-27'.X5>,
#   <Cell 'Review Details_2019-05-27'.Y5>,
#   <Cell 'Review Details_2019-05-27'.Z5>,
#   <Cell 'Review Details_2019-05-27'.AA5>,
#   <Cell 'Review Details_2019-05-27'.AB5>,
#   <Cell 'Review Details_2019-05-27'.AC5>,
#   <Cell 'Review Details_2019-05-27'.AD5>,
#   <Cell 'Review Details_2019-05-27'.AE5>,
#   <Cell 'Review Details_2019-05-27'.AF5>),
#  (<Cell 'Review Details_2019-05-27'.A6>,
#   <Cell 'Review Details_2019-05-27'.B6>,
#   <Cell 'Review Details_2019-05-27'.C6>,
#   <Cell 'Review Details_2019-05-27'.D6>,
#   <Cell 'Review Details_2019-05-27'.E6>,
#   <Cell 'Review Details_2019-05-27'.F6>,
#   <Cell 'Review Details_2019-05-27'.G6>,
#   <Cell 'Review Details_2019-05-27'.H6>,
#   <Cell 'Review Details_2019-05-27'.I6>,
#   <Cell 'Review Details_2019-05-27'.J6>,
#   <Cell 'Review Details_2019-05-27'.K6>,
#   <Cell 'Review Details_2019-05-27'.L6>,
#   <Cell 'Review Details_2019-05-27'.M6>,
#   <Cell 'Review Details_2019-05-27'.N6>,
#   <Cell 'Review Details_2019-05-27'.O6>,
#   <Cell 'Review Details_2019-05-27'.P6>,
#   <Cell 'Review Details_2019-05-27'.Q6>,
#   <Cell 'Review Details_2019-05-27'.R6>,
#   <Cell 'Review Details_2019-05-27'.S6>,
#   <Cell 'Review Details_2019-05-27'.T6>,
#   <Cell 'Review Details_2019-05-27'.U6>,
#   <Cell 'Review Details_2019-05-27'.V6>,
#   <Cell 'Review Details_2019-05-27'.W6>,
#   <Cell 'Review Details_2019-05-27'.X6>,
#   <Cell 'Review Details_2019-05-27'.Y6>,
#   <Cell 'Review Details_2019-05-27'.Z6>,
#   <Cell 'Review Details_2019-05-27'.AA6>,
#   <Cell 'Review Details_2019-05-27'.AB6>,
#   <Cell 'Review Details_2019-05-27'.AC6>,
#   <Cell 'Review Details_2019-05-27'.AD6>,
#   <Cell 'Review Details_2019-05-27'.AE6>,
#   <Cell 'Review Details_2019-05-27'.AF6>))

# %%
for row in sheet.iter_rows(min_row=1,max_row=2,min_col=1,max_col=3):
    print(row)
# Out:
# (<Cell 'Review Details_2019-05-27'.A1>, <Cell 'Review Details_2019-05-27'.B1>, <Cell 'Review Details_2019-05-27'.C1>)
# (<Cell 'Review Details_2019-05-27'.A2>, <Cell 'Review Details_2019-05-27'.B2>, <Cell 'Review Details_2019-05-27'.C2>)

# %%
for column in sheet.iter_cols(min_row=1,max_row=2,min_col=1,max_col=3):
    print(column)
# Out:
# (<Cell 'Review Details_2019-05-27'.A1>, <Cell 'Review Details_2019-05-27'.A2>)
# (<Cell 'Review Details_2019-05-27'.B1>, <Cell 'Review Details_2019-05-27'.B2>)
# (<Cell 'Review Details_2019-05-27'.C1>, <Cell 'Review Details_2019-05-27'.C2>)

# %% [markdown]
# You’ll notice that in the first example, when iterating through the rows using .iter_rows(), you get one tuple element per row selected. While when using .iter_cols() and iterating through columns, you’ll get one tuple per column instead.

# %%
# One additional argument you can pass to both methods is the Boolean values_only. 
# When it’s set to True, the values of the cell are returned, instead of the Cell object:
for value in sheet.iter_rows(min_row=1,max_row=2,min_col=1,max_col=3,values_only=True):
    print(value)
# Out:
# ('report_date', 'online_store', 'upc')
# (datetime.datetime(2019, 1, 2, 0, 0), 'FRESHAMAZON', 8718114216478)

# %%
# If you want to iterate through the whole dataset, then you can also use the attributes .rows or .columns directly
for row in sheet.rows:
    print(row)
# Out:
# (<Cell 'Review Details_2019-05-27'.A2500>, <Cell 'Review Details_2019-05-27'.B2500>, <Cell 'Review Details_2019-05-27'.C2500>, <Cell 'Review Details_2019-05-27'.D2500>, <Cell 'Review Details_2019-05-27'.E2500>, <Cell 'Review Details_2019-05-27'.F2500>, <Cell 'Review Details_2019-05-27'.G2500>, <Cell 'Review Details_2019-05-27'.H2500>, <Cell 'Review Details_2019-05-27'.I2500>, <Cell 'Review Details_2019-05-27'.J2500>, <Cell 'Review Details_2019-05-27'.K2500>, <Cell 'Review Details_2019-05-27'.L2500>, <Cell 'Review Details_2019-05-27'.M2500>, <Cell 'Review Details_2019-05-27'.N2500>, <Cell 'Review Details_2019-05-27'.O2500>, <Cell 'Review Details_2019-05-27'.P2500>, <Cell 'Review Details_2019-05-27'.Q2500>, <Cell 'Review Details_2019-05-27'.R2500>, <Cell 'Review Details_2019-05-27'.S2500>, <Cell 'Review Details_2019-05-27'.T2500>, <Cell 'Review Details_2019-05-27'.U2500>, <Cell 'Review Details_2019-05-27'.V2500>, <Cell 'Review Details_2019-05-27'.W2500>, <Cell 'Review Details_2019-05-27'.X2500>, <Cell 'Review Details_2019-05-27'.Y2500>, <Cell 'Review Details_2019-05-27'.Z2500>, <Cell 'Review Details_2019-05-27'.AA2500>, <Cell 'Review Details_2019-05-27'.AB2500>, <Cell 'Review Details_2019-05-27'.AC2500>, <Cell 'Review Details_2019-05-27'.AD2500>, <Cell 'Review Details_2019-05-27'.AE2500>, <Cell 'Review Details_2019-05-27'.AF2500>)
# (<Cell 'Review Details_2019-05-27'.A2501>, <Cell 'Review Details_2019-05-27'.B2501>, <Cell 'Review Details_2019-05-27'.C2501>, <Cell 'Review Details_2019-05-27'.D2501>, <Cell 'Review Details_2019-05-27'.E2501>, <Cell 'Review Details_2019-05-27'.F2501>, <Cell 'Review Details_2019-05-27'.G2501>, <Cell 'Review Details_2019-05-27'.H2501>, <Cell 'Review Details_2019-05-27'.I2501>, <Cell 'Review Details_2019-05-27'.J2501>, <Cell 'Review Details_2019-05-27'.K2501>, <Cell 'Review Details_2019-05-27'.L2501>, <Cell 'Review Details_2019-05-27'.M2501>, <Cell 'Review Details_2019-05-27'.N2501>, <Cell 'Review Details_2019-05-27'.O2501>, <Cell 'Review Details_2019-05-27'.P2501>, <Cell 'Review Details_2019-05-27'.Q2501>, <Cell 'Review Details_2019-05-27'.R2501>, <Cell 'Review Details_2019-05-27'.S2501>, <Cell 'Review Details_2019-05-27'.T2501>, <Cell 'Review Details_2019-05-27'.U2501>, <Cell 'Review Details_2019-05-27'.V2501>, <Cell 'Review Details_2019-05-27'.W2501>, <Cell 'Review Details_2019-05-27'.X2501>, <Cell 'Review Details_2019-05-27'.Y2501>, <Cell 'Review Details_2019-05-27'.Z2501>, <Cell 'Review Details_2019-05-27'.AA2501>, <Cell 'Review Details_2019-05-27'.AB2501>, <Cell 'Review Details_2019-05-27'.AC2501>, <Cell 'Review Details_2019-05-27'.AD2501>, <Cell 'Review Details_2019-05-27'.AE2501>, <Cell 'Review Details_2019-05-27'.AF2501>)
# (<Cell 'Review Details_2019-05-27'.A2502>, <Cell 'Review Details_2019-05-27'.B2502>, <Cell 'Review Details_2019-05-27'.C2502>, <Cell 'Review Details_2019-05-27'.D2502>, <Cell 'Review Details_2019-05-27'.E2502>, <Cell 'Review Details_2019-05-27'.F2502>, <Cell 'Review Details_2019-05-27'.G2502>, <Cell 'Review Details_2019-05-27'.H2502>, <Cell 'Review Details_2019-05-27'.I2502>, <Cell 'Review Details_2019-05-27'.J2502>, <Cell 'Review Details_2019-05-27'.K2502>, <Cell 'Review Details_2019-05-27'.L2502>, <Cell 'Review Details_2019-05-27'.M2502>, <Cell 'Review Details_2019-05-27'.N2502>, <Cell 'Review Details_2019-05-27'.O2502>, <Cell 'Review Details_2019-05-27'.P2502>, <Cell 'Review Details_2019-05-27'.Q2502>, <Cell 'Review Details_2019-05-27'.R2502>, <Cell 'Review Details_2019-05-27'.S2502>, <Cell 'Review Details_2019-05-27'.T2502>, <Cell 'Review Details_2019-05-27'.U2502>, <Cell 'Review Details_2019-05-27'.V2502>, <Cell 'Review Details_2019-05-27'.W2502>, <Cell 'Review Details_2019-05-27'.X2502>, <Cell 'Review Details_2019-05-27'.Y2502>, <Cell 'Review Details_2019-05-27'.Z2502>, <Cell 'Review Details_2019-05-27'.AA2502>, <Cell 'Review Details_2019-05-27'.AB2502>, <Cell 'Review Details_2019-05-27'.AC2502>, <Cell 'Review Details_2019-05-27'.AD2502>, <Cell 'Review Details_2019-05-27'.AE2502>, <Cell 'Review Details_2019-05-27'.AF2502>)

# %% [markdown]
# #### Manipulate Data Using Python’s Default Data Structures

# %%
# First of all, have a look at the headers and see what information you care most about:
for value in sheet.iter_rows(min_row=1,max_row=1,values_only=True):
    print(value)
# Out:
# ('report_date', 'online_store', 'upc', 'retailer_product_code', 'brand', 'category', 'sub_category', 'product_description', 'review_date', 'review_rating', 'review_title', 'review_text', 'is_competitor', 'manufacturer', 'market', 'matched_keywords', 'time_of_publication', 'url', 'review_type', 'parent_review', 'manufacturers_response', 'dimension1', 'dimension2', 'dimension3', 'dimension4', 'dimension5', 'dimension6', 'dimension7', 'dimension8', 'verified_purchase', 'helpful_review_count', 'review_hash_id')

# %%
for value in sheet.iter_rows(min_row=2,
                             min_col=4,
                             max_col=7,
                             values_only=True):
        print(value)
# Out:
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B014DFNNRY', 'Marmite', 'Foods', 'Savoury')
# ('B014DFNNRY', 'Marmite', 'Foods', 'Savoury')
# ('B014DFKELC', 'Knorr', 'Foods', 'Savoury')
# ('B014G37I7E', 'Cif', 'Homecare', 'HHC')
# ('B014DFNNRY', 'Marmite', 'Foods', 'Savoury')
# ('B014DFNNRY', 'Marmite', 'Foods', 'Savoury')
# ('B014DFKELC', 'Knorr', 'Foods', 'Savoury')
# ('B0151I60Z4', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFKXKY', 'Knorr', 'Foods', 'Savoury')
# ('B014G2LG1E', 'Knorr', 'Foods', 'Savoury')
# ('B0151I60Z4', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2Y57G', 'TRESemmé', 'Personal Care', 'Hair')
# ('B004PU04CA', 'Cif', 'Homecare', 'Household Care')
# ('B00OQ84AW6', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014G50572', 'Domestos', 'Homecare', 'Household Care')
# ('B0142CIRB0', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014G2WPGY', 'Dove', 'Personal Care', 'Hair')
# ('B014G35AW4', 'Vaseline', 'Personal Care', 'Skin Care')
# ('B017GS8KEQ', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B014G2WPGY', 'Dove', 'Personal Care', 'Hair')
# ('B017GS8KEQ', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B018M7GERK', 'PG tips', 'Refreshment', 'Tea and Soy & Fruit Beverages')
# (15093011, 'Badedas', 'Personal Care', 'Skin Cleansing')
# ('B06VVP78MF', 'Comfort', 'Homecare', 'Laundry')
# ('B0151I60Z4', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B0151I60Z4', 'Dove Men+Care', 'Personal Care', 'Deos')
# (5411116, 'Magnum', 'Refreshment', 'Ice Cream')
# (4820843, 'Vaseline', 'Personal Care', 'Skin Care')
# (4820843, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# ('B017VWDSAS', 'Persil', 'Homecare', 'Laundry')
# (4820843, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deos')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# ('B01B4FMP2A', 'Alberto Balsam', 'Personal Care', 'Hair Care')
# ('B004K557YU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deos')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# (14880011, "Colman's", 'Foods', 'Savoury')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014PEJ48K', 'Persil', 'Homecare', 'Laundry')
# ('B014PEJ48K', 'Persil', 'Homecare', 'Laundry')
# ('B014PEJ48K', 'Persil', 'Homecare', 'Laundry')
# ('B014PEJ48K', 'Persil', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair Care')
# (2192604, 'Simple', 'Personal Care', 'Skin Care')
# (11125011, 'Marmite', 'Foods', 'Other Foods')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ85YHG', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PHTBG', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PLAQ6', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7RGSWK', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OTRIFPC', 'Simple', 'Personal Care', 'Skin Care')
# ('B003UU59QW', 'Marmite', 'Foods', 'Other Foods')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B003UU59QW', 'Marmite', 'Foods', 'Other Foods')
# (722135, 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# (279100011, 'Domestos', 'Homecare', 'Household Care')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B005RYCTU8', 'Pot Noodle', 'Foods', 'Savoury')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B006EHVDWW', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PHTBG', 'Dove', 'Personal Care', 'Skin Cleansing')
# (3184888, "Hellmann's", 'Foods', 'Dressings')
# (8371, "Hellmann's", 'Foods', 'Dressings')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DF8Z68', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (56134011, "Hellmann's", 'Foods', 'Dressings')
# ('B00OTRIFPC', 'Simple', 'Personal Care', 'Skin Care')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0015SXSKK', 'Vaseline', 'Personal Care', 'Skin Care')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PLAQ6', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014G36LGI', 'Domestos', 'Homecare', 'Household Care')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# (306586011, 'Persil', 'Homecare', 'Laundry')
# (29000011, 'Solero', 'Refreshment', 'Ice Cream')
# (2007571, "Hellmann's", 'Foods', 'Dressings')
# (2167602, "Hellmann's", 'Foods', 'Dressings')
# (2544274, "Hellmann's", 'Foods', 'Dressings')
# (7010738, "Hellmann's", 'Foods', 'Dressings')
# (7245898, "Hellmann's", 'Foods', 'Dressings')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# ('B003E6XD2E', 'Radox', 'Personal Care', 'Skin Cleansing')
# ('B00CLN9AOG', 'Domestos', 'Homecare', 'Household Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B075K3D4CG', 'Surf & Comfort', 'Homecare', 'Laundry')
# ('B075V65RMK', 'Bovril', 'Foods', 'Savoury')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# (802751, 'Simple', 'Personal Care', 'Skin Care')
# (306585011, 'Persil', 'Homecare', 'Laundry')
# (346448011, 'Comfort', 'Homecare', 'Laundry')
# (11125011, 'Marmite', 'Foods', 'Other Foods')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFL740', 'Knorr', 'Foods', 'Savoury')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# (6536708, 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B0015SXSKK', 'Vaseline', 'Personal Care', 'Skin Care')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B01GJEBE82', 'Simple', 'Personal Care', 'Hair Care')
# ('B014DFKO4E', 'Knorr', 'Foods', 'Savoury')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# (29000011, 'Solero', 'Refreshment', 'Ice Cream')
# (59222011, 'Simple', 'Personal Care', 'Hair Care')
# ('B00OTT5PEO', 'VO5', 'Personal Care', 'Hair Care')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# ('B003WUUB1S', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ85YHG', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B01FDSUGRK', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# (528642, 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B014G50572', 'Domestos', 'Homecare', 'Household Care')
# ('B014DFKXKY', 'Knorr', 'Foods', 'Savoury')
# ('B0151I60Z4', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFKO4E', 'Knorr', 'Foods', 'Savoury')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014G2UJLM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DF6204', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DF520A', 'Cif', 'Homecare', 'Household Care')
# ('B079JLTQ94', 'Comfort', 'Homecare', 'Laundry')
# ('B079JLTQ94', 'Comfort', 'Homecare', 'Laundry')
# ('B079JLTQ94', 'Comfort', 'Homecare', 'Laundry')
# (6512453, 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (7220928, 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# (7733636, 'Magnum', 'Refreshment', 'Ice Cream')
# (7454723, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (7733628, 'Magnum', 'Refreshment', 'Ice Cream')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# (7883548, 'Simple', 'Personal Care', 'Skin Care')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# ('B005RYCTU8', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00OQ3BX58', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OTT5T1S', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B0152X4G5E', 'Dove', 'Personal Care', 'Skin Care')
# ('B0152X4GQS', 'Dove', 'Personal Care', 'Skin Care')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B014G37I7E', 'Cif', 'Homecare', 'Household Care')
# (346448011, 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# (10305011, 'Heartbrand', 'Refreshment', 'Ice Cream')
# (11074011, "Colman's", 'Foods', 'Dressings')
# (13240011, 'PG tips', 'Refreshment', 'Tea and Soy & Fruit Beverages')
# (31020011, 'Domestos', 'Homecare', 'Household Care')
# (310405011, 'Alberto Balsam', 'Personal Care', 'Hair Care')
# ('B000NJUM5Q', 'Domestos', 'Homecare', 'Household Care')
# ('B006EHVDWW', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B014G2LG1E', 'Knorr', 'Foods', 'Savoury')
# ('B014G2RG3Q', 'Pot Noodle', 'Foods', 'Savoury')
# (34075011, 'Comfort', 'Homecare', 'Laundry')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# (18408011, 'Heartbrand', 'Refreshment', 'Ice Cream')
# (307451011, 'Comfort', 'Homecare', 'Laundry')
# (3588432, 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G36LGI', 'Domestos', 'Homecare', 'Household Care')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFL740', 'Knorr', 'Foods', 'Savoury')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B00OTT5PEO', 'VO5', 'Personal Care', 'Hair Care')
# ('B00H13MB9C', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00CLN9AOG', 'Domestos', 'Homecare', 'Household Care')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PHTBG', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B014G37I7E', 'Cif', 'Homecare', 'Household Care')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B003NTLPFY', "Hellmann's", 'Foods', 'Dressings')
# ('B003NTLPFY', "Hellmann's", 'Foods', 'Dressings')
# (307451011, 'Comfort', 'Homecare', 'Laundry')
# (2197529, 'Simple', 'Personal Care', 'Skin Care')
# (6333427, 'Dove', 'Personal Care', 'Skin Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B014G2QCEA', 'Maille', 'Foods', 'Dressings')
# ('B014DF7CNA', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B0043F4PIG', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B014G2SXGA', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# (307451011, 'Comfort', 'Homecare', 'Laundry')
# ('B014G2QQWS', "Colman's", 'Foods', 'Dressings')
# ('B014G2OJY0', "Hellmann's", 'Foods', 'Dressings')
# ('B0015SXSKK', 'Vaseline', 'Personal Care', 'Skin Care')
# ('B005RYCTU8', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B014G2ZCWS', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B014G50572', 'Domestos', 'Homecare', 'Household Care')
# ('B01BKOFGJE', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# (3836959, 'Badedas', 'Personal Care', 'Skin Cleansing')
# (5966159, 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# (13240011, 'PG tips', 'Refreshment', 'Tea and Soy & Fruit Beverages')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B003XWY0HQ', 'PG tips', 'Refreshment', 'Tea and Soy & Fruit Beverages')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# ('B07CMDGCLY', 'Persil', 'Homecare', 'Laundry')
# (2197529, 'Simple', 'Personal Care', 'Skin Care')
# (7821190, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2197421, 'Simple', 'Personal Care', 'Skin Care')
# ('B003WUUB1S', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B007XR2IOE', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00OQ85YHG', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# (13821011, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2197529, 'Simple', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B06WVL72Z9', 'Surf', 'Homecare', 'Laundry')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G36LGI', 'Domestos', 'Homecare', 'Household Care')
# ('B06W54N6ZC', 'Maille', 'Foods', 'Dressings')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B015J4NK1C', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B003NTLPFY', "Hellmann's", 'Foods', 'Dressings')
# ('B06XNNR2J2', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# (6083277, 'Vaseline', 'Personal Care', 'Skin Care')
# (34075011, 'Comfort', 'Homecare', 'Laundry')
# ('B003UU59QW', 'Marmite', 'Foods', 'Other Foods')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# (2244551, 'Simple', 'Personal Care', 'Skin Care')
# (722135, 'TRESemmé', 'Personal Care', 'Hair Care')
# (7892811, 'Magnum', 'Refreshment', 'Ice Cream')
# (4188339, 'Simple', 'Personal Care', 'Skin Care')
# (2490243, 'Dove', 'Personal Care', 'Skin Cleansing')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7897168, 'Simple', 'Personal Care', 'Skin Care')
# (7841613, 'Magnum', 'Refreshment', 'Ice Cream')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (7694874, 'Comfort', 'Homecare', 'Laundry')
# (7378216, 'Dove', 'Personal Care', 'Skin Cleansing')
# (7306420, 'Surf', 'Homecare', 'Laundry')
# (2319148, "Colman's", 'Foods', 'Savoury')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# (3727850, 'Simple', 'Personal Care', 'Skin Cleansing')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B075K3D4CG', 'Surf & Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# (4642422, 'Simple', 'Personal Care', 'Skin Care')
# (67211011, 'Dove', 'Personal Care', 'Skin Cleansing')
# (56134011, "Hellmann's", 'Foods', 'Dressings')
# (13117011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (311975011, 'Magnum', 'Refreshment', 'Ice Cream')
# (311975011, 'Magnum', 'Refreshment', 'Ice Cream')
# (74007011, 'Simple', 'Personal Care', 'Skin Care')
# (31014011, 'Domestos', 'Homecare', 'Household Care')
# (58820011, "Hellmann's", 'Foods', 'Dressings')
# ('B003XWY0HQ', 'PG tips', 'Refreshment', 'Tea and Soy & Fruit Beverages')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B01GJEBE78', 'Simple', 'Personal Care', 'Skin Care')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# (346448011, 'Comfort', 'Homecare', 'Laundry')
# (2244551, 'Simple', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B0787NHP5D', 'Simple', 'Personal Care', 'Skin Care')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B075GQBNNB', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B00CLN9AOG', 'Domestos', 'Homecare', 'Household Care')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair')
# ('B00OTRIFPC', 'Simple', 'Personal Care', 'Skin Care')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B07CKTFLRF', 'Persil', 'Homecare', 'Laundry')
# (23276011, 'Simple', 'Personal Care', 'Skin Care')
# (412575011, 'Simple', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B0152X4GQS', 'Dove', 'Personal Care', 'Skin Care')
# ('B0050DPCZA', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B0152X4G5E', 'Dove', 'Personal Care', 'Skin Care')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (2197510, 'Simple', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# ('B014G2QCEA', 'Maille', 'Foods', 'Dressings')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair')
# ('B00OTRIFPC', 'Simple', 'Personal Care', 'Skin Care')
# ('B003E6XD2E', 'Radox', 'Personal Care', 'Skin Cleansing')
# ('B0057EP8NI', 'Pot Noodle', 'Foods', 'Savoury')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B00YHMZBOM', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair')
# (307451011, 'Comfort', 'Homecare', 'Laundry')
# (279213011, 'Magnum', 'Refreshment', 'Ice Cream')
# (37907011, 'Marmite', 'Foods', 'Other Foods')
# (34082011, 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (262056011, 'Vaseline', 'Personal Care', 'Skin Care')
# (279211011, 'Magnum', 'Refreshment', 'Ice Cream')
# (279105011, 'Comfort', 'Homecare', 'Laundry')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (2521067, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2197502, 'Simple', 'Personal Care', 'Skin Care')
# (1132547, 'Simple', 'Personal Care', 'Skin Care')
# (1547623, 'Simple', 'Personal Care', 'Skin Care')
# (3851133, 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B017VWDSAS', 'Persil', 'Homecare', 'Laundry')
# ('B00WX2H08I', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B00FCAOZXG', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014DF5IRM', 'Cif', 'Homecare', 'Household Care')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B004K557YU', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B01BKOFGJE', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B0142CI67A', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2UJLM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2UJLM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2UJLM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B014DF9PMQ', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B014DF520A', 'Cif', 'Homecare', 'Household Care')
# ('B014DF8Z68', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B014G2ONG4', "Hellmann's", 'Foods', 'Dressings')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B079JLTTR6', 'Comfort', 'Homecare', 'Laundry')
# ('B079JLTTR6', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B0050DPCZA', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OTT5PEO', 'VO5', 'Personal Care', 'Hair Care')
# ('B0057EP8NI', 'Pot Noodle', 'Foods', 'Savoury')
# ('B0057EP8NI', 'Pot Noodle', 'Foods', 'Savoury')
# ('B003UU59QW', 'Marmite', 'Foods', 'Other Foods')
# ('B003UU59QW', 'Marmite', 'Foods', 'Other Foods')
# ('B000NJUM5Q', 'Domestos', 'Homecare', 'Household Care')
# ('B000NJUM5Q', 'Domestos', 'Homecare', 'Household Care')
# ('B00P1IECBE', 'TRESemmé', 'Personal Care', 'Hair')
# ('B00P7RGSWK', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PFDDM', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ3BX58', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ3BX58', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00OQ3BX58', 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# ('B00YHMZBOM', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00YHMZBOM', 'Pot Noodle', 'Foods', 'Savoury')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B00H13MB9C', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B01FDSUGRK', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair Care')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deodorants & Fragrances')
# ('B003WUUB1S', 'Dove', 'Personal Care', 'Deodorants & Fragrances')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deodorants & Fragrances')
# ('B00X7K5QNG', 'Pot Noodle', 'Foods', 'Savoury')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B073QRR4SC', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B07CZ66MJ2', 'Persil', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C28T7', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# ('B077YK7GLF', 'Comfort', 'Homecare', 'Laundry')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (28894011, 'Domestos', 'Homecare', 'Household Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (764640, 'Simple', 'Personal Care', 'Skin Care')
# (357396011, 'Magnum', 'Refreshment', 'Ice Cream')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (3190242, 'Simple', 'Personal Care', 'Skin Care')
# (309900, 'Vaseline', 'Personal Care', 'Skin Care')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (280931011, 'Lynx', 'Personal Care', 'Skin Cleansing')
# (279108011, 'Comfort', 'Homecare', 'Laundry')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (2197510, 'Simple', 'Personal Care', 'Skin Care')
# (3840719, 'TRESemmé', 'Personal Care', 'Hair')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (6083218, 'Vaseline', 'Personal Care', 'Skin Care')
# (280910011, 'Radox', 'Personal Care', 'Skin Cleansing')
# (34082011, 'Lynx', 'Personal Care', 'Deodorants & Fragrances')
# (28894011, 'Domestos', 'Homecare', 'Household Care')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# (10391011, "Ben & Jerry's", 'Refreshment', 'Ice Cream')
# ...
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07P75FTR3', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B075K3D4CG', 'Surf & Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deos')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deos')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07P75FTR3', 'Persil & Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B00OTRIFPC', 'Simple', 'Personal Care', 'Skin Care')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ3BX58', 'Lynx', 'Personal Care', 'Deos')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B003UU59QW', 'Marmite', 'Foods', 'Savoury')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B00P7PLAQ6', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deos')
# ('B00P7RGSWK', 'TRESemmé', 'Personal Care', 'Hair')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B0057EP8NI', 'Pot Noodle', 'Foods', 'Savoury')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ890AI', 'TRESemmé', 'Personal Care', 'Hair')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B003E6XD2E', 'Radox', 'Personal Care', 'Skin Cleansing')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B075K3D4CG', 'Surf & Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00YHMZBOM', 'Pot Noodle', 'Foods', 'Other Foods')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B007XR2IOE', 'Pot Noodle', 'Foods', 'Savoury')
# ('B00OQ3KBZG', 'Sure', 'Personal Care', 'Deos')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B07CCNVLXY', 'Persil', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B00P7PE82O', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B07CZGKTYB', 'Persil', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B07BNMH6S8', 'Persil', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B0731BX4SH', 'Comfort', 'Homecare', 'Laundry')
# ('B073V3SVM9', 'Surf', 'Homecare', 'Laundry')
# ('B07BNKMTMH', 'Persil', 'Homecare', 'Laundry')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B00YHMZBOM', 'Pot Noodle', 'Foods', 'Other Foods')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B0057EP8NI', 'Pot Noodle', 'Foods', 'Savoury')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B0731C6QG5', 'Comfort', 'Homecare', 'Laundry')
# ('B00OQ85N8Q', 'TRESemmé', 'Personal Care', 'Hair')
# ('B073QSDF1S', 'Comfort', 'Homecare', 'Laundry')
# ('B073QS4W7G', 'Comfort', 'Homecare', 'Laundry')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B077YLQ2R1', 'Comfort', 'Homecare', 'Laundry')
# ('B00TA3L6UG', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B07P75FTR3', 'Persil & Comfort', 'Homecare', 'Laundry')
# (533009, 'Sure', 'Personal Care', 'Deos')
# (949271, 'Simple', 'Personal Care', 'Skin Care')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (292303, 'St. Ives', 'Personal Care', 'Skin Care')
# (533009, 'Sure', 'Personal Care', 'Deos')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (593818, 'Radox', 'Personal Care', 'Skin Cleansing')
# (404241, 'Dove', 'Personal Care', 'Deos')
# (428302, 'TRESemmé', 'Personal Care', 'Hair')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (949305, 'Simple', 'Personal Care', 'Skin Care')
# (292303, 'St. Ives', 'Personal Care', 'Skin Care')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (540285, 'Dove', 'Personal Care', 'Deos')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (550106, 'Dove', 'Personal Care', 'Skin Care')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (244451, 'Vaseline', 'Personal Care', 'Personal Care')
# (451501, 'Simple', 'Personal Care', 'Skin Care')
# (185256, 'Dove', 'Personal Care', 'Skin Cleansing')
# (292338, 'St. Ives', 'Personal Care', 'Skin Care')
# (704258, 'Lynx', 'Personal Care', 'Deos')
# (604660, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2262706, 'TRESemmé', 'Personal Care', 'Hair')
# (2040925, 'St. Ives', 'Personal Care', 'Skin Care')
# (5176556, 'Dove', 'Personal Care', 'Skin Care')
# (5176556, 'Dove', 'Personal Care', 'Skin Care')
# (3373289, 'Dove', 'Personal Care', 'Skin Cleansing')
# (5176542, 'Dove', 'Personal Care', 'Skin Care')
# (4051564, 'Simple', 'Personal Care', 'Skin Care')
# (5119681, 'PG tips', 'Refreshment', 'Tea')
# (4669940, 'Comfort', 'Homecare', 'Laundry')
# (5368564, 'Dove', 'Personal Care', 'Skin Cleansing')
# (3760811, 'Comfort', 'Homecare', 'Laundry')
# (8348, 'Knorr', 'Foods', 'Savoury')
# (3988558, 'Knorr', 'Foods', 'Savoury')
# (5452070, 'Domestos', 'Homecare', 'HHC')
# (3760811, 'Comfort', 'Homecare', 'Laundry')
# (3204003, 'Dove', 'Personal Care', 'Deos')
# (6002045, 'Persil', 'Homecare', 'Laundry')
# (5020193, 'Comfort', 'Homecare', 'Laundry')
# (3760811, 'Comfort', 'Homecare', 'Laundry')
# (41581, 'Dove', 'Personal Care', 'Skin Cleansing')
# (5117112, 'Simple', 'Personal Care', 'Skin Care')
# (1929406, 'Pot Noodle', 'Foods', 'Savoury')
# (5020193, 'Comfort', 'Homecare', 'Laundry')
# (3368468, 'Knorr', 'Foods', 'Savoury')
# (6198613, 'Surf', 'Homecare', 'Laundry')
# (5009699, 'Dove', 'Personal Care', 'Skin Cleansing')
# (2867000, 'Dove', 'Personal Care', 'Deos')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B014DF520A', 'Cif', 'Homecare', 'HHC')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014DF520A', 'Cif', 'Homecare', 'HHC')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B06XNNR2J2', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014G36LGI', 'Domestos', 'Homecare', 'HHC')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B014DF9PMQ', 'Dove', 'Personal Care', 'Skin Cleansing')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B004K557YU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014DF520A', 'Cif', 'Homecare', 'HHC')
# ('B014DFQ5VA', 'Lynx', 'Personal Care', 'Skin Cleansing')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B00FCAOZXG', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014DF8Z68', 'Sure', 'Personal Care', 'Deos')
# ('B014DF8Z68', 'Sure', 'Personal Care', 'Deos')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014DF520A', 'Cif', 'Homecare', 'HHC')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B06XP9RLQM', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014DF5IRM', 'Cif', 'Homecare', 'HHC')
# ('B014G2ONG4', "Hellmann's", 'Foods', 'Dressings')
# ('B00FCAOZXG', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014DF5IRM', 'Cif', 'Homecare', 'HHC')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B00FCAOZXG', 'Pot Noodle', 'Foods', 'Savoury')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B014G2VTL6', 'Sure', 'Personal Care', 'Deos')
# ('B014G36LGI', 'Domestos', 'Homecare', 'HHC')
# ('B014G2UJLM', 'Lynx', 'Personal Care', 'Deos')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B015J4MXZ6', 'Comfort', 'Homecare', 'Laundry')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B015J4N8VY', 'Comfort', 'Homecare', 'Laundry')
# ('B00ZIWIWRS', 'TRESemmé', 'Personal Care', 'Hair')
# ('B014G2YBPC', 'TRESemmé', 'Personal Care', 'Hair')
# ('B06XP9RLQM', 'Pot Noodle', 'Foods', 'Savoury')
# ('B014DFDAOU', 'TRESemmé', 'Personal Care', 'Hair')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B0142CI6FC', 'Dove Men+Care', 'Personal Care', 'Deos')
# ('B014PEJY4E', 'Comfort', 'Homecare', 'Laundry')
# (37085011, 'Maille', 'Foods', 'Dressings')
# (42565011, 'Knorr', 'Foods', 'Savoury')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (251608011, 'Cif', 'Homecare', 'HHC')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (31751011, 'Calippo', 'Foods', 'Ice Cream')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (18770011, 'Simple', 'Personal Care', 'Skin Cleansing')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (307445011, 'Persil', 'Homecare', 'Laundry')
# (286622011, 'Simple', 'Personal Care', 'Skin Care')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (11120011, 'Bovril', 'Foods', 'Savoury')
# (13958011, "Hellmann's", 'Foods', 'Dressings')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')
# (399390011, 'Cornetto', 'Foods', 'Ice Cream')

# %%
# Now that you know how to get all the important product information you need, 
# let’s put that data into a dictionary:

import json
from openpyxl import load_workbook

workbook = load_workbook(filename="openpyxl1.xlsx")
sheet = workbook.active

products = {}

# Using the values_only because you want to return the cells' values
for row in sheet.iter_rows(min_row=2,
                           min_col=4,
                           max_col=7,
                           values_only=True):
    product_id = row[0]
    product = {
        "parent": row[1],
        "title": row[2],
        "category": row[3]
    }
    products[product_id] = product

# Using json here to be able to format the output for displaying later
print(json.dumps(products))
# Out:
# {"CHANDIGARH,": {"parent": "CHANDIGARH", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "PASIGHAT,": {"parent": "ARUNACHAL PRADESH", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "DEVARAKONDA,": {"parent": "TELANGANA", "title": "SKU:  AH-J3AO-R7DN", "category": "Pure 100% Leather Block Print Rectangular Jewelry Box with Mirror | Button Closure Multiple Utility Case (Shantiniketan Handicrafts) (Yellow)"}, "MUMBAI,": {"parent": "MAHARASHTRA", "title": "SKU:  2X-3C0F-KNJE", "category": "100% Leather Elephant Shaped Piggy Coin Bank | Block Printed West Bengal Handicrafts (Shantiniketan Art) | Money Bank for Kids | Children's Gift Ideas"}, "HOWRAH,": {"parent": "WEST BENGAL", "title": "SKU:  HH-FOWV-5YWO", "category": "Women's Trendy Pure Leather Clutch Purse | Leather Zipper Wallet"}, "ORAI,": {"parent": "UTTAR PRADESH", "title": "SKU:  TQ-OE6K-9DIK", "category": "Ultra Slim 100% Pure Leather Men's Wallet with Cash, Card and Coin Compartments | Jet Black Gent's Money Organizer with Cover (1 pc)"}, "BAREILLY,": {"parent": "UTTAR PRADESH", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "BENGALURU,": {"parent": "KARNATAKA", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "Bhilai,": {"parent": "CHHATTISGARH", "title": "SKU:  NU-CKZ5-4O49", "category": "Pure Leather Sling Bag with Multiple Pockets and Adjustable Strap | Shantiniketan Block Print Cross-Body Bags for Women (1 pc) (Yellow)"}, "FARIDABAD,": {"parent": "HARYANA", "title": "SKU:  2X-3C0F-KNJE", "category": "100% Leather Elephant Shaped Piggy Coin Bank | Block Printed West Bengal Handicrafts (Shantiniketan Art) | Money Bank for Kids | Children's Gift Ideas"}, "AGARTALA,": {"parent": "TRIPURA", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "COONOOR,": {"parent": "TAMIL NADU", "title": "SKU:  94-TSV3-EIW6", "category": "Bright and Colorful Shantiniketan Leather Elephant Piggy Coin Bank for Kids/Adults | Light-Weight Handcrafted Elephant Shaped Money Bank (Green, Large"}, "PUNE,": {"parent": "MAHARASHTRA", "title": "SKU:  DN-0WDX-VYOT", "category": "Women's Set of 5 Multicolor Pure Leather Single Lipstick Cases with Mirror, Handy and Compact Handcrafted Shantiniketan Block Printed Jewelry Boxes"}, "MANTHA,": {"parent": "MAHARASHTRA", "title": "SKU:  YJ-5CCT-M3PP", "category": "Pure Leather Camel Color Gent's Wallet with Coin Compartment and Card Holders | Men's Ultra Slim Money Organiser (1 pc)"}, "KOLKATA,": {"parent": "WEST BENGAL", "title": "SKU:  N8-YFZF-P74I", "category": "Stylish and Sleek Multiple Pockets 100 Percent Leather Shoulder Bag Contemporary Indian Leather Handicrafts for Women (Yellow) (BL335)"}, "MAHALINGPUR,": {"parent": "KARNATAKA", "title": "SKU:  TQ-OE6K-9DIK", "category": "Ultra Slim 100% Pure Leather Men's Wallet with Cash, Card and Coin Compartments | Jet Black Gent's Money Organizer with Cover (1 pc)"}, "HYDERABAD,": {"parent": "TELANGANA", "title": "SKU:  8V-OQ14-I63T", "category": "Bright and Colorful Shantiniketan Leather Elephant Piggy Coin Bank for Kids/Adults | Light-Weight Handcrafted Elephant Shaped Money Bank (Yellow, Larg"}, "MUMBAI 400 026,": {"parent": "MAHARASHTRA", "title": "SKU:  AY-Z7BT-BMVM", "category": "Women's Pure Leather Jhallar Clutch Purse with Zipper Compartments | Floral Block Print Ladies Wallet (Red ...

# %% [markdown]
# #### Appending New Data

# %%
workbook = load_workbook(filename="openpyxl.xlsx")
sheet = workbook.active

# Write what you want into a specific cell
sheet["C1"] = "writing ;)"

# Save the spreadsheet
workbook.save(filename="openpyxl.xlsx")

# %% [markdown]
# ### Writing Excel Spreadsheets With openpyxl

# %%
# It makes it easier to print all of your spreadsheet values by just calling print_rows().
def print_rows():
    for row in sheet.iter_rows(values_only=True):
        print(row)

# %% [markdown]
# #### Adding and Updating Cell Values

# %% [markdown]
# __CACH 1__

# %%
sheet["A1"] = "value"

# %% [markdown]
# __CACH 2__

# %%
cell = sheet["A1"]
cell
# Out:
# <Cell 'Sheet'.A1>

# %%
cell.value
# Out:
# 'value'

# %%
cell.value = "hey"
cell.value
# Out:
# 'hey'

# %% [markdown]
# The new value is only stored into the spreadsheet once you call workbook.save().

# %% [markdown]
# The openpyxl creates a cell when adding a value, if that cell didn’t exist before:

# %%
# Before, our spreadsheet has only 1 row
print_rows()
# Out:
# ('hey', 'world!', 'writing ;)')

# %%
# Try adding a value to row 10
sheet["B10"] = "test"
print_rows()

# As you can see, when trying to add a value to cell B10, 
# you end up with a tuple with 10 rows, just so you can have that test value.
# Out:
# ('hey', 'world!', 'writing ;)')
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, None, None)
# (None, 'test', None)

# %% [markdown]
# #### Managing Rows and Columns

# %%
workbook = Workbook() # create a new empty workbook.
sheet = workbook.active

sheet["A1"] = "hello" # add data to specific cells.
sheet["B1"] = "world!" # add data to specific cells.

workbook.save(filename="openpyxl.xlsx")
print_rows()
# Out:
# ('hello', 'world!')

# %%
# # Insert a column before the existing column 1 ("A")
sheet.insert_cols(idx=1)
print_rows()
# Out:
# (None, 'hello', 'world!')

# %%
# Insert 5 columns between column 2 ("B") and 3 ("C")
sheet.insert_cols(idx=3, amount=5)
print_rows()
# Out:
# (None, 'hello', None, None, None, None, None, 'world!')

# %%
# Delete the created columns
sheet.delete_cols(idx=3, amount=5)
sheet.delete_cols(idx=1)
print_rows()
# Out:
# ('hello', 'world!')

# %%
# Insert a new row in the beginning
sheet.insert_rows(idx=1)
print_rows()
# Out:
# (None, None)
# ('hello', 'world!')

# %%
# Insert 3 new rows in the beginning
sheet.insert_rows(idx=1, amount=3)
print_rows()
# Out:
# (None, None)
# (None, None)
# (None, None)
# (None, None)
# ('hello', 'world!')

# %%
# Delete the first 4 rows
sheet.delete_rows(idx=1, amount=4)
print_rows()
# Out:
# ('hello', 'world!')

# %% [markdown]
# The only thing you need to remember is that when inserting new data (rows or columns), the insertion happens before the idx parameter.
#
# So, if you do insert_rows(1), it inserts a new row before the existing first row.
#
# It’s the same for columns: when you call insert_cols(2), it inserts a new column right before the already existing second column (B).
#
# However, when deleting rows or columns, .delete_... deletes data starting from the index passed as an argument.
#
# For example, when doing delete_rows(2) it deletes row 2, and when doing delete_cols(3) it deletes the third column (C).

# %% [markdown]
# #### Managing Sheets

# %%
workbook = load_workbook(filename="openpyxl2.xlsx")
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27', 'Sheet3', 'Sheet1', 'Sheet2']

# %%
# You can select a sheet using its title
sheet3 = workbook['Sheet3']
sheet1 = workbook['Sheet1']
sheet2 = workbook['Sheet2']

# %%
# You can also change a sheet title very easily:
sheet3.title = "This is sheet 3"
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27', 'This is sheet 3', 'Sheet1', 'Sheet2']

# %%
# Create a sheet
nsheet = workbook.create_sheet("New sheet")
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27',
#  'This is sheet 3',
#  'Sheet1',
#  'Sheet2',
#  'New sheet']

# %%
# You can also define the position to create the sheet at
hr_sheet = workbook.create_sheet("HR",3)
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27',
#  'This is sheet 3',
#  'Sheet1',
#  'HR',
#  'Sheet2',
#  'New sheet']

# %%
# delete a sheet
workbook.remove(hr_sheet)
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27',
#  'This is sheet 3',
#  'Sheet1',
#  'Sheet2',
#  'New sheet']

# %%
workbook.remove(workbook['HR'])
workbook.sheetnames
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 workbook.remove(workbook['HR'])
#       2 workbook.sheetnames
#
# File d:\python build app\.venv\Lib\site-packages\openpyxl\workbook\workbook.py:287, in Workbook.__getitem__(self, key)
#     285     if sheet.title == key:
#     286         return sheet
# --> 287 raise KeyError("Worksheet {0} does not exist.".format(key))
#
# KeyError: 'Worksheet HR does not exist.'

# %%
# One other thing you can do is make duplicates of a sheet using copy_worksheet():
workbook.copy_worksheet(workbook['Sheet1'])
workbook.sheetnames
# Out:
# ['Review Details_2019-05-27',
#  'This is sheet 3',
#  'Sheet1',
#  'Sheet2',
#  'New sheet',
#  'Sheet1 Copy']

# %% [markdown]
# #### Freezing Rows and Columns

# %%
workbook = load_workbook(filename="openpyxl2.xlsx")
workbook.sheetnames # use workbook.sheetnames to see all the sheets you have available to work with
sheet = workbook.active 
sheet
# Out:
# <Worksheet "Review Details_2019-05-27">

# %%
sheet.freeze_panes = 'C1'
workbook.save("openpyxl2-frozen.xlsx")

# %% [markdown]
# If you open the sample_frozen.xlsx spreadsheet in your favorite spreadsheet editor, you’ll notice that row 1 and columns A and B are frozen and are always visible no matter where you navigate within the spreadsheet.

# %% [markdown]
# #### Adding Filters

# %% [markdown]
# You can use openpyxl to add filters and sorts to your spreadsheet. However, when you open the spreadsheet, the data won’t be rearranged according to these sorts and filters.
#
# At first, this might seem like a pretty useless feature, but when you’re programmatically creating a spreadsheet that is going to be sent and used by somebody else, it’s still nice to at least create the filters and allow people to use it afterward.

# %%
sheet.dimensions
# Out:
# 'A1:AF2502'

# %%
sheet.auto_filter.ref = 'A1:AF2502'
workbook.save(filename="openpyxl2_with_filters.xlsx")

# %% [markdown]
# #### Adding Formulas

# %%
from openpyxl.utils import FORMULAE
FORMULAE
# Out:
# frozenset({'ABS',
#            'ACCRINT',
#            'ACCRINTM',
#            'ACOS',
#            'ACOSH',
#            'AMORDEGRC',
#            'AMORLINC',
#            'AND',
#            'AREAS',
#            'ASC',
#            'ASIN',
#            'ASINH',
#            'ATAN',
#            'ATAN2',
#            'ATANH',
#            'AVEDEV',
#            'AVERAGE',
#            'AVERAGEA',
#            'AVERAGEIF',
#            'AVERAGEIFS',
#            'BAHTTEXT',
#            'BESSELI',
#            'BESSELJ',
#            'BESSELK',
#            'BESSELY',
#            'BETADIST',
#            'BETAINV',
#            'BIN2DEC',
#            'BIN2HEX',
#            'BIN2OCT',
#            'BINOMDIST',
#            'CEILING',
#            'CELL',
#            'CHAR',
#            'CHIDIST',
#            'CHIINV',
#            'CHITEST',
#            'CHOOSE',
#            'CLEAN',
#            'CODE',
#            'COLUMN',
#            'COLUMNS',
#            'COMBIN',
#            'COMPLEX',
#            'CONCATENATE',
#            'CONFIDENCE',
#            'CONVERT',
#            'CORREL',
#            'COS',
#            'COSH',
#            'COUNT',
#            'COUNTA',
#            'COUNTBLANK',
#            'COUNTIF',
#            'COUNTIFS',
#            'COUPDAYBS',
#            'COUPDAYS',
#            'COUPDAYSNC',
#            'COUPNCD',
#            'COUPNUM',
#            'COUPPCD',
#            'COVAR',
#            'CRITBINOM',
#            'CUBEKPIMEMBER',
#            'CUBEMEMBER',
#            'CUBEMEMBERPROPERTY',
#            'CUBERANKEDMEMBER',
#            'CUBESET',
#            'CUBESETCOUNT',
#            'CUBEVALUE',
#            'CUMIPMT',
#            'CUMPRINC',
#            'DATE',
#            'DATEDIF',
#            'DATEVALUE',
#            'DAVERAGE',
#            'DAY',
#            'DAYS360',
#            'DB',
#            'DCOUNT',
#            'DCOUNTA',
#            'DDB',
#            'DEC2BIN',
#            'DEC2HEX',
#            'DEC2OCT',
#            'DEGREES',
#            'DELTA',
#            'DEVSQ',
#            'DGET',
#            'DISC',
#            'DMAX',
#            'DMIN',
#            'DOLLAR',
#            'DOLLARDE',
#            'DOLLARFR',
#            'DPRODUCT',
#            'DSTDEV',
#            'DSTDEVP',
#            'DSUM',
#            'DURATION',
#            'DVAR',
#            'DVARP',
#            'ECMA.CEILING',
#            'EDATE',
#            'EFFECT',
#            'EOMONTH',
#            'ERF',
#            'ERFC',
#            'ERROR.TYPE',
#            'EVEN',
#            'EXACT',
#            'EXP',
#            'EXPONDIST',
#            'FACT',
#            'FACTDOUBLE',
#            'FALSE',
#            'FDIST',
#            'FIND',
#            'FINDB',
#            'FINV',
#            'FISHER',
#            'FISHERINV',
#            'FIXED',
#            'FLOOR',
#            'FORECAST',
#            'FREQUENCY',
#            'FTEST',
#            'FV',
#            'FVSCHEDULE',
#            'GAMMADIST',
#            'GAMMAINV',
#            'GAMMALN',
#            'GCD',
#            'GEOMEAN',
#            'GESTEP',
#            'GETPIVOTDATA',
#            'GROWTH',
#            'HARMEAN',
#            'HEX2BIN',
#            'HEX2DEC',
#            'HEX2OCT',
#            'HLOOKUP',
#            'HOUR',
#            'HYPERLINK',
#            'HYPGEOMDIST',
#            'IF',
#            'IFERROR',
#            'IMABS',
#            'IMAGINARY',
#            'IMARGUMENT',
#            'IMCONJUGATE',
#            'IMCOS',
#            'IMDIV',
#            'IMEXP',
#            'IMLN',
#            'IMLOG10',
#            'IMLOG2',
#            'IMPOWER',
#            'IMPRODUCT',
#            'IMREAL',
#            'IMSIN',
#            'IMSQRT',
#            'IMSUB',
#            'IMSUM',
#            'INDEX',
#            'INDIRECT',
#            'INFO',
#            'INT',
#            'INTERCEPT',
#            'INTRATE',
#            'IPMT',
#            'IRR',
#            'ISBLANK',
#            'ISERR',
#            'ISERROR',
#            'ISEVEN',
#            'ISLOGICAL',
#            'ISNA',
#            'ISNONTEXT',
#            'ISNUMBER',
#            'ISO.CEILING',
#            'ISODD',
#            'ISPMT',
#            'ISREF',
#            'ISTEXT',
#            'JIS',
#            'KURT',
#            'LARGE',
#            'LCM',
#            'LEFT',
#            'LEFTB',
#            'LEN',
#            'LENB',
#            'LINEST',
#            'LN',
#            'LOG',
#            'LOG10',
#            'LOGEST',
#            'LOGINV',
#            'LOGNORMDIST',
#            'LOOKUP',
#            'LOWER',
#            'MATCH',
#            'MAX',
#            'MAXA',
#            'MDETERM',
#            'MDURATION',
#            'MEDIAN',
#            'MID',
#            'MIDB',
#            'MIN',
#            'MINA',
#            'MINUTE',
#            'MINVERSE',
#            'MIRR',
#            'MMULT',
#            'MOD',
#            'MODE',
#            'MONTH',
#            'MROUND',
#            'MULTINOMIAL',
#            'N',
#            'NA',
#            'NEGBINOMDIST',
#            'NETWORKDAYS',
#            'NETWORKDAYS.INTL',
#            'NOMINAL',
#            'NORMDIST',
#            'NORMINV',
#            'NORMSDIST',
#            'NORMSINV',
#            'NOT',
#            'NOW',
#            'NPER',
#            'NPV',
#            'OCT2BIN',
#            'OCT2DEC',
#            'OCT2HEX',
#            'ODD',
#            'ODDFPRICE',
#            'ODDFYIELD',
#            'ODDLPRICE',
#            'ODDLYIELD',
#            'OFFSET',
#            'OR',
#            'PEARSON',
#            'PERCENTILE',
#            'PERCENTRANK',
#            'PERMUT',
#            'PHONETIC',
#            'PI',
#            'PMT',
#            'POISSON',
#            'POWER',
#            'PPMT',
#            'PRICE',
#            'PRICEDISC',
#            'PRICEMAT',
#            'PROB',
#            'PRODUCT',
#            'PROPER',
#            'PV',
#            'QUARTILE',
#            'QUOTIENT',
#            'RADIANS',
#            'RAND',
#            'RANDBETWEEN',
#            'RANK',
#            'RATE',
#            'RECEIVED',
#            'REPLACE',
#            'REPLACEB',
#            'REPT',
#            'RIGHT',
#            'RIGHTB',
#            'ROMAN',
#            'ROUND',
#            'ROUNDDOWN',
#            'ROUNDUP',
#            'ROW',
#            'ROWS',
#            'RSQ',
#            'RTD',
#            'SEARCH',
#            'SEARCHB',
#            'SECOND',
#            'SERIESSUM',
#            'SIGN',
#            'SIN',
#            'SINH',
#            'SKEW',
#            'SLN',
#            'SLOPE',
#            'SMALL',
#            'SQRT',
#            'SQRTPI',
#            'STANDARDIZE',
#            'STDEV STDEVA',
#            'STDEVP',
#            'STDEVPA STEYX',
#            'SUBSTITUTE',
#            'SUBTOTAL',
#            'SUM',
#            'SUMIF',
#            'SUMIFS',
#            'SUMPRODUCT',
#            'SUMSQ',
#            'SUMX2MY2',
#            'SUMX2PY2',
#            'SUMXMY2',
#            'SYD',
#            'T',
#            'TAN',
#            'TANH',
#            'TBILLEQ',
#            'TBILLPRICE',
#            'TBILLYIELD',
#            'TDIST',
#            'TEXT',
#            'TIME',
#            'TIMEVALUE',
#            'TINV',
#            'TODAY',
#            'TRANSPOSE',
#            'TREND',
#            'TRIM',
#            'TRIMMEAN',
#            'TRUE ADDRESS',
#            'TRUNC',
#            'TTEST',
#            'TYPE',
#            'UPPER',
#            'VALUE',
#            'VAR',
#            'VARA',
#            'VARP',
#            'VARPA',
#            'VDB',
#            'VLOOKUP',
#            'WEEKDAY',
#            'WEEKNUM',
#            'WEIBULL',
#            'WORKDAY ',
#            'WORKDAY.INTL',
#            'XIRR',
#            'XNPV',
#            'YEAR',
#            'YEARFRAC',
#            'YIELD',
#            'YIELDDISC',
#            'YIELDMAT',
#            'ZTEST'})

# %%
workbook = load_workbook(filename="openpyxl.xlsx")
workbook.sheetnames # use workbook.sheetnames to see all the sheets you have available to work with
sheet = workbook.active 
sheet
# Out:
# <Worksheet "Sheet">

# %%
# AVERAGE FORMULA
sheet["C2"] = "=AVERAGE(A2:A6)"
workbook.save(filename="openpyxl_formulas.xlsx")

# %%
# COUNTIF FORMULA
sheet["C3"] = '=COUNTIF(A2:B6, ">100")'
workbook.save(filename="openpyxl_formulas.xlsx")

# %% [markdown]
# You’ll have to make sure that the strings within a formula are always in double quotes, so you either have to use single quotes around the formula like in the example above or you’ll have to escape the double quotes inside the formula: "=COUNTIF(I2:I100, \">0\")".

# %% [markdown]
# #### Adding Styles

# %%
# Import necessary style classes
from openpyxl.styles import Font, Color, Alignment, Border, Side

# Create a few styles
bold_font = Font(bold=True)
big_red_text = Font(color="00FF0000", size=20)
center_aligned_text = Alignment(horizontal="center")
double_border_side = Side(border_style="double")
square_border = Border(top=double_border_side,
                       right=double_border_side,
                       bottom=double_border_side,
                       left=double_border_side)

# Style some cells!
sheet["A2"].font = bold_font
sheet["A3"].font = big_red_text
sheet["A4"].alignment = center_aligned_text
sheet["A5"].border = square_border
workbook.save(filename="openpyxl_styles.xlsx")

# %% [markdown]
# Note: For the colors, you can also use HEX codes instead by doing Font(color="C70E0F").

# %%
# You can also combine styles by simply adding them to the cell at the same time:

# Reusing the same styles from the example above
sheet["A6"].alignment = center_aligned_text
sheet["A6"].font = big_red_text
sheet["A6"].border = square_border
workbook.save(filename="openpyxl_styles.xlsx")

# %% [markdown]
# When you want to apply multiple styles to one or several cells, you can use a NamedStyle class instead, which is like a style template that you can use over and over again. Have a look at the example below:

# %%
from openpyxl.styles import NamedStyle

# Let's create a style template for the header row
header = NamedStyle(name="header")
header.font = Font(bold=True)
header.border = Border(bottom=Side(border_style="thin"))
header.alignment = Alignment(horizontal="center", vertical="center")

# Now let's apply this to all first row (header) cells
header_row = sheet[1]
for cell in header_row:
    cell.style = header

workbook.save(filename="openpyxl_styles.xlsx")

# If you open the spreadsheet now, you should see that its first row is bold, 
# the text is aligned to the center, and there’s a small bottom border!

# %% [markdown]
# #### Conditional Formatting

# %%
from openpyxl.styles import PatternFill
from openpyxl.styles.differential import DifferentialStyle
from openpyxl.formatting.rule import Rule

red_background = PatternFill(fgColor="00FF0000")
diff_style = DifferentialStyle(fill=red_background)
rule = Rule(type="expression", dxf=diff_style)
rule.formula = ["$A1<3"]
sheet.conditional_formatting.add("A1:O100", rule)
workbook.save("openpyxl_conditional_formatting.xlsx")

# %% [markdown]
# DifferentialStyle is quite similar to NamedStyle, which you already saw above, and it’s used to aggregate multiple styles such as fonts, borders, alignment, and so forth.
#
# Rule is responsible for selecting the cells and applying the styles if the cells match the rule’s logic.
#
# Using a Rule object, you can create numerous conditional formatting scenarios.
#
# However, for simplicity sake, the openpyxl package offers 3 built-in formats that make it easier to create a few common conditional formatting patterns. These built-ins are:
#
#     ColorScale
#
#     IconSet
#
#     DataBar

# %%
# The ColorScale gives you the ability to create color gradients:
from openpyxl.formatting.rule import ColorScaleRule
color_scale_rule = ColorScaleRule(start_type="min",
                                      start_color="00FF0000",  # Red
                                      end_type="max",
                                      end_color="0000FF00")  # Green

# Again, let's add this gradient to the star ratings, column "H"
sheet.conditional_formatting.add("H2:H100", color_scale_rule)
workbook.save(filename="openpyxl_conditional_formatting_color_scale.xlsx")

# %%
# You can also add a third color and make two gradients instead:
from openpyxl.formatting.rule import ColorScaleRule
color_scale_rule = ColorScaleRule(start_type="num",
                                  start_value=1,
                                  start_color="00FF0000",  # Red
                                  mid_type="num",
                                  mid_value=3,
                                  mid_color="00FFFF00",  # Yellow
                                  end_type="num",
                                  end_value=5,
                                  end_color="0000FF00")  # Green

# Again, let's add this gradient to the star ratings, column "H"
sheet.conditional_formatting.add("H2:H100", color_scale_rule)
workbook.save(filename="openpyxl_conditional_formatting_color_scale_3.xlsx")

# %%
# The IconSet allows you to add an icon to the cell according to its value:

from openpyxl.formatting.rule import IconSetRule

icon_set_rule = IconSetRule("5Arrows", "num", [1, 2, 3, 4, 5])
sheet.conditional_formatting.add("H2:H100", icon_set_rule)
workbook.save("openpyxl_conditional_formatting_icon_set.xlsx")

# %%
# Finally, the DataBar allows you to create progress bars:
from openpyxl.formatting.rule import DataBarRule

data_bar_rule = DataBarRule(start_type="num",
                            start_value=1,
                            end_type="num",
                            end_value="5",
                            color="0000FF00")  # Green
sheet.conditional_formatting.add("H2:H100", data_bar_rule)
workbook.save("openpyxl_conditional_formatting_data_bar.xlsx")

# %% [markdown]
# #### Adding Images

# %% [markdown]
# __pip install Pillow__

# %%
from openpyxl import load_workbook
from openpyxl.drawing.image import Image

# Let's use the hello_world spreadsheet since it has less data
workbook = load_workbook(filename="openpyxl.xlsx")
sheet = workbook.active

logo = Image("logo.png")

# A bit of resizing to not fill the whole spreadsheet with the logo
logo.height = 150
logo.width = 150

sheet.add_image(logo, "A3")
workbook.save(filename="openpyxl_logo.xlsx")

# The image’s left top corner is on the cell you chose, in this case, A3.

# %% [markdown]
# #### Adding Pretty Charts

# %%
from openpyxl import Workbook
from openpyxl.chart import BarChart, Reference

workbook = Workbook()
sheet = workbook.active

# Let's create some sample sales data
rows = [
    ["Product", "Online", "Store"],
    [1, 30, 45],
    [2, 40, 30],
    [3, 40, 25],
    [4, 50, 30],
    [5, 30, 25],
    [6, 25, 35],
    [7, 20, 40],
]

for row in rows:
    sheet.append(row)

# %%
# Now you’re going to start by creating a bar chart that displays the total number of sales per product:

chart = BarChart()
data = Reference(worksheet=sheet,
                 min_row=1,
                 max_row=8,
                 min_col=2,
                 max_col=3)

chart.add_data(data, titles_from_data=True)
sheet.add_chart(chart, "E2")

workbook.save("chart.xlsx")

# Like with images, the top left corner of the chart is on the cell you added the chart to. 
# In your case, it was on cell E2.

# %% [markdown]
# Try creating a line chart instead, changing the data a bit:

# %%
import random
from openpyxl import Workbook
from openpyxl.chart import LineChart, Reference

workbook = Workbook()
sheet = workbook.active

# Let's create some sample sales data
rows = [
    ["", "January", "February", "March", "April",
    "May", "June", "July", "August", "September",
     "October", "November", "December"],
    [1, ],
    [2, ],
    [3, ],
]

for row in rows:
    sheet.append(row)

for row in sheet.iter_rows(min_row=2,
                           max_row=4,
                           min_col=2,
                           max_col=13):
    for cell in row:
        cell.value = random.randrange(5, 100)

# %%
chart = LineChart()
data = Reference(worksheet=sheet,
                 min_row=2,
                 max_row=4,
                 min_col=1,
                 max_col=13)

chart.add_data(data, from_rows=True, titles_from_data=True)
sheet.add_chart(chart, "C6")

workbook.save("line_chart.xlsx")

# One thing to keep in mind here is the fact that you’re using from_rows=True when adding the data. 
# This argument makes the chart plot row by row instead of column by column.

# In your sample data, you see that each product has a row with 12 values (1 column per month). 
# That’s why you use from_rows. If you don’t pass that argument, by default, 
# the chart tries to plot by column, and you’ll get a month-by-month comparison of sales.

# Another difference that has to do with the above argument change is the fact that our Reference 
# now starts from the first column, min_col=1, instead of the second one. 
# This change is needed because the chart now expects the first column to have the titles.

# %% [markdown]
# There are a couple of other things you can also change regarding the style of the chart. For example, you can add specific categories to the chart:

# %%
cats = Reference(worksheet=sheet,
                 min_row=1,
                 max_row=1,
                 min_col=2,
                 max_col=13)
chart.set_categories(cats)

# %% [markdown]
# Another thing you can do to improve the chart readability is to add an axis. You can do it using the attributes x_axis and y_axis:

# %%
chart.x_axis.title = "Months"
chart.y_axis.title = "Sales (per unit)"

# %% [markdown]
# There is also a way to style your chart by using Excel’s default ChartStyle property. In this case, you have to choose a number between 1 and 48. Depending on your choice, the colors of your chart change as well:

# %%
# You can play with this by choosing any number between 1 and 48
chart.style = 24

# %% [markdown]
# Here’s the full code used to generate the line chart with categories, axis titles, and style:

# %%
import random
from openpyxl import Workbook
from openpyxl.chart import LineChart, Reference

workbook = Workbook()
sheet = workbook.active

# Let's create some sample sales data
rows = [
    ["", "January", "February", "March", "April",
    "May", "June", "July", "August", "September",
     "October", "November", "December"],
    [1, ],
    [2, ],
    [3, ],
]

for row in rows:
    sheet.append(row)

for row in sheet.iter_rows(min_row=2,
                           max_row=4,
                           min_col=2,
                           max_col=13):
    for cell in row:
        cell.value = random.randrange(5, 100)

# Create a LineChart and add the main data
chart = LineChart()
data = Reference(worksheet=sheet,
                           min_row=2,
                           max_row=4,
                           min_col=1,
                           max_col=13)
chart.add_data(data, titles_from_data=True, from_rows=True)

# Add categories to the chart
cats = Reference(worksheet=sheet,
                 min_row=1,
                 max_row=1,
                 min_col=2,
                 max_col=13)
chart.set_categories(cats)

# Rename the X and Y Axis
chart.x_axis.title = "Months"
chart.y_axis.title = "Sales (per unit)"

# Apply a specific Style
chart.style = 24

# Save!
sheet.add_chart(chart, "C6")
workbook.save("line_chart.xlsx")
