# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", 50)

# %%
# this would be a huge pain to load into a database
mo = pd.read_csv('mariano-rivera.csv')
mo.tail()
# Out:
#     Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF  CG  SHO  SV    IP   H  \
# 14  2009   39  NYY  AL  3  3  0.500  1.76  66   0  55   0    0  44  66.1  48
# 15  2010   40  NYY  AL  3  3  0.500  1.80  61   0  55   0    0  33  60.0  39
# 16  2011   41  NYY  AL  1  2  0.333  1.91  64   0  54   0    0  44  61.1  47
# 17  2012   42  NYY  AL  1  1  0.500  2.16   9   0   9   0    0   5   8.1   6
# 18  2013   43  NYY  AL  6  2  0.750  2.11  64   0  60   0    0  44  64.0  58
#
#      R  ER  HR  BB  IBB  SO  HBP  BK  WP   BF  ERA+   WHIP  H/9  HR/9  BB/9  \
# 14  14  13   7  12    1  72    1   0   1  257   262  0.905  6.5   0.9   1.6
# 15  14  12   2  11    3  45    5   0   0  230   241  0.833  5.9   0.3   1.7
# 16  13  13   3   8    2  60    2   0   1  233   226  0.897  6.9   0.4   1.2
# 17   2   2   0   2    2   8    0   0   0   32   203  0.960  6.5   0.0   2.2
# 18  16  15   6   9    3  54    1   0   0  256   192  1.047  8.2   0.8   1.3
#
#     SO/9  SO/BB    Awards
# 14   9.8   6.00  ASMVP-14
# 15   6.8   4.09        AS
# 16   8.8   7.50   ASCYA-8
# 17   8.6   4.00       NaN
# 18   7.6   6.00        AS

# %%
clean = lambda s: s.replace('$', '')[:-1] if '.' in s else s.replace('$', '') # a lot going on here
url = 'https://raw.github.com/gjreda/best-sandwiches/master/data/best-sandwiches-geocode.tsv'
sandwiches = pd.read_table(url, sep='\t', converters={'price': lambda s: float(clean(s))})
sandwiches.head(3)
# Out:
#    rank           sandwich   restaurant  \
# 0     1                BLT  Old Oak Tap
# 1     2      Fried Bologna    Au Cheval
# 2     3  Woodland Mushroom         Xoco
#
#                                          description  price  \
# 0  The B is applewood smoked&mdash;nice and snapp...   10.0
# 1  Thought your bologna-eating days had retired w...    9.0
# 2  Leave it to Rick Bayless and crew to come up w...    9.5
#
#                 address     city         phone              website  \
# 0  2109 W. Chicago Ave.  Chicago  773-772-0406     theoldoaktap.com
# 1   800 W. Randolph St.  Chicago  312-929-4580  aucheval.tumblr.com
# 2      445 N. Clark St.  Chicago  312-334-3688      rickbayless.com
#
#                     full_address  \
# 0  2109 W. Chicago Ave., Chicago
# 1   800 W. Randolph St., Chicago
# 2      445 N. Clark St., Chicago
#
#                                   formatted_address        lat        lng
# 0  2109 West Chicago Avenue, Chicago, IL 60622, USA  41.895734 -87.679960
# 1  800 West Randolph Street, Chicago, IL 60607, USA  41.884672 -87.647754
# 2    445 North Clark Street, Chicago, IL 60654, USA  41.890602 -87.630925

# %%
gh = pd.read_json('https://api.github.com/repos/pydata/pandas/issues?per_page=3')
gh[['body', 'created_at', 'title', 'url']].head(3)
# Out:
#                                                 body  \
# 0  Currently, on the main branch with the PDEP-6 ...
# 1  ### Pandas version checks\n\n- [X] I have chec...
# 2  Backport PR #54586: REF: Refactor conversion o...
#
#                  created_at  \
# 0 2023-08-21 12:37:49+00:00
# 1 2023-08-21 11:15:29+00:00
# 2 2023-08-21 09:18:37+00:00
#
#                                                title  \
# 0  PDEP-6: special case (allow) upcasting to floa...
# 1  BUG: read_pickle omit timezone when reading ol...
# 2  Backport PR #54586 on branch 2.1.x (REF: Refac...
#
#                                                  url
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...

# %%
clip = pd.read_clipboard()
clip.head()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:397, in PythonParser._infer_columns(self)
#     396 try:
# --> 397     line = self._buffered_line()
#     399     while self.line_pos <= hr:
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:630, in PythonParser._buffered_line(self)
#     629 else:
# --> 630     return self._next_line()
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:731, in PythonParser._next_line(self)
#     730 while True:
# --> 731     orig_line = self._next_iter_line(row_num=self.pos + 1)
#     732     self.pos += 1
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:795, in PythonParser._next_iter_line(self, row_num)
#     794 assert self.data is not None
# --> 795 line = next(self.data)
#     796 # for mypy
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# EmptyDataError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 clip = pd.read_clipboard()
#       2 clip.head()
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\clipboards.py:110, in read_clipboard(sep, dtype_backend, **kwargs)
#     104 elif len(sep) > 1 and kwargs.get("engine") == "c":
#     105     warnings.warn(
#     106         "read_clipboard with regex separator does not work properly with c engine.",
#     107         stacklevel=find_stack_level(),
#     108     )
# --> 110 return read_csv(StringIO(text), sep=sep, dtype_backend=dtype_backend, **kwargs)
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1679, in TextFileReader._make_engine(self, f, engine)
#    1676     raise ValueError(msg)
#    1678 try:
# -> 1679     return mapping[engine](f, **self.options)
#    1680 except Exception:
#    1681     if self.handles is not None:
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:124, in PythonParser.__init__(self, f, **kwds)
#     118 self._col_indices: list[int] | None = None
#     119 columns: list[list[Scalar | None]]
#     120 (
#     121     columns,
#     122     self.num_original_columns,
#     123     self.unnamed_cols,
# --> 124 ) = self._infer_columns()
#     126 # Now self.columns has the set of columns that we will process.
#     127 # The original set is stored in self.original_columns.
#     128 # error: Cannot determine type of 'index_names'
#     129 (
#     130     self.columns,
#     131     self.index_names,
#    (...)
#     136     self.index_names,  # type: ignore[has-type]
#     137 )
#
# File d:\python build app\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:425, in PythonParser._infer_columns(self)
#     422         return columns, num_original_columns, unnamed_cols
#     424     if not self.names:
# --> 425         raise EmptyDataError("No columns to parse from file") from err
#     427     line = self.names[:]
#     429 this_columns: list[Scalar | None] = []
#
# EmptyDataError: No columns to parse from file

# %%
# All of this is basically the same as it would be with Postgres, MySQL, or any other database
# Just pass pandas a connection object and it'll take care of the rest.
from pandas.io import sql
import sqlite3
conn = sqlite3.connect('towed.db')
query = "SELECT * FROM towed"
towed = sql.read_sql(query, con=conn, parse_dates={'date':'%m/%d/%Y'})
towed.head()
# Out:
#         date  make style model color    plate state             towed_to  \
# 0 2014-11-18  FORD    LL         BLK  S105053    IL        10300 S. Doty
# 1 2014-11-18  HOND    4D   ACC   BLK  S415270    IL  400 E. Lower Wacker
# 2 2014-11-18  CHRY    VN         SIL  V847641    IL    701 N. Sacramento
# 3 2014-11-18  HYUN    4D         SIL  N756530    IL  400 E. Lower Wacker
# 4 2014-11-18  TOYT    4D         WHI  K702211    IL  400 E. Lower Wacker
#
#     facility_phone  inventory_num
# 0  (773) 568-8495         2750424
# 1   (312) 744-7550         917129
# 2   (773) 265-7605        6798366
# 3   (312) 744-7550         917127
# 4   (312) 744-7550         917128

# %%
towed[100:105]
# Out:
#           date  make style model color     plate state             towed_to  \
# 100 2014-11-18  FORD    4D         SIL     B9455    NB        10300 S. Doty
# 101 2014-11-18   BMW    4D         WHI   V960806    IL  400 E. Lower Wacker
# 102 2014-11-18  DODG    PK    TK   RED  1382871B    IL        10300 S. Doty
# 103 2014-11-18  CHEV    4D         TAN   V356714    IL        10300 S. Doty
# 104 2014-11-18  BUIC    4D         WHI   S941660    IL        10300 S. Doty
#
#       facility_phone  inventory_num
# 100  (773) 568-8495         2750400
# 101   (312) 744-7550         917087
# 102  (773) 568-8495         2750398
# 103  (773) 568-8495         2750397
# 104  (773) 568-8495         2750396

# %%
towed.info() # empty string showing up as non-null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5065 entries, 0 to 5064
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            5065 non-null   datetime64[ns]
#  1   make            5065 non-null   object
#  2   style           5065 non-null   object
#  3   model           5065 non-null   object
#  4   color           5065 non-null   object
#  5   plate           5065 non-null   object
#  6   state           5065 non-null   object
#  7   towed_to        5065 non-null   object
#  8   facility_phone  5065 non-null   object
#  9   inventory_num   5065 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 395.8+ KB

# %%
mo.info() # note the nulls in the Awards column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    19 non-null     int64
#  1   Age     19 non-null     int64
#  2   Tm      19 non-null     object
#  3   Lg      19 non-null     object
#  4   W       19 non-null     int64
#  5   L       19 non-null     int64
#  6   W-L%    19 non-null     float64
#  7   ERA     19 non-null     float64
#  8   G       19 non-null     int64
#  9   GS      19 non-null     int64
#  10  GF      19 non-null     int64
#  11  CG      19 non-null     int64
#  12  SHO     19 non-null     int64
#  13  SV      19 non-null     int64
#  14  IP      19 non-null     float64
#  15  H       19 non-null     int64
#  16  R       19 non-null     int64
#  17  ER      19 non-null     int64
#  18  HR      19 non-null     int64
#  19  BB      19 non-null     int64
#  20  IBB     19 non-null     int64
#  21  SO      19 non-null     int64
#  22  HBP     19 non-null     int64
#  23  BK      19 non-null     int64
#  24  WP      19 non-null     int64
#  25  BF      19 non-null     int64
#  26  ERA+    19 non-null     int64
#  27  WHIP    19 non-null     float64
#  28  H/9     19 non-null     float64
#  29  HR/9    19 non-null     float64
#  30  BB/9    19 non-null     float64
#  31  SO/9    19 non-null     float64
#  32  SO/BB   19 non-null     float64
#  33  Awards  15 non-null     object
# dtypes: float64(9), int64(22), object(3)
# memory usage: 5.2+ KB

# %%
mo.describe() # basic stats for any numeric column
# Out:
#               Year        Age          W          L       W-L%        ERA  \
# count    19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean   2004.000000  34.000000   4.315789   3.157895   0.570158   2.222105
# std       5.627314   5.627314   2.083070   1.462994   0.174293   0.918861
# min    1995.000000  25.000000   1.000000   0.000000   0.200000   1.380000
# 25%    1999.500000  29.500000   3.000000   2.000000   0.500000   1.800000
# 50%    2004.000000  34.000000   4.000000   3.000000   0.571000   1.910000
# 75%    2008.500000  38.500000   6.000000   4.000000   0.651500   2.250000
# max    2013.000000  43.000000   8.000000   6.000000   1.000000   5.510000
#
#                G         GS         GF    CG   SHO         SV          IP  \
# count  19.000000  19.000000  19.000000  19.0  19.0  19.000000   19.000000
# mean   58.684211   0.526316  50.105263   0.0   0.0  34.315789   67.315789
# std    17.023032   2.294157  19.944074   0.0   0.0  15.198877   18.657506
# min     9.000000   0.000000   2.000000   0.0   0.0   0.000000    8.100000
# 25%    61.000000   0.000000  51.500000   0.0   0.0  31.500000   62.550000
# 50%    64.000000   0.000000  57.000000   0.0   0.0  39.000000   70.200000
# 75%    66.000000   0.000000  60.500000   0.0   0.0  44.000000   75.100000
# max    74.000000  10.000000  69.000000   0.0   0.0  53.000000  107.200000
#
#                H          R         ER         HR         BB        IBB  \
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean   52.526316  17.894737  16.578947   3.736842  15.052632   2.157895
# std    15.886292   8.305920   8.064434   2.423086   8.140937   1.500487
# min     6.000000   2.000000   2.000000   0.000000   2.000000   0.000000
# 25%    45.000000  14.000000  13.000000   2.500000  10.500000   1.000000
# 50%    58.000000  16.000000  14.000000   3.000000  12.000000   2.000000
# 75%    63.000000  21.000000  19.000000   4.500000  19.000000   3.000000
# max    73.000000  43.000000  41.000000  11.000000  34.000000   6.000000
#
#                SO        HBP         BK         WP          BF        ERA+  \
# count   19.000000  19.000000  19.000000  19.000000   19.000000   19.000000
# mean    61.736842   2.421053   0.157895   0.684211  268.578947  222.157895
# std     24.250641   1.894899   0.374634   0.749269   75.045405   56.108291
# min      8.000000   0.000000   0.000000   0.000000   32.000000   84.000000
# 25%     51.500000   1.000000   0.000000   0.000000  251.000000  192.000000
# 50%     60.000000   2.000000   0.000000   1.000000  277.000000  233.000000
# 75%     73.000000   4.000000   0.000000   1.000000  303.500000  254.500000
# max    130.000000   6.000000   1.000000   2.000000  425.000000  316.000000
#
#             WHIP        H/9       HR/9       BB/9       SO/9      SO/BB
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean    0.998684   6.994737   0.489474   1.994737   8.142105   4.870000
# std     0.171747   1.107787   0.328117   0.779939   1.403296   2.553853
# min     0.665000   5.200000   0.000000   0.800000   5.300000   1.700000
# 25%     0.901000   6.300000   0.300000   1.300000   6.900000   3.350000
# 50%     0.994000   6.900000   0.400000   2.100000   8.000000   4.090000
# 75%     1.070500   7.600000   0.600000   2.400000   9.250000   6.085000
# max     1.507000   9.500000   1.500000   4.000000  10.900000  12.830000

# %%
towed.set_index('date', inplace=True)

# %%
# SELECT *
# FROM towed
# WHERE date = '2014-11-04'
# LIMIT 5;
towed.ix['2014-11-04']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6408\2272064418.py in ?()
#       1 # SELECT *
#       2 # FROM towed
#       3 # WHERE date = '2014-11-04'
#       4 # LIMIT 5;
# ----> 5 towed.ix['2014-11-04']
#
# d:\python build app\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
